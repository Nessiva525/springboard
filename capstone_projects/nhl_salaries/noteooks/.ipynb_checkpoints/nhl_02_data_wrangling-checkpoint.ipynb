# %% [markdown]
# <h1>Capstone 2 - NHL Salaries: 02_data_wrangling

# %% [markdown]
# **Follow up:**
# * try to use code only to create list of 'other' countries
# * drop capfriendly['POS']?
# * drop ELC because their values are limited by the collective bargaining agreement

# %% [markdown]
# <h2>Import Libraries

# %%
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h2>Load Data

# %% [markdown]
# Data was gathered from two sources.
# 1. Salary information was scraped from www.capfriendly.com for the 2023-24 season.  It also includes player performance statistics and advanced metrics for player performance.
# <br>**Note:** capfriendly.com was recently purchased and will reportedly be shut down on or after July 5, 2024. https://puckpedia.com/ is the current best alternative source of salary cap information.  <br>
# <br>
# 2. Official player performance statistics from www.nhl.com

# %% [markdown]
# <h3> Load capfriendly.com data

# %% [markdown]
#  Data includes all players with an NHL contract in the 2023-34 season reguardless of whether they played a game or not
#
# Data Reference: https://www.capfriendly.com/browse/active/2025/salary?stats-season=2024&display=signing-team,country,weight,height,draft,waivers-exempt,signing-status,expiry-year,performance-bonus,signing-bonus,caphit-percent,aav,length,minors-salary,base-salary,skater-individual-advanced-stats,skater-on-ice-advanced-stats,goalie-advanced-stats,arbitration-eligible,type,signing-age,signing-date,arbitration,extension

# %%
capfriendly = pd.read_csv(r'/Users/ness/Desktop/Springboard/Projects/-Capstone 2/NHL Salaries/raw_data/23_24_capfriendly_extended_data.csv')

# %% [markdown]
# <h3>Load and combine NHL.com data

# %% [markdown]
# Data include only includes skaters (goalies excluded) who played in at least one game in the NHL during the 2023-24 season

# %%
# specifying the path to .xlsx files
path = "/Users/ness/Desktop/Springboard/Projects/-Capstone 2/NHL Salaries/raw_data/"
 
# .xlsx files in the path
file_list = glob.glob(path + "/*.xlsx")
 
# list of excel files we want to merge.
excl_list = []
 
for file in file_list:
    excl_list.append(pd.read_excel(file))
 
# concatenate all DataFrames in the list
nhl_official_merged = pd.concat(excl_list, ignore_index=True)
nhl_official_merged.shape
# Out:
# (924, 24)

# %% [markdown]
# **Export merged NHL.com data to .csv**

# %%
#nhl_official_merged.to_csv('/Users/ness/Desktop/Springboard/Projects/-Capstone 2/NHL Salaries/raw_data/nhl_official_merged.csv', index=False)

# %% [markdown]
# **change name of nhl_official_merged for ease of use**

# %%
nhl = nhl_official_merged

#confirm same shape
nhl.shape
# Out:
# (924, 24)

# %% [markdown]
# <h2>Explore capfriendly.com data

# %% [markdown]
# Capfriendly Features with description:
# https://docs.google.com/document/d/1F8UDKo5p10ED4UygCGKGzrnNQBuGPRt0FqkQwN16b9M/edit?usp=sharing

# %% [markdown]
# Features from both datasets with current types and needed modifications:
# https://docs.google.com/document/d/1jo5o9vj3ags7nBWPP4MO-qoZKUys22-ipBtEQ6aPsE8/edit?usp=sharing

# %%
capfriendly.head()
# Out:
#                 PLAYER TEAM  AGE        COUNTRY  WEIGHT HEIGHT POS HANDED  GP  \
# 0  1. Nathan MacKinnon  COL   27         Canada     200   6'0"   C  Right  82
# 1    2. Connor McDavid  EDM   26         Canada     193   6'1"   C   Left  76
# 2    3. Artemi Panarin  NYR   31         Russia     170  5'11"  LW  Right  82
# 3   4. Auston Matthews  TOR   25  United States     215   6'3"   C   Left  81
# 4     5. Erik Karlsson  PIT   33         Sweden     190   6'0"  RD  Right  82
#
#     G  ... SIGNING AGE CLAUSE LENGTH SIGNING EXPIRY EXP. YEAR      CAP HIT  \
# 0  51  ...          27    NMC      8     UFA    UFA      2031  $12,600,000
# 1  32  ...          21    NMC      8     RFA    UFA      2026  $12,500,000
# 2  49  ...          27    NMC      7     UFA    UFA      2026  $11,642,857
# 3  69  ...          21    NMC      5     RFA    UFA      2024  $11,640,250
# 4  11  ...          29    NMC      8     UFA    UFA      2027  $11,500,000
#
#   CAP HIT %          AAV       SALARY
# 0     15.3%  $12,600,000  $16,500,000
# 1     16.7%  $12,500,000  $11,000,000
# 2     14.3%  $11,642,857  $11,000,000
# 3     14.6%  $11,640,250   $7,975,000
# 4     14.5%  $11,500,000  $11,500,000
#
# [5 rows x 58 columns]

# %%
capfriendly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1571 entries, 0 to 1570
# Data columns (total 58 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PLAYER        1571 non-null   object
#  1   TEAM          1571 non-null   object
#  2   AGE           1571 non-null   int64
#  3   COUNTRY       1571 non-null   object
#  4   WEIGHT        1571 non-null   int64
#  5   HEIGHT        1571 non-null   object
#  6   POS           1571 non-null   object
#  7   HANDED        1571 non-null   object
#  8   GP            1571 non-null   int64
#  9   G             1571 non-null   object
#  10  A             1571 non-null   object
#  11  P             1571 non-null   object
#  12  P/GP          1571 non-null   object
#  13  +/-           1571 non-null   object
#  14  Sh            1571 non-null   object
#  15  Sh%           1571 non-null   object
#  16  TOI           1095 non-null   object
#  17  ixG           1571 non-null   object
#  18  iSh           1571 non-null   object
#  19  iCF           1571 non-null   object
#  20  iFF           1571 non-null   object
#  21  ixG60         1571 non-null   object
#  22  iSh60         1571 non-null   object
#  23  iCF60         1571 non-null   object
#  24  iFF60         1571 non-null   object
#  25  SF            1092 non-null   object
#  26  SA            1092 non-null   object
#  27  SF%           1571 non-null   object
#  28  CF            1092 non-null   object
#  29  CA            1092 non-null   object
#  30  CF%           1571 non-null   object
#  31  FF            1092 non-null   object
#  32  FA            1092 non-null   object
#  33  FF%           1571 non-null   object
#  34  xGF           1571 non-null   object
#  35  xGA           1571 non-null   object
#  36  xGF%          1571 non-null   object
#  37  W             1571 non-null   object
#  38  L             1571 non-null   object
#  39  SO            1571 non-null   object
#  40  GAA           1571 non-null   object
#  41  Sv%           1571 non-null   object
#  42  GA60          1571 non-null   object
#  43  xGA60         1571 non-null   object
#  44  GSAx60        1571 non-null   object
#  45  SIGNING TEAM  1571 non-null   object
#  46  EXTENSION     419 non-null    object
#  47  SIGNING DATE  1571 non-null   object
#  48  SIGNING AGE   1571 non-null   int64
#  49  CLAUSE        245 non-null    object
#  50  LENGTH        1571 non-null   int64
#  51  SIGNING       1571 non-null   object
#  52  EXPIRY        1571 non-null   object
#  53  EXP. YEAR     1571 non-null   int64
#  54  CAP HIT       1571 non-null   object
#  55  CAP HIT %     1571 non-null   object
#  56  AAV           1571 non-null   object
#  57  SALARY        1571 non-null   object
# dtypes: int64(6), object(52)
# memory usage: 712.0+ KB

# %%
#save origional column names to list
capfriendly_orig_columns=capfriendly.columns.tolist()

# %%
capfriendly_orig_columns
# Out:
# ['PLAYER',
#  'TEAM',
#  'AGE',
#  'COUNTRY',
#  'WEIGHT',
#  'HEIGHT',
#  'POS',
#  'HANDED',
#  'GP',
#  'G',
#  'A',
#  'P',
#  'P/GP',
#  '+/-',
#  'Sh',
#  'Sh%',
#  'TOI',
#  'ixG',
#  'iSh',
#  'iCF',
#  'iFF',
#  'ixG60',
#  'iSh60',
#  'iCF60',
#  'iFF60',
#  'SF',
#  'SA',
#  'SF%',
#  'CF',
#  'CA',
#  'CF%',
#  'FF',
#  'FA',
#  'FF%',
#  'xGF',
#  'xGA',
#  'xGF%',
#  'W',
#  'L',
#  'SO',
#  'GAA',
#  'Sv%',
#  'GA60',
#  'xGA60',
#  'GSAx60',
#  'SIGNING TEAM',
#  'EXTENSION',
#  'SIGNING DATE',
#  'SIGNING AGE',
#  'CLAUSE',
#  'LENGTH',
#  'SIGNING',
#  'EXPIRY',
#  'EXP. YEAR',
#  'CAP HIT',
#  'CAP HIT %',
#  'AAV',
#  'SALARY']

# %% [markdown]
# <h3> Drop irrelivant data

# %% [markdown]
# <h4>Limit capfriendly.com data to only skaters

# %%
capfriendly.shape
# Out:
# (1571, 58)

# %%
capfriendly = capfriendly[capfriendly['POS']!='G']
capfriendly.shape
# Out:
# (1400, 58)

# %% [markdown]
# <h4>Drop unnecessary columns

# %% [markdown]
# * The team that signed the player ('SIGNING TEAM') will affect salary number not the team they currently play for ('TEAM') so the current 'TEAM' will be dropped.
# * 'W', 'L', 'SO', 'GAA', 'Sv%', 'GA60', 'xGA60', and 'GSAx60' are all statistics for goalies which are not included in this project
# * 'CAP HIT', and  'CAP HIT %' are what the player's current team has against the salary cap for that player.  It includes any portion of the AAV held back by the previous team after a trade and therefore does not show the whole picture.
# * salary is only a portion of the AAV calculation and can be front loaded or backloaded to a contract and therefore does not show the whole picture.

# %%
drop = ['TEAM','W','L','SO','GAA','Sv%','GA60','xGA60','GSAx60','CAP HIT','CAP HIT %','SALARY']

capfriendly.drop(columns=drop, inplace=True)

# %%
capfriendly.shape
# Out:
# (1400, 46)

# %%
capfriendly_orig_columns_after_drop = capfriendly.columns.tolist()
capfriendly_orig_columns_after_drop
# Out:
# ['PLAYER',
#  'AGE',
#  'COUNTRY',
#  'WEIGHT',
#  'HEIGHT',
#  'POS',
#  'HANDED',
#  'GP',
#  'G',
#  'A',
#  'P',
#  'P/GP',
#  '+/-',
#  'Sh',
#  'Sh%',
#  'TOI',
#  'ixG',
#  'iSh',
#  'iCF',
#  'iFF',
#  'ixG60',
#  'iSh60',
#  'iCF60',
#  'iFF60',
#  'SF',
#  'SA',
#  'SF%',
#  'CF',
#  'CA',
#  'CF%',
#  'FF',
#  'FA',
#  'FF%',
#  'xGF',
#  'xGA',
#  'xGF%',
#  'SIGNING TEAM',
#  'EXTENSION',
#  'SIGNING DATE',
#  'SIGNING AGE',
#  'CLAUSE',
#  'LENGTH',
#  'SIGNING',
#  'EXPIRY',
#  'EXP. YEAR',
#  'AAV']

# %% [markdown]
# <h3><ins>Categorical data<ins>

# %%
categorical=['COUNTRY', 'SIGNING TEAM', 'CLAUSE', 'SIGNING', 'EXPIRY','POS', 'HANDED']
capfriendly[categorical].head(10)
# Out:
#           COUNTRY SIGNING TEAM CLAUSE SIGNING EXPIRY     POS HANDED
# 0          Canada          COL    NMC     UFA    UFA       C  Right
# 1          Canada          EDM    NMC     RFA    UFA       C   Left
# 2          Russia          NYR    NMC     UFA    UFA      LW  Right
# 3   United States          TOR    NMC     RFA    UFA       C   Left
# 4          Sweden          SJS    NMC     UFA    UFA      RD  Right
# 5  Czech Republic          BOS    NMC     UFA    UFA      RW  Right
# 6          Canada          LAK  M-NTC     UFA    UFA      RD  Right
# 7          Canada          TOR    NMC     UFA    UFA   C, LW   Left
# 8          Canada          TOR    NMC     RFA    UFA      RW  Right
# 9          Canada          CGY    NMC     UFA    UFA  LW, RW   Left

# %% [markdown]
# **Country Data**
# countries with less than 5% of representation will be grouped into "Other" for the 'COUNTRY' category

# %%
capfriendly['COUNTRY'].unique()
# Out:
# array(['Canada', 'Russia', 'United States', 'Sweden', 'Czech Republic',
#        'Finland', 'Slovenia', 'Switzerland', 'Germany', 'Norway',
#        'Denmark', 'Austria', 'Slovakia', 'Belarus', 'Latvia',
#        'Netherlands', 'France', 'Uzbekistan', 'Poland', 'United Kingdom',
#        'Australia', 'Belgium'], dtype=object)

# %% [markdown]
# **THIS IS A STEP I WANT TO FIGURE OUT HOW TO DO ONLY WITH CODE**
# want: create filtering mask to then be able to change 'COUNTRY' values not in list to 'Other'

# %%
#filtering mask? -- need to figure out
capfriendly['COUNTRY'].astype('category').value_counts(normalize=True)>0.05
# Out:
# COUNTRY
# Canada             True
# United States      True
# Sweden             True
# Russia             True
# Finland            True
# Czech Republic    False
# Slovakia          False
# Switzerland       False
# Belarus           False
# Germany           False
# Norway            False
# France            False
# Denmark           False
# Austria           False
# Latvia            False
# United Kingdom    False
# Australia         False
# Netherlands       False
# Slovenia          False
# Poland            False
# Belgium           False
# Uzbekistan        False
# Name: proportion, dtype: bool

# %%
# Manual work around for above
#create a list of countries representing > 5% of countries,
non_other = ['Canada', 'United States', 'Sweden', 'Russia', 'Finland']

# %%
#replace countries not representing at least 5% with "Other"
capfriendly.loc[~capfriendly["COUNTRY"].isin(non_other), "COUNTRY"] = "Other"

# %%
capfriendly['COUNTRY'].value_counts(normalize=True)
# Out:
# COUNTRY
# Canada           0.438571
# United States    0.277857
# Sweden           0.092857
# Other            0.085000
# Russia           0.055000
# Finland          0.050714
# Name: proportion, dtype: float64

# %%
#change data type to category
capfriendly['COUNTRY'] = capfriendly['COUNTRY'].astype('category')
capfriendly['COUNTRY'].dtype
# Out:
# CategoricalDtype(categories=['Canada', 'Finland', 'Other', 'Russia', 'Sweden',
#                   'United States'],
# , ordered=False)

# %% [markdown]
# <h4>Explore Signing Team

# %%
#number of unique teams
len(capfriendly['SIGNING TEAM'].unique())
# Out:
# 32

# %%
#unique teams
capfriendly['SIGNING TEAM'].unique()
# Out:
# array(['COL', 'EDM', 'NYR', 'TOR', 'SJS', 'BOS', 'LAK', 'CGY', 'FLA',
#        'BUF', 'DAL', 'CBJ', 'TBL', 'WSH', 'CHI', 'VGK', 'NYI', 'NSH',
#        'MIN', 'NJD', 'DET', 'PIT', 'WPG', 'CAR', 'OTT', 'PHI', 'STL',
#        'VAN', 'MTL', 'SEA', 'ARI', 'ANA'], dtype=object)

# %%
#convert to category and ensure no whitespace
capfriendly['SIGNING TEAM']=capfriendly['SIGNING TEAM'].str.strip().astype('category')
capfriendly['SIGNING TEAM'].dtype
# Out:
# CategoricalDtype(categories=['ANA', 'ARI', 'BOS', 'BUF', 'CAR', 'CBJ', 'CGY', 'CHI',
#                   'COL', 'DAL', 'DET', 'EDM', 'FLA', 'LAK', 'MIN', 'MTL',
#                   'NJD', 'NSH', 'NYI', 'NYR', 'OTT', 'PHI', 'PIT', 'SEA',
#                   'SJS', 'STL', 'TBL', 'TOR', 'VAN', 'VGK', 'WPG', 'WSH'],
# , ordered=False)

# %% [markdown]
# <h4>Explore 'CLAUSE'

# %% [markdown]
# * 'CLAUSE' represents trade or movenment clauses in player contracts.
#     * 'NMC' means No Movement Clause
#     * 'NTC' means No Trade Clause.
#     * A 'M-' in front of either means it is modified or limited to n teams. When it includes both it means it transfers from one to the other.
# * 'CLAUSE' can be a trade off for length or money in a contract negotiation

# %%
#unique teams
capfriendly['CLAUSE'].unique()
# Out:
# array(['NMC', 'M-NTC', nan, 'M-NTC, NMC', 'NTC', 'NTC, NMC'], dtype=object)

# %%
# Replace NaN values with 'None'
capfriendly.loc[capfriendly["CLAUSE"].isna(), "CLAUSE"] = 'None'

# %%
#convert to category and ensure no whitespace
capfriendly['CLAUSE'] = capfriendly['CLAUSE'].str.strip().astype('category')
capfriendly['CLAUSE'].unique()
# Out:
# ['NMC', 'M-NTC', 'None', 'M-NTC, NMC', 'NTC', 'NTC, NMC']
# Categories (6, object): ['M-NTC', 'M-NTC, NMC', 'NMC', 'NTC', 'NTC, NMC', 'None']

# %% [markdown]
# <h4>Explore 'SIGNING' - Contract type @ signing

# %% [markdown]
# * 'SIGNING' represents free agent status at time of signing
# * 'UFA' means Unrestricted Free Agent, 'RFA' means Restricted Free Agent, and 'ELC' means Entry Level Contract
#     * 'UFA' can sign with any team
#     * 'RFA' can only sign with current team or under certain situations can sign with another team but current team receives compensation in terms of future draft picks
#     * 'ELC' is a specific type of contract for players entering the league and have strict regiulations especially reguarding salary and length.

# %%
capfriendly['SIGNING'].value_counts()
# Out:
# SIGNING
# UFA    535
# ELC    511
# RFA    354
# Name: count, dtype: int64

# %%
#convert to category and ensure no whitespace
capfriendly['SIGNING'] = capfriendly['SIGNING'].str.strip().astype('category')

# %%
capfriendly['SIGNING'].unique()
# Out:
# ['UFA', 'RFA', 'ELC']
# Categories (3, object): ['ELC', 'RFA', 'UFA']

# %% [markdown]
# <h4>Explore 'EXPIRY' - Contract type @ expiration of contract

# %% [markdown]
# * 'EXPIRY' represents free agent status at time of contract expiration
# * 'unrestricted' will include: 'UFA', 'UFANo QO' means Unrestricted Free Agent no Qualifing Offer and 'UFAGroup 6' which is UFA who has met age and experience requitements to become an UFA
# * 'restricted' will include: 'RFA' and '10.2(c)' which is a type of RFA who has not met age and experience requitements to become an UFA and therfore can only sign with their current organization
# * Contracts explained: https://afpanalytics.com/nhl-business-statistic-glossary/#:~:text=Player%20Contracts,minimum%20salary%20%2B%20%24375%2C000).

# %%
capfriendly['EXPIRY'].value_counts()
# Out:
# EXPIRY
# UFA           660
# RFA           583
# UFANo QO       80
# UFAGroup 6     52
# 10.2(c)        25
# Name: count, dtype: int64

# %%
#convert contract types to 'unrestricted' or 'restricted'
capfriendly.loc[capfriendly["EXPIRY"].isin(['UFA', 'UFANo QO', 'UFAGroup 6' ]), "EXPIRY"] = 'unrestricted'
capfriendly.loc[capfriendly["EXPIRY"].isin(['RFA', '10.2(c)' ]), "EXPIRY"] = 'restricted'

# %%
# convert to category
capfriendly['EXPIRY'] = capfriendly['EXPIRY'].astype('category')

# %%
capfriendly['EXPIRY'].unique()
# Out:
# ['unrestricted', 'restricted']
# Categories (2, object): ['restricted', 'unrestricted']

# %% [markdown]
# <h4>Explore 'POS' - Position

# %% [markdown]
# * Players cam play multiple positions: 'C' center, 'LW' left wing, 'RW' right wing, 'LD' left defence, 'RD' right defence

# %%
#capfriendly positions: all positions they may play
capfriendly['POS'].unique()
# Out:
# array(['C', 'LW', 'RD', 'RW', 'C, LW', 'LW, RW', 'C, RW', 'LD', 'LW, C',
#        'RW, C', 'C, RW, LW', 'LD/RD', 'RW, LW', 'C, LW, RW', 'LW, RW, C',
#        'RW, C, LW', 'LW, C, RW', 'LD/RD, LW', 'D', 'RW, LW, C', 'LW, LD'],
#       dtype=object)

# %%
#explore position for ELC contract at signing 
capfriendly['POS'].loc[capfriendly['SIGNING']=='ELC'].value_counts(normalize=True)
# Out:
# POS
# C            0.221135
# LD           0.209393
# LW           0.127202
# RD           0.127202
# RW           0.123288
# LW, RW       0.037182
# C, LW        0.029354
# LW, C        0.027397
# RW, C        0.025440
# RW, LW       0.025440
# LD/RD        0.015656
# C, RW        0.013699
# C, LW, RW    0.009785
# LW, C, RW    0.001957
# C, RW, LW    0.001957
# D            0.001957
# RW, LW, C    0.001957
# Name: proportion, dtype: float64

# %%
#explore position for ELC or RFA contract at signing 
capfriendly['POS'].loc[capfriendly['SIGNING'].isin(['RFA'])].value_counts(normalize=True)
# Out:
# POS
# LD           0.138418
# RD           0.138418
# C            0.121469
# LW, RW       0.104520
# RW           0.096045
# LD/RD        0.079096
# RW, LW       0.076271
# C, LW        0.056497
# LW           0.053672
# C, RW        0.042373
# LW, C        0.036723
# RW, C        0.025424
# LW, RW, C    0.008475
# C, LW, RW    0.008475
# LW, C, RW    0.005650
# C, RW, LW    0.002825
# RW, C, LW    0.002825
# LD/RD, LW    0.002825
# Name: proportion, dtype: float64

# %%
#primary position as listed  in oficial listed NHL stats
nhl['Pos'].value_counts()
# Out:
# Pos
# D    315
# C    297
# L    171
# R    141
# Name: count, dtype: int64

# %% [markdown]
# **Reasoning to drop capfriendly['POS']:** Just because they play multiple positions doesnt mean it is a 50:50 split per position.  There is no way to tell if they play 50:50 at eack or 99:1 from the data.

# %% [markdown]
# **create list for follow up on when joined: capfriendly_follow_up**

# %%
capfriendly_follow_up = [{'POS':'drop after join?  too many positions'}]

# %%
# Defer to official NHL listed positions and drop capfriendly['POS']
#capfriendly.drop(columns='POS', inplace=True)

# %%
#capfriendly.columns

# %% [markdown]
# <h4>Explore 'HANDED'

# %%
capfriendly['HANDED'].value_counts()
# Out:
# HANDED
# Left     858
# Right    542
# Name: count, dtype: int64

# %%
#convert to category and ensure no whitespace
capfriendly['HANDED'] = capfriendly['HANDED'].str.strip().astype('category')

# %%
capfriendly['HANDED'].unique()
# Out:
# ['Right', 'Left']
# Categories (2, object): ['Left', 'Right']

# %% [markdown]
# <h3><ins>Integer data<ins>

# %%
# features needing to convert to 'int'
to_int = ['AGE', 'WEIGHT', 'HEIGHT', 'GP', 'G', 'A', 'P', '+/-', 'Sh', 'iSh', 'iCF', 'iFF', 'SF', 'SA', 'CF', 'CA', 'FF', 'FA', 'AAV']
capfriendly[to_int].head()
# Out:
#    AGE  WEIGHT HEIGHT  GP   G    A    P +/-   Sh  iSh  iCF  iFF    SF   SA  \
# 0   27     200   6'0"  82  51   89  140  35  405  404  690  525  1331  787
# 1   26     193   6'1"  76  32  100  132  35  263  263  452  354  1195  683
# 2   31     170  5'11"  82  49   71  120  18  302  303  651  431  1161  707
# 3   25     215   6'3"  81  69   38  107  31  369  368  694  534  1127  673
# 4   33     190   6'0"  82  11   45   56   4  213  214  550  311  1291  881
#
#      CF    CA    FF    FA          AAV
# 0  2562  1516  1882  1115  $12,600,000
# 1  2240  1238  1673   934  $12,500,000
# 2  2342  1308  1723   987  $11,642,857
# 3  2240  1473  1642  1025  $11,640,250
# 4  2601  1749  1840  1332  $11,500,000

# %%
#check data types and nulls
capfriendly[to_int].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1400 entries, 0 to 1570
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AGE     1400 non-null   int64
#  1   WEIGHT  1400 non-null   int64
#  2   HEIGHT  1400 non-null   object
#  3   GP      1400 non-null   int64
#  4   G       1400 non-null   object
#  5   A       1400 non-null   object
#  6   P       1400 non-null   object
#  7   +/-     1400 non-null   object
#  8   Sh      1400 non-null   object
#  9   iSh     1400 non-null   object
#  10  iCF     1400 non-null   object
#  11  iFF     1400 non-null   object
#  12  SF      921 non-null    object
#  13  SA      921 non-null    object
#  14  CF      921 non-null    object
#  15  CA      921 non-null    object
#  16  FF      921 non-null    object
#  17  FA      921 non-null    object
#  18  AAV     1400 non-null   object
# dtypes: int64(3), object(16)
# memory usage: 218.8+ KB

# %% [markdown]
# <h4>Convert features with no null values and that don't need modification before changing to 'int'

# %%
to_int_basic = ['AGE', 'WEIGHT', 'GP', 'G', 'A', 'P', '+/-', 'Sh', 'iSh', 'iCF', 'iFF']
capfriendly[to_int_basic] = capfriendly[to_int_basic].astype('int')
capfriendly[to_int_basic].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1400 entries, 0 to 1570
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AGE     1400 non-null   int64
#  1   WEIGHT  1400 non-null   int64
#  2   GP      1400 non-null   int64
#  3   G       1400 non-null   int64
#  4   A       1400 non-null   int64
#  5   P       1400 non-null   int64
#  6   +/-     1400 non-null   int64
#  7   Sh      1400 non-null   int64
#  8   iSh     1400 non-null   int64
#  9   iCF     1400 non-null   int64
#  10  iFF     1400 non-null   int64
# dtypes: int64(11)
# memory usage: 131.2 KB

# %%
#subset integer list to ones that need modifying
int_modify = [x for x in to_int if x not in to_int_basic]
capfriendly[int_modify].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1400 entries, 0 to 1570
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HEIGHT  1400 non-null   object
#  1   SF      921 non-null    object
#  2   SA      921 non-null    object
#  3   CF      921 non-null    object
#  4   CA      921 non-null    object
#  5   FF      921 non-null    object
#  6   FA      921 non-null    object
#  7   AAV     1400 non-null   object
# dtypes: object(8)
# memory usage: 98.4+ KB

# %% [markdown]
# <h4>Explore 'HEIGHT'

# %% [markdown]
# * change from foot, inches to inches

# %%
#remove " from HEIGHT
capfriendly['HEIGHT'] = capfriendly['HEIGHT'].astype(str).str.replace('"', '')

# %%
# convert to inches
capfriendly["HEIGHT_in"] = (capfriendly.HEIGHT.str.split("'").str[0].astype(int) * 12) + (
    capfriendly.HEIGHT.str.split("'").str[1].astype(int))
capfriendly["HEIGHT_in"].head()
# Out:
# 0    72
# 1    73
# 2    71
# 3    75
# 4    72
# Name: HEIGHT_in, dtype: int64

# %%
#replace HEIGHT in lists
to_int[2] = 'HEIGHT_in'
int_modify[0]="HEIGHT_in"
f"{to_int}, {int_modify}"
# Out:
# "['AGE', 'WEIGHT', 'HEIGHT_in', 'GP', 'G', 'A', 'P', '+/-', 'Sh', 'iSh', 'iCF', 'iFF', 'SF', 'SA', 'CF', 'CA', 'FF', 'FA', 'AAV'], ['HEIGHT_in', 'SF', 'SA', 'CF', 'CA', 'FF', 'FA', 'AAV']"

# %% [markdown]
# <h4>Explore integer advanced stats - 'SF', 'SA', 'CF', 'CA', 'FF', 'FA'

# %%
capfriendly[int_modify].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1400 entries, 0 to 1570
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   HEIGHT_in  1400 non-null   int64
#  1   SF         921 non-null    object
#  2   SA         921 non-null    object
#  3   CF         921 non-null    object
#  4   CA         921 non-null    object
#  5   FF         921 non-null    object
#  6   FA         921 non-null    object
#  7   AAV        1400 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 98.4+ KB

# %% [markdown]
# <h4>Explore Nan

# %%
capfriendly.loc[capfriendly['SF'].isna()].T
# Out:
#                            53              72                     94    \
# PLAYER        54. Jakub Voracek  73. Shea Weber  95. Gabriel Landeskog
# AGE                          33              37                     30
# COUNTRY                   Other          Canada                 Sweden
# WEIGHT                      214             230                    215
# HEIGHT                      6'2             6'4                    6'1
# POS                      RW, LW              RD                  LW, C
# HANDED                     Left           Right                   Left
# GP                            0               0                      0
# G                             0               0                      0
# A                             0               0                      0
# P                             0               0                      0
# P/GP                       0.00            0.00                   0.00
# +/-                           0               0                      0
# Sh                            0               0                      0
# Sh%                        0.00            0.00                   0.00
# TOI                         NaN             NaN                    NaN
# ixG                        0.00            0.00                   0.00
# iSh                           0               0                      0
# iCF                           0               0                      0
# iFF                           0               0                      0
# ixG60                      0.00            0.00                   0.00
# iSh60                      0.00            0.00                   0.00
# iCF60                      0.00            0.00                   0.00
# iFF60                      0.00            0.00                   0.00
# SF                          NaN             NaN                    NaN
# SA                          NaN             NaN                    NaN
# SF%                        0.00            0.00                   0.00
# CF                          NaN             NaN                    NaN
# CA                          NaN             NaN                    NaN
# CF%                        0.00            0.00                   0.00
# FF                          NaN             NaN                    NaN
# FA                          NaN             NaN                    NaN
# FF%                        0.00            0.00                   0.00
# xGF                        0.00            0.00                   0.00
# xGA                        0.00            0.00                   0.00
# xGF%                       0.00            0.00                   0.00
# SIGNING TEAM                PHI             NSH                    COL
# EXTENSION                     ✔             NaN                      ✔
# SIGNING DATE      Jul. 30, 2015   Jul. 24, 2012          Jul. 27, 2021
# SIGNING AGE                  25              26                     28
# CLAUSE                     None            None                    NMC
# LENGTH                        8              14                      8
# SIGNING                     UFA             RFA                    UFA
# EXPIRY             unrestricted    unrestricted           unrestricted
# EXP. YEAR                  2024            2026                   2029
# AAV                  $8,250,000      $7,857,143             $7,000,000
# HEIGHT_in                    74              76                     73
#
#                             98               122               159   \
# PLAYER        99. Brent Seabrook  123. Ryan Ellis  160. Jake Muzzin
# AGE                           38               32                34
# COUNTRY                   Canada           Canada            Canada
# WEIGHT                       220              180               217
# HEIGHT                       6'3             5'10               6'3
# POS                           RD               RD                LD
# HANDED                     Right            Right              Left
# GP                             0                0                 0
# G                              0                0                 0
# A                              0                0                 0
# P                              0                0                 0
# P/GP                        0.00             0.00              0.00
# +/-                            0                0                 0
# Sh                             0                0                 0
# Sh%                         0.00             0.00              0.00
# TOI                          NaN              NaN               NaN
# ixG                         0.00             0.00              0.00
# iSh                            0                0                 0
# iCF                            0                0                 0
# iFF                            0                0                 0
# ixG60                       0.00             0.00              0.00
# iSh60                       0.00             0.00              0.00
# iCF60                       0.00             0.00              0.00
# iFF60                       0.00             0.00              0.00
# SF                           NaN              NaN               NaN
# SA                           NaN              NaN               NaN
# SF%                         0.00             0.00              0.00
# CF                           NaN              NaN               NaN
# CA                           NaN              NaN               NaN
# CF%                         0.00             0.00              0.00
# FF                           NaN              NaN               NaN
# FA                           NaN              NaN               NaN
# FF%                         0.00             0.00              0.00
# xGF                         0.00             0.00              0.00
# xGA                         0.00             0.00              0.00
# xGF%                        0.00             0.00              0.00
# SIGNING TEAM                 CHI              NSH               TOR
# EXTENSION                      ✔                ✔                 ✔
# SIGNING DATE       Sep. 26, 2015    Aug. 14, 2018     Feb. 24, 2020
# SIGNING AGE                   31               28                31
# CLAUSE                     M-NTC             None             M-NTC
# LENGTH                         8                8                 4
# SIGNING                      UFA              UFA               UFA
# EXPIRY              unrestricted     unrestricted      unrestricted
# EXP. YEAR                   2024             2027              2024
# AAV                   $6,875,000       $6,250,000        $5,625,000
# HEIGHT_in                     75               70                75
#
#                            177                  401               418   \
# PLAYER        178. Bryan Little  402. Tucker Poolman  419. Radim Simek
# AGE                          35                   30                30
# COUNTRY                  Canada        United States             Other
# WEIGHT                      191                  199               200
# HEIGHT                      6'0                  6'2              5'11
# POS                       C, RW                   RD             LD/RD
# HANDED                    Right                Right              Left
# GP                            0                    0                 0
# G                             0                    0                 0
# A                             0                    0                 0
# P                             0                    0                 0
# P/GP                       0.00                 0.00              0.00
# +/-                           0                    0                 0
# Sh                            0                    0                 0
# Sh%                        0.00                 0.00              0.00
# TOI                         NaN                  NaN               NaN
# ixG                        0.00                 0.00              0.00
# iSh                           0                    0                 0
# iCF                           0                    0                 0
# iFF                           0                    0                 0
# ixG60                      0.00                 0.00              0.00
# iSh60                      0.00                 0.00              0.00
# iCF60                      0.00                 0.00              0.00
# iFF60                      0.00                 0.00              0.00
# SF                          NaN                  NaN               NaN
# SA                          NaN                  NaN               NaN
# SF%                        0.00                 0.00              0.00
# CF                          NaN                  NaN               NaN
# CA                          NaN                  NaN               NaN
# CF%                        0.00                 0.00              0.00
# FF                          NaN                  NaN               NaN
# FA                          NaN                  NaN               NaN
# FF%                        0.00                 0.00              0.00
# xGF                        0.00                 0.00              0.00
# xGA                        0.00                 0.00              0.00
# xGF%                       0.00                 0.00              0.00
# SIGNING TEAM                WPG                  VAN               SJS
# EXTENSION                     ✔                  NaN                 ✔
# SIGNING DATE      Sep. 14, 2017        Jul. 28, 2021      Mar. 3, 2020
# SIGNING AGE                  30                   28                27
# CLAUSE                    M-NTC                 None              None
# LENGTH                        6                    4                 4
# SIGNING                     UFA                  UFA               UFA
# EXPIRY             unrestricted         unrestricted      unrestricted
# EXP. YEAR                  2024                 2025              2024
# AAV                  $5,291,667           $2,500,000        $2,250,000
# HEIGHT_in                    72                   74                71
#
#                              498   ...                 1542  \
# PLAYER        499. Riley Stillman  ...  1543. Sheldon Dries
# AGE                            25  ...                   29
# COUNTRY                    Canada  ...        United States
# WEIGHT                        196  ...                  180
# HEIGHT                        6'1  ...                  5'9
# POS                            LD  ...                    C
# HANDED                       Left  ...                 Left
# GP                              0  ...                    0
# G                               0  ...                    0
# A                               0  ...                    0
# P                               0  ...                    0
# P/GP                         0.00  ...                 0.00
# +/-                             0  ...                    0
# Sh                              0  ...                    0
# Sh%                          0.00  ...                 0.00
# TOI                           NaN  ...                  NaN
# ixG                          0.00  ...                 0.00
# iSh                             0  ...                    0
# iCF                             0  ...                    0
# iFF                             0  ...                    0
# ixG60                        0.00  ...                 0.00
# iSh60                        0.00  ...                 0.00
# iCF60                        0.00  ...                 0.00
# iFF60                        0.00  ...                 0.00
# SF                            NaN  ...                  NaN
# SA                            NaN  ...                  NaN
# SF%                          0.00  ...                 0.00
# CF                            NaN  ...                  NaN
# CA                            NaN  ...                  NaN
# CF%                          0.00  ...                 0.00
# FF                            NaN  ...                  NaN
# FA                            NaN  ...                  NaN
# FF%                          0.00  ...                 0.00
# xGF                          0.00  ...                 0.00
# xGA                          0.00  ...                 0.00
# xGF%                         0.00  ...                 0.00
# SIGNING TEAM                  CHI  ...                  VAN
# EXTENSION                       ✔  ...                    ✔
# SIGNING DATE        Apr. 25, 2021  ...        Jun. 27, 2022
# SIGNING AGE                    23  ...                   28
# CLAUSE                       None  ...                 None
# LENGTH                          3  ...                    2
# SIGNING                       RFA  ...                  UFA
# EXPIRY               unrestricted  ...         unrestricted
# EXP. YEAR                    2024  ...                 2024
# AAV                    $1,350,000  ...             $762,500
# HEIGHT_in                      73  ...                   69
#
#                              1543               1549                 1550  \
# PLAYER        1544. Matt Kiersted  1550. Brad Malone  1551. Chris Wideman
# AGE                            25                 34                   33
# COUNTRY             United States             Canada        United States
# WEIGHT                        181                217                  183
# HEIGHT                        6'0                6'2                 5'10
# POS                            LD              C, LW                   RD
# HANDED                       Left               Left                Right
# GP                              0                  0                    0
# G                               0                  0                    0
# A                               0                  0                    0
# P                               0                  0                    0
# P/GP                         0.00               0.00                 0.00
# +/-                             0                  0                    0
# Sh                              0                  0                    0
# Sh%                          0.00               0.00                 0.00
# TOI                           NaN                NaN                  NaN
# ixG                          0.00               0.00                 0.00
# iSh                             0                  0                    0
# iCF                             0                  0                    0
# iFF                             0                  0                    0
# ixG60                        0.00               0.00                 0.00
# iSh60                        0.00               0.00                 0.00
# iCF60                        0.00               0.00                 0.00
# iFF60                        0.00               0.00                 0.00
# SF                            NaN                NaN                  NaN
# SA                            NaN                NaN                  NaN
# SF%                          0.00               0.00                 0.00
# CF                            NaN                NaN                  NaN
# CA                            NaN                NaN                  NaN
# CF%                          0.00               0.00                 0.00
# FF                            NaN                NaN                  NaN
# FA                            NaN                NaN                  NaN
# FF%                          0.00               0.00                 0.00
# xGF                          0.00               0.00                 0.00
# xGA                          0.00               0.00                 0.00
# xGF%                         0.00               0.00                 0.00
# SIGNING TEAM                  FLA                EDM                  MTL
# EXTENSION                       ✔                  ✔                    ✔
# SIGNING DATE        Jun. 27, 2022      Jun. 13, 2022         Jun. 6, 2022
# SIGNING AGE                    24                 33                   32
# CLAUSE                       None               None                 None
# LENGTH                          2                  2                    2
# SIGNING                       RFA                UFA                  UFA
# EXPIRY               unrestricted       unrestricted         unrestricted
# EXP. YEAR                    2024               2024                 2024
# AAV                      $762,500           $762,500             $762,500
# HEIGHT_in                      72                 74                   70
#
#                             1552                1557  \
# PLAYER        1553. Taylor Fedun  1558. Matthew Peca
# AGE                           35                  30
# COUNTRY                   Canada              Canada
# WEIGHT                       200                 182
# HEIGHT                       6'1                 5'9
# POS                           RD               LW, C
# HANDED                     Right                Left
# GP                             0                   0
# G                              0                   0
# A                              0                   0
# P                              0                   0
# P/GP                        0.00                0.00
# +/-                            0                   0
# Sh                             0                   0
# Sh%                         0.00                0.00
# TOI                          NaN                 NaN
# ixG                         0.00                0.00
# iSh                            0                   0
# iCF                            0                   0
# iFF                            0                   0
# ixG60                       0.00                0.00
# iSh60                       0.00                0.00
# iCF60                       0.00                0.00
# iFF60                       0.00                0.00
# SF                           NaN                 NaN
# SA                           NaN                 NaN
# SF%                         0.00                0.00
# CF                           NaN                 NaN
# CA                           NaN                 NaN
# CF%                         0.00                0.00
# FF                           NaN                 NaN
# FA                           NaN                 NaN
# FF%                         0.00                0.00
# xGF                         0.00                0.00
# xGA                         0.00                0.00
# xGF%                        0.00                0.00
# SIGNING TEAM                 PIT                 STL
# EXTENSION                      ✔                   ✔
# SIGNING DATE        May 25, 2022       Mar. 23, 2022
# SIGNING AGE                   34                  29
# CLAUSE                      None                None
# LENGTH                         2                   2
# SIGNING                      UFA                 UFA
# EXPIRY              unrestricted        unrestricted
# EXP. YEAR                   2024                2024
# AAV                     $762,500            $762,500
# HEIGHT_in                     73                  69
#
#                                   1558                 1559  \
# PLAYER        1559. Markus Niemeläinen  1560. Kyle Clifford
# AGE                                 25                   32
# COUNTRY                        Finland               Canada
# WEIGHT                             190                  217
# HEIGHT                             6'6                  6'2
# POS                                 LD                   LW
# HANDED                            Left                 Left
# GP                                   0                    0
# G                                    0                    0
# A                                    0                    0
# P                                    0                    0
# P/GP                              0.00                 0.00
# +/-                                  0                    0
# Sh                                   0                    0
# Sh%                               0.00                 0.00
# TOI                                NaN                  NaN
# ixG                               0.00                 0.00
# iSh                                  0                    0
# iCF                                  0                    0
# iFF                                  0                    0
# ixG60                             0.00                 0.00
# iSh60                             0.00                 0.00
# iCF60                             0.00                 0.00
# iFF60                             0.00                 0.00
# SF                                 NaN                  NaN
# SA                                 NaN                  NaN
# SF%                               0.00                 0.00
# CF                                 NaN                  NaN
# CA                                 NaN                  NaN
# CF%                               0.00                 0.00
# FF                                 NaN                  NaN
# FA                                 NaN                  NaN
# FF%                               0.00                 0.00
# xGF                               0.00                 0.00
# xGA                               0.00                 0.00
# xGF%                              0.00                 0.00
# SIGNING TEAM                       EDM                  TOR
# EXTENSION                            ✔                    ✔
# SIGNING DATE             Mar. 10, 2022         Mar. 9, 2022
# SIGNING AGE                         24                   31
# CLAUSE                            None                 None
# LENGTH                               2                    2
# SIGNING                            RFA                  UFA
# EXPIRY                    unrestricted         unrestricted
# EXP. YEAR                         2024                 2024
# AAV                           $762,500             $762,500
# HEIGHT_in                           78                   74
#
#                              1560                 1561
# PLAYER        1561. Billy Sweezey  1562. Seth Griffith
# AGE                            27                   30
# COUNTRY             United States               Canada
# WEIGHT                        205                  191
# HEIGHT                        6'2                  5'9
# POS                            RD                RW, C
# HANDED                      Right                Right
# GP                              0                    0
# G                               0                    0
# A                               0                    0
# P                               0                    0
# P/GP                         0.00                 0.00
# +/-                             0                    0
# Sh                              0                    0
# Sh%                          0.00                 0.00
# TOI                           NaN                  NaN
# ixG                          0.00                 0.00
# iSh                             0                    0
# iCF                             0                    0
# iFF                             0                    0
# ixG60                        0.00                 0.00
# iSh60                        0.00                 0.00
# iCF60                        0.00                 0.00
# iFF60                        0.00                 0.00
# SF                            NaN                  NaN
# SA                            NaN                  NaN
# SF%                          0.00                 0.00
# CF                            NaN                  NaN
# CA                            NaN                  NaN
# CF%                          0.00                 0.00
# FF                            NaN                  NaN
# FA                            NaN                  NaN
# FF%                          0.00                 0.00
# xGF                          0.00                 0.00
# xGA                          0.00                 0.00
# xGF%                         0.00                 0.00
# SIGNING TEAM                  CBJ                  EDM
# EXTENSION                     NaN                    ✔
# SIGNING DATE         Mar. 7, 2022         Mar. 3, 2022
# SIGNING AGE                    26                   29
# CLAUSE                       None                 None
# LENGTH                          2                    2
# SIGNING                       UFA                  UFA
# EXPIRY               unrestricted         unrestricted
# EXP. YEAR                    2024                 2024
# AAV                      $762,500             $762,500
# HEIGHT_in                      74                   69
#
# [47 rows x 479 columns]

# %% [markdown]
# **replace nan integer advanced stats with with 0**
# * the three players with NaN values only played 1 game and all of the other advanced stats are 0
#     *advanced stats are pulled from a seperate company and included in the capfriendly data

# %%
capfriendly.update(capfriendly[['SF', 'SA', 'CF', 'CA', 'FF', 'FA']].fillna(0))
capfriendly[['SF', 'SA', 'CF', 'CA', 'FF', 'FA']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1400 entries, 0 to 1570
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SF      1400 non-null   object
#  1   SA      1400 non-null   object
#  2   CF      1400 non-null   object
#  3   CA      1400 non-null   object
#  4   FF      1400 non-null   object
#  5   FA      1400 non-null   object
# dtypes: object(6)
# memory usage: 76.6+ KB

# %% [markdown]
# **Convert advanced stats to int**

# %%
for i in ['SF', 'SA', 'CF', 'CA', 'FF', 'FA']:
    capfriendly[i] = capfriendly[i].astype('int')

#confirm
capfriendly[['SF', 'SA', 'CF', 'CA', 'FF', 'FA']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1400 entries, 0 to 1570
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SF      1400 non-null   int64
#  1   SA      1400 non-null   int64
#  2   CF      1400 non-null   int64
#  3   CA      1400 non-null   int64
#  4   FF      1400 non-null   int64
#  5   FA      1400 non-null   int64
# dtypes: int64(6)
# memory usage: 76.6 KB

# %% [markdown]
# <h4>Explore AAV

# %%
capfriendly['AAV'].head()
# Out:
# 0    $12,600,000
# 1    $12,500,000
# 2    $11,642,857
# 3    $11,640,250
# 4    $11,500,000
# Name: AAV, dtype: object

# %%
#drop '$' and ',' then convert to int 
capfriendly['AAV'] = capfriendly['AAV'].str.strip("$").str.replace(',', '').astype('int')
capfriendly['AAV'].head()
# Out:
# 0    12600000
# 1    12500000
# 2    11642857
# 3    11640250
# 4    11500000
# Name: AAV, dtype: int64

# %% [markdown]
# <h4>Convert remaining int_modify to int

# %%
capfriendly[to_int].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1400 entries, 0 to 1570
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   AGE        1400 non-null   int64
#  1   WEIGHT     1400 non-null   int64
#  2   HEIGHT_in  1400 non-null   int64
#  3   GP         1400 non-null   int64
#  4   G          1400 non-null   int64
#  5   A          1400 non-null   int64
#  6   P          1400 non-null   int64
#  7   +/-        1400 non-null   int64
#  8   Sh         1400 non-null   int64
#  9   iSh        1400 non-null   int64
#  10  iCF        1400 non-null   int64
#  11  iFF        1400 non-null   int64
#  12  SF         1400 non-null   int64
#  13  SA         1400 non-null   int64
#  14  CF         1400 non-null   int64
#  15  CA         1400 non-null   int64
#  16  FF         1400 non-null   int64
#  17  FA         1400 non-null   int64
#  18  AAV        1400 non-null   int64
# dtypes: int64(19)
# memory usage: 218.8 KB

# %% [markdown]
# <h3><ins>Float<ins>

# %%
#explore
to_float = ['P/GP', 'TOI', 'Sh%', 'ixG', 'ixG60', 'iSh60', 'iCF60', 'iFF60', 'SF%', 'CF%', 'FF%', 'xGF', 'xGA', 'xGF%']
capfriendly[to_float].head()
# Out:
#    P/GP    TOI   Sh%    ixG ixG60  iSh60  iCF60  iFF60    SF%    CF%    FF%  \
# 0  1.71  22:48  0.13  38.35  1.24  13.08  22.34  17.00  62.84  62.82  62.80
# 1  1.74  21:21  0.12  34.08  1.26   9.72  16.71  13.08  63.63  64.40  64.17
# 2  1.46  20:07  0.16  32.07  1.17  11.02  23.68  15.68  62.15  64.16  63.58
# 3  1.32  20:57  0.19  50.16  1.77  13.00  24.52  18.87  62.61  60.33  61.57
# 4  0.68  24:16  0.05  12.27  0.37   6.45  16.57   9.38  59.44  59.79  58.01
#
#       xGF    xGA   xGF%
# 0  154.32  83.13  64.98
# 1  157.57  74.52  67.89
# 2  143.38  77.31  64.97
# 3  147.28  80.43  64.68
# 4  156.87  99.90  61.09

# %%
capfriendly[to_float].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1400 entries, 0 to 1570
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   P/GP    1400 non-null   object
#  1   TOI     924 non-null    object
#  2   Sh%     1400 non-null   object
#  3   ixG     1400 non-null   object
#  4   ixG60   1400 non-null   object
#  5   iSh60   1400 non-null   object
#  6   iCF60   1400 non-null   object
#  7   iFF60   1400 non-null   object
#  8   SF%     1400 non-null   object
#  9   CF%     1400 non-null   object
#  10  FF%     1400 non-null   object
#  11  xGF     1400 non-null   object
#  12  xGA     1400 non-null   object
#  13  xGF%    1400 non-null   object
# dtypes: object(14)
# memory usage: 164.1+ KB

# %% [markdown]
# <h4>Explore 'TOI' - Average Time On Ice per game

# %% [markdown]
# * capfriendly includes all players with a contract whereas NHL official data is only for players that have played during the season
# * a NaN number in capfriendly['TOI'] means the player has not played in the NHL during the season

# %%
#check if length of nhl equal to length of capfriendly with no nan
f"len(nhl) == sum(capfriendly['TOI'].notna()): {len(nhl) == sum(capfriendly['TOI'].notna())}"
# Out:
# "len(nhl) == sum(capfriendly['TOI'].notna()): True"

# %% [markdown]
# **drop players who didn't play in the NHL during the season: drop nan**

# %%
#drop nan in TOI
capfriendly = capfriendly.dropna(subset=['TOI']).reset_index(drop=True)
capfriendly
# Out:
#                       PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS  \
# 0        1. Nathan MacKinnon   27         Canada     200    6'0       C
# 1          2. Connor McDavid   26         Canada     193    6'1       C
# 2          3. Artemi Panarin   31         Russia     170   5'11      LW
# 3         4. Auston Matthews   25  United States     215    6'3       C
# 4           5. Erik Karlsson   33         Sweden     190    6'0      RD
# ..                       ...  ...            ...     ...    ...     ...
# 919    1566. Jalen Chatfield   27  United States     188    6'1      RD
# 920       1567. Parker Kelly   24         Canada     188    6'0      LW
# 921     1569. Boris Katchouk   25         Canada     179    6'1      LW
# 922     1570. Taylor Raddysh   25         Canada     198    6'2      RW
# 923  1571. Alex Barré-Boulet   26         Canada     168    5'9  RW, LW
#
#     HANDED  GP   G    A  ...  EXTENSION   SIGNING DATE  SIGNING AGE  CLAUSE  \
# 0    Right  82  51   89  ...          ✔  Sep. 20, 2022           27     NMC
# 1     Left  76  32  100  ...          ✔   Jul. 5, 2017           21     NMC
# 2    Right  82  49   71  ...        NaN   Jul. 1, 2019           27     NMC
# 3     Left  81  69   38  ...          ✔   Feb. 5, 2019           21     NMC
# 4    Right  82  11   45  ...          ✔  Jun. 17, 2019           29     NMC
# ..     ...  ..  ..  ...  ...        ...            ...          ...     ...
# 919  Right  72   8   14  ...          ✔  Jan. 21, 2022           26    None
# 920   Left  80   8   10  ...          ✔  Oct. 12, 2021           23    None
# 921   Left  59   7    6  ...        NaN  Jul. 31, 2021           23    None
# 922  Right  73   5    9  ...        NaN  Jul. 30, 2021           23    None
# 923   Left  36   6    3  ...        NaN  Jul. 30, 2021           24    None
#
#     LENGTH SIGNING        EXPIRY  EXP. YEAR       AAV  HEIGHT_in
# 0        8     UFA  unrestricted       2031  12600000         72
# 1        8     RFA  unrestricted       2026  12500000         73
# 2        7     UFA  unrestricted       2026  11642857         71
# 3        5     RFA  unrestricted       2024  11640250         75
# 4        8     UFA  unrestricted       2027  11500000         72
# ..     ...     ...           ...        ...       ...        ...
# 919      2     RFA  unrestricted       2024    762500         73
# 920      2     RFA  unrestricted       2024    762500         72
# 921      3     RFA  unrestricted       2024    758333         73
# 922      3     RFA  unrestricted       2024    758333         74
# 923      3     RFA  unrestricted       2024    758333         69
#
# [924 rows x 47 columns]

# %%
capfriendly
#confirm
#f"nhl: {len(nhl)} capfrienly: {len(capfriendly)}"
# Out:
#                       PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS  \
# 0        1. Nathan MacKinnon   27         Canada     200    6'0       C
# 1          2. Connor McDavid   26         Canada     193    6'1       C
# 2          3. Artemi Panarin   31         Russia     170   5'11      LW
# 3         4. Auston Matthews   25  United States     215    6'3       C
# 4           5. Erik Karlsson   33         Sweden     190    6'0      RD
# ..                       ...  ...            ...     ...    ...     ...
# 919    1566. Jalen Chatfield   27  United States     188    6'1      RD
# 920       1567. Parker Kelly   24         Canada     188    6'0      LW
# 921     1569. Boris Katchouk   25         Canada     179    6'1      LW
# 922     1570. Taylor Raddysh   25         Canada     198    6'2      RW
# 923  1571. Alex Barré-Boulet   26         Canada     168    5'9  RW, LW
#
#     HANDED  GP   G    A  ...  EXTENSION   SIGNING DATE  SIGNING AGE  CLAUSE  \
# 0    Right  82  51   89  ...          ✔  Sep. 20, 2022           27     NMC
# 1     Left  76  32  100  ...          ✔   Jul. 5, 2017           21     NMC
# 2    Right  82  49   71  ...        NaN   Jul. 1, 2019           27     NMC
# 3     Left  81  69   38  ...          ✔   Feb. 5, 2019           21     NMC
# 4    Right  82  11   45  ...          ✔  Jun. 17, 2019           29     NMC
# ..     ...  ..  ..  ...  ...        ...            ...          ...     ...
# 919  Right  72   8   14  ...          ✔  Jan. 21, 2022           26    None
# 920   Left  80   8   10  ...          ✔  Oct. 12, 2021           23    None
# 921   Left  59   7    6  ...        NaN  Jul. 31, 2021           23    None
# 922  Right  73   5    9  ...        NaN  Jul. 30, 2021           23    None
# 923   Left  36   6    3  ...        NaN  Jul. 30, 2021           24    None
#
#     LENGTH SIGNING        EXPIRY  EXP. YEAR       AAV  HEIGHT_in
# 0        8     UFA  unrestricted       2031  12600000         72
# 1        8     RFA  unrestricted       2026  12500000         73
# 2        7     UFA  unrestricted       2026  11642857         71
# 3        5     RFA  unrestricted       2024  11640250         75
# 4        8     UFA  unrestricted       2027  11500000         72
# ..     ...     ...           ...        ...       ...        ...
# 919      2     RFA  unrestricted       2024    762500         73
# 920      2     RFA  unrestricted       2024    762500         72
# 921      3     RFA  unrestricted       2024    758333         73
# 922      3     RFA  unrestricted       2024    758333         74
# 923      3     RFA  unrestricted       2024    758333         69
#
# [924 rows x 47 columns]

# %% [markdown]
# **convert TOI from MM:SS to minutes as float**

# %%
capfriendly['TOI'][0]
# Out:
# '22:48'

# %%
22+48/60
# Out:
# 22.8

# %%
capfriendly['TOI_min']=capfriendly.TOI.str.split(":").str[0].astype(float) + (capfriendly.TOI.str.split(":").str[1].astype(float)/60)

capfriendly['TOI_min'].head()
# Out:
# 0    22.800000
# 1    21.350000
# 2    20.116667
# 3    20.950000
# 4    24.266667
# Name: TOI_min, dtype: float64

# %% [markdown]
# <h4>Convert to_float to float

# %%
#swap TOI with TOI_min
to_float_mod = ['P/GP', 'TOI_min', 'Sh%', 'ixG', 'ixG60', 'iSh60', 'iCF60', 'iFF60', 'SF%', 'CF%', 'FF%', 'xGF', 'xGA', 'xGF%']

# %%
# convert to float and round to 2 decimal places
capfriendly[to_float_mod] = round(capfriendly[to_float_mod].astype(float),2)
capfriendly[to_float_mod].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 924 entries, 0 to 923
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   P/GP     924 non-null    float64
#  1   TOI_min  924 non-null    float64
#  2   Sh%      924 non-null    float64
#  3   ixG      924 non-null    float64
#  4   ixG60    924 non-null    float64
#  5   iSh60    924 non-null    float64
#  6   iCF60    924 non-null    float64
#  7   iFF60    924 non-null    float64
#  8   SF%      924 non-null    float64
#  9   CF%      924 non-null    float64
#  10  FF%      924 non-null    float64
#  11  xGF      924 non-null    float64
#  12  xGA      924 non-null    float64
#  13  xGF%     924 non-null    float64
# dtypes: float64(14)
# memory usage: 101.2 KB

# %% [markdown]
# <h3><ins>Boolean<ins>

# %% [markdown]
# <h4> Explore 'EXTENSION'

# %% [markdown]
# * 'EXTENSION' represents whether the current contract was signed as an extention with signing team
#     * Contracts signed as an extension have different regulations than those signed as a free agent.  The biggest difference is 'LENGTH' can be 8 years for an extension vs 7 years for a free agent.
#     * '✔' will be replaced with 'True' and nan will be replaced with 'False'

# %%
capfriendly['EXTENSION'].value_counts()
# Out:
# EXTENSION
# ✔    320
# Name: count, dtype: int64

# %%
capfriendly['EXTENSION'].head()
# Out:
# 0      ✔
# 1      ✔
# 2    NaN
# 3      ✔
# 4      ✔
# Name: EXTENSION, dtype: object

# %% [markdown]
# **Replace '✔' with True and nan with False**

# %%
#replace
capfriendly.loc[~capfriendly['EXTENSION'].isna(),'EXTENSION'] = True
capfriendly.loc[capfriendly['EXTENSION'].isna(),'EXTENSION'] = False

#check
capfriendly['EXTENSION'].value_counts()
# Out:
# EXTENSION
# False    604
# True     320
# Name: count, dtype: int64

# %%
capfriendly['EXTENSION'].head()
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# Name: EXTENSION, dtype: object

# %% [markdown]
# <h3><ins>Datetime<ins>

# %% [markdown]
# <h4>Explore 'SIGNING DATE'

# %%
capfriendly['SIGNING DATE'].head()
# Out:
# 0    Sep. 20, 2022
# 1     Jul. 5, 2017
# 2     Jul. 1, 2019
# 3     Feb. 5, 2019
# 4    Jun. 17, 2019
# Name: SIGNING DATE, dtype: object

# %%
capfriendly['SIGNING DATE'].describe()
# Out:
# count              924
# unique             479
# top       Jul. 1, 2023
# freq               104
# Name: SIGNING DATE, dtype: object

# %%
#remove '.' from signing date before converting to datetime
capfriendly['SIGNING DATE'] = capfriendly['SIGNING DATE'].str.replace('.', '')

# %%
# convert to datetime using pd.to_datetime with predefined format
capfriendly['SIGNING DATE'] = pd.to_datetime(capfriendly['SIGNING DATE'], format='%b %d, %Y')
capfriendly['SIGNING DATE'].head()
# Out:
# 0   2022-09-20
# 1   2017-07-05
# 2   2019-07-01
# 3   2019-02-05
# 4   2019-06-17
# Name: SIGNING DATE, dtype: datetime64[ns]

# %%
capfriendly['SIGNING DATE']
# Out:
# 0     2022-09-20
# 1     2017-07-05
# 2     2019-07-01
# 3     2019-02-05
# 4     2019-06-17
#          ...
# 919   2022-01-21
# 920   2021-10-12
# 921   2021-07-31
# 922   2021-07-30
# 923   2021-07-30
# Name: SIGNING DATE, Length: 924, dtype: datetime64[ns]

# %% [markdown]
# <h3><ins>String data<ins>

# %% [markdown]
# <h4>Remove list numbering from name in 'PLAYER'

# %%
capfriendly['PLAYER'].head()
# Out:
# 0    1. Nathan MacKinnon
# 1      2. Connor McDavid
# 2      3. Artemi Panarin
# 3     4. Auston Matthews
# 4       5. Erik Karlsson
# Name: PLAYER, dtype: object

# %%
capfriendly['PLAYER']=capfriendly['PLAYER'].str.lstrip('1234567890.')
capfriendly['PLAYER']=capfriendly['PLAYER'].astype('str')
capfriendly['PLAYER']
# Out:
# 0        Nathan MacKinnon
# 1          Connor McDavid
# 2          Artemi Panarin
# 3         Auston Matthews
# 4           Erik Karlsson
#               ...
# 919       Jalen Chatfield
# 920          Parker Kelly
# 921        Boris Katchouk
# 922        Taylor Raddysh
# 923     Alex Barré-Boulet
# Name: PLAYER, Length: 924, dtype: object

# %% [markdown]
# **Remove white spaces**

# %%
capfriendly['PLAYER'] = capfriendly['PLAYER'].str.strip()

# %%
# count of players names
capfriendly['PLAYER'].value_counts()
# Out:
# PLAYER
# Corey Perry          2
# Sebastian Aho        2
# Nathan MacKinnon     1
# Tyson Foerster       1
# Jayden Struble       1
#                     ..
# Scott Laughton       1
# Dylan DeMelo         1
# Mathieu Joseph       1
# Alex Newhook         1
# Alex Barré-Boulet    1
# Name: count, Length: 922, dtype: int64

# %% [markdown]
# **Show Duplicated players**
# * There are two players named 'Sebastian Aho'.  One is a Defenseman for NYI and the other is a Center for CAR
# * Corey Perry had his contract terminated early in the season (CHI for 16 games) and signed with a different team later in the same season (EDM for 38 games)

# %%
players= capfriendly['PLAYER']
capfriendly[players.isin(players[players.duplicated()])].sort_values('PLAYER')
# Out:
#             PLAYER  AGE  COUNTRY  WEIGHT HEIGHT POS HANDED  GP   G   A  ...  \
# 243    Corey Perry   38   Canada     205    6'3  RW  Right  54  12  10  ...
# 759    Corey Perry   38   Canada     205    6'3  RW  Right  54  12  10  ...
# 46   Sebastian Aho   25  Finland     176    6'0   C   Left  78  36  53  ...
# 694  Sebastian Aho   27   Sweden     176   5'10  LD   Left  58   2   7  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 243    2023-06-30           38    None       1      UFA  unrestricted
# 759    2024-01-22           38    None       1      UFA  unrestricted
# 46     2019-07-01           21    None       5      RFA  unrestricted
# 694    2022-07-09           26    None       2      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 243       2024  4000000         75    13.37
# 759       2024  1100000         75    13.37
# 46        2024  8460250         72    19.62
# 694       2024   825000         70    16.38
#
# [4 rows x 48 columns]

# %% [markdown]
# **'Corey Perry' duplicate**
# * Corey Perry had his contract terminated early in the season (CHI for 16 games) and signed with a different team later in the same season (EDM for 38 games)

# %%
capfriendly[players.isin(['Corey Perry'])].T
# Out:
#                               243                  759
# PLAYER                Corey Perry          Corey Perry
# AGE                            38                   38
# COUNTRY                    Canada               Canada
# WEIGHT                        205                  205
# HEIGHT                        6'3                  6'3
# POS                            RW                   RW
# HANDED                      Right                Right
# GP                             54                   54
# G                              12                   12
# A                              10                   10
# P                              22                   22
# P/GP                         0.41                 0.41
# +/-                            -6                   -6
# Sh                             82                   82
# Sh%                          0.15                 0.15
# TOI                         13:22                13:22
# ixG                         13.56                13.56
# iSh                            82                   82
# iCF                           143                  143
# iFF                           120                  120
# ixG60                        1.14                 1.14
# iSh60                        6.97                 6.97
# iCF60                       12.15                12.15
# iFF60                       10.19                10.19
# SF                            347                  347
# SA                            308                  308
# SF%                         52.98                52.98
# CF                            730                  730
# CA                            597                  597
# CF%                         55.01                55.01
# FF                            510                  510
# FA                            452                  452
# FF%                         53.01                53.01
# xGF                         42.14                42.14
# xGA                         29.57                29.57
# xGF%                        58.76                58.76
# SIGNING TEAM                  CHI                  EDM
# EXTENSION                    True                False
# SIGNING DATE  2023-06-30 00:00:00  2024-01-22 00:00:00
# SIGNING AGE                    38                   38
# CLAUSE                       None                 None
# LENGTH                          1                    1
# SIGNING                       UFA                  UFA
# EXPIRY               unrestricted         unrestricted
# EXP. YEAR                    2024                 2024
# AAV                       4000000              1100000
# HEIGHT_in                      75                   75
# TOI_min                     13.37                13.37

# %% [markdown]
# **Drop duplicate**
# Based on knowledge of Corey Perry's previous contracts and the value of the contract he signed with EDM for the 2024-25 season, I will drop the duplicate at index 243 representing his first contract with CHI.

# %%
#confirm index
capfriendly.iloc[[243]]
# Out:
#           PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP   G   A  ...  \
# 243  Corey Perry   38  Canada     205    6'3  RW  Right  54  12  10  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 243    2023-06-30           38    None       1      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 243       2024  4000000         75    13.37
#
# [1 rows x 48 columns]

# %%
#Drop row  inplace
capfriendly.drop(243, inplace=True)

# %%
#reset index
capfriendly.reset_index(drop=True, inplace=True)

# %%
#confirm
capfriendly.iloc[[243]]
# Out:
#            PLAYER  AGE        COUNTRY  WEIGHT HEIGHT        POS HANDED  GP  \
# 243  Nick Foligno   35  United States     208    6'0  LW, C, RW   Left  74
#
#       G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 243  17  20  ...    2023-06-27           35    None       1      UFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 243  unrestricted       2024  4000000         72    17.75
#
# [1 rows x 48 columns]

# %% [markdown]
# **'Sebastian Aho' duplicate**
# * There are two players named 'Sebastian Aho'.  One is a Defenseman for NYI and the other is a Center for CAR

# %%
capfriendly[capfriendly['PLAYER']=='Sebastian Aho']
# Out:
#             PLAYER  AGE  COUNTRY  WEIGHT HEIGHT POS HANDED  GP   G   A  ...  \
# 46   Sebastian Aho   25  Finland     176    6'0   C   Left  78  36  53  ...
# 693  Sebastian Aho   27   Sweden     176   5'10  LD   Left  58   2   7  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 46     2019-07-01           21    None       5      RFA  unrestricted
# 693    2022-07-09           26    None       2      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 46        2024  8460250         72    19.62
# 693       2024   825000         70    16.38
#
# [2 rows x 48 columns]

# %%
#Modify name of Sebastian Aho who plays center
capfriendly.iloc[[46],[0]] = 'Sebastian Aho (C)'
capfriendly.iloc[[46],[0]]
# Out:
#                PLAYER
# 46  Sebastian Aho (C)

# %%
#Modify name of Sebastian Aho who plays dedense
capfriendly.iloc[[693],[0]] = 'Sebastian Aho (D)'
capfriendly.iloc[[693],[0]]
# Out:
#                 PLAYER
# 693  Sebastian Aho (D)

# %%
#confirm
capfriendly[capfriendly['PLAYER'].str.contains('Sebastian Aho')]
# Out:
#                 PLAYER  AGE  COUNTRY  WEIGHT HEIGHT POS HANDED  GP   G   A  \
# 46   Sebastian Aho (C)   25  Finland     176    6'0   C   Left  78  36  53
# 693  Sebastian Aho (D)   27   Sweden     176   5'10  LD   Left  58   2   7
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 46   ...    2019-07-01           21    None       5      RFA  unrestricted
# 693  ...    2022-07-09           26    None       2      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 46        2024  8460250         72    19.62
# 693       2024   825000         70    16.38
#
# [2 rows x 48 columns]

# %%
#follow up note
nhl_follow_up =[{'Player':'ensure change to Sebastian Aho (C) or Sebastian Aho (D)'}]

# %%
#follow up note
capfriendly_follow_up.append({'PLAYER': 'revisit to change player names after cleaning NHL official data'})

# %% [markdown]
# <H3>Verify all dtype changes and create list of new columns

# %%
#verify dtype
capfriendly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 923 entries, 0 to 922
# Data columns (total 48 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PLAYER        923 non-null    object
#  1   AGE           923 non-null    int64
#  2   COUNTRY       923 non-null    category
#  3   WEIGHT        923 non-null    int64
#  4   HEIGHT        923 non-null    object
#  5   POS           923 non-null    object
#  6   HANDED        923 non-null    category
#  7   GP            923 non-null    int64
#  8   G             923 non-null    int64
#  9   A             923 non-null    int64
#  10  P             923 non-null    int64
#  11  P/GP          923 non-null    float64
#  12  +/-           923 non-null    int64
#  13  Sh            923 non-null    int64
#  14  Sh%           923 non-null    float64
#  15  TOI           923 non-null    object
#  16  ixG           923 non-null    float64
#  17  iSh           923 non-null    int64
#  18  iCF           923 non-null    int64
#  19  iFF           923 non-null    int64
#  20  ixG60         923 non-null    float64
#  21  iSh60         923 non-null    float64
#  22  iCF60         923 non-null    float64
#  23  iFF60         923 non-null    float64
#  24  SF            923 non-null    int64
#  25  SA            923 non-null    int64
#  26  SF%           923 non-null    float64
#  27  CF            923 non-null    int64
#  28  CA            923 non-null    int64
#  29  CF%           923 non-null    float64
#  30  FF            923 non-null    int64
#  31  FA            923 non-null    int64
#  32  FF%           923 non-null    float64
#  33  xGF           923 non-null    float64
#  34  xGA           923 non-null    float64
#  35  xGF%          923 non-null    float64
#  36  SIGNING TEAM  923 non-null    category
#  37  EXTENSION     923 non-null    object
#  38  SIGNING DATE  923 non-null    datetime64[ns]
#  39  SIGNING AGE   923 non-null    int64
#  40  CLAUSE        923 non-null    category
#  41  LENGTH        923 non-null    int64
#  42  SIGNING       923 non-null    category
#  43  EXPIRY        923 non-null    category
#  44  EXP. YEAR     923 non-null    int64
#  45  AAV           923 non-null    int64
#  46  HEIGHT_in     923 non-null    int64
#  47  TOI_min       923 non-null    float64
# dtypes: category(6), datetime64[ns](1), float64(14), int64(22), object(5)
# memory usage: 310.5+ KB

# %%
#compare columns to capfriendly_orig_columns_after_drop
capfriendly.columns.isin(capfriendly_orig_columns_after_drop)
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False, False])

# %% [markdown]
# **Update column list in order to subset cleaned data**

# %%
#replace 'HEIGHT' and 'TOI' with new versions in cleaned column list
"""I cant imaging this is the most efficient method for this but I realized i made a mistake early in my code.
I've updated the earlier code but I'm leaving this here for now because it works and will update it at a leter time"""
#clone
capfriendly_clean_columns = []
i=0
while i<len(capfriendly_orig_columns_after_drop):
    
    capfriendly_clean_columns.append(capfriendly_orig_columns_after_drop[i])
    i+=1 

#replace
for x in range(len(capfriendly_clean_columns)):
    
    if capfriendly_clean_columns[x]=='HEIGHT':
        capfriendly_clean_columns[x]='HEIGHT_in'
    
    if capfriendly_clean_columns[x]=='TOI':
        capfriendly_clean_columns[x]='TOI_min'

# %%
#verify
capfriendly_clean_columns
# Out:
# ['PLAYER',
#  'AGE',
#  'COUNTRY',
#  'WEIGHT',
#  'HEIGHT_in',
#  'POS',
#  'HANDED',
#  'GP',
#  'G',
#  'A',
#  'P',
#  'P/GP',
#  '+/-',
#  'Sh',
#  'Sh%',
#  'TOI_min',
#  'ixG',
#  'iSh',
#  'iCF',
#  'iFF',
#  'ixG60',
#  'iSh60',
#  'iCF60',
#  'iFF60',
#  'SF',
#  'SA',
#  'SF%',
#  'CF',
#  'CA',
#  'CF%',
#  'FF',
#  'FA',
#  'FF%',
#  'xGF',
#  'xGA',
#  'xGF%',
#  'SIGNING TEAM',
#  'EXTENSION',
#  'SIGNING DATE',
#  'SIGNING AGE',
#  'CLAUSE',
#  'LENGTH',
#  'SIGNING',
#  'EXPIRY',
#  'EXP. YEAR',
#  'AAV']

# %%
#FOLLOW UP NOTE
capfriendly_follow_up.append({'capfriendly_clean_columns': 'create cleaned df after fixing player data to match nhl data'})

# %%
capfriendly_follow_up
# Out:
# [{'POS': 'drop after join?  too many positions'},
#  {'PLAYER': 'revisit to change player names after cleaning NHL official data'},
#  {'capfriendly_clean_columns': 'create cleaned df after fixing player data to match nhl data'}]

# %% [markdown]
# <h2>Explore nhl.com data

# %%
nhl.shape
# Out:
# (924, 24)

# %%
nhl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 924 entries, 0 to 923
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  924 non-null    object
#  1   Season  924 non-null    int64
#  2   Team    924 non-null    object
#  3   S/C     924 non-null    object
#  4   Pos     924 non-null    object
#  5   GP      924 non-null    int64
#  6   G       924 non-null    int64
#  7   A       924 non-null    int64
#  8   P       924 non-null    int64
#  9   +/-     924 non-null    int64
#  10  PIM     924 non-null    int64
#  11  P/GP    924 non-null    float64
#  12  EVG     924 non-null    int64
#  13  EVP     924 non-null    int64
#  14  PPG     924 non-null    int64
#  15  PPP     924 non-null    int64
#  16  SHG     924 non-null    int64
#  17  SHP     924 non-null    int64
#  18  OTG     924 non-null    int64
#  19  GWG     924 non-null    int64
#  20  S       924 non-null    int64
#  21  S%      924 non-null    object
#  22  TOI/GP  924 non-null    object
#  23  FOW%    924 non-null    object
# dtypes: float64(1), int64(16), object(7)
# memory usage: 173.4+ KB

# %%
#save origional columns to list
nhl_orig_columns = nhl.columns.tolist()

# %% [markdown]
# <h3> Explore 'Player'

# %%
# remove whitespace
nhl['Player'] = nhl['Player'].str.strip()

# %%
nhl['Player'].value_counts()
# Out:
# Player
# Sebastian Aho      2
# Mikael Backlund    1
# Jacob Bryson       1
# William Carrier    1
# Matt Martin        1
#                   ..
# Rasmus Kupari      1
# Jan Jenik          1
# Ruslan Iskhakov    1
# Jack St. Ivany     1
# Patrik Koch        1
# Name: count, Length: 923, dtype: int64

# %% [markdown]
# <h4>Update Sebastian Aho to C or D

# %%
nhl[nhl.Player.str.contains('Sebastian Aho')]
# Out:
#             Player    Season Team S/C Pos  GP   G   A   P  +/-  ...  PPG  PPP  \
# 798  Sebastian Aho  20232024  NYI   L   D  58   2   7   9   -7  ...    0    2
# 817  Sebastian Aho  20232024  CAR   L   C  78  36  53  89   34  ...   11   32
#
#      SHG  SHP  OTG  GWG    S    S%  TOI/GP  FOW%
# 798    0    0    0    0   48   4.2   16:23    --
# 817    1    2    2   10  216  16.7   19:38  54.1
#
# [2 rows x 24 columns]

# %%
#Modify name of Sebastian Aho who plays defense
nhl.iloc[[798],[0]] = 'Sebastian Aho (D)'
nhl.iloc[[798],[0]]
# Out:
#                 Player
# 798  Sebastian Aho (D)

# %%
#Modify name of Sebastian Aho who plays center
nhl.iloc[[817],[0]] = 'Sebastian Aho (C)'

nhl.iloc[[817],[0]]
# Out:
#                 Player
# 817  Sebastian Aho (C)

# %%
#confirm
nhl[nhl.Player.str.contains('Sebastian Aho')]
# Out:
#                 Player    Season Team S/C Pos  GP   G   A   P  +/-  ...  PPG  \
# 798  Sebastian Aho (D)  20232024  NYI   L   D  58   2   7   9   -7  ...    0
# 817  Sebastian Aho (C)  20232024  CAR   L   C  78  36  53  89   34  ...   11
#
#      PPP  SHG  SHP  OTG  GWG    S    S%  TOI/GP  FOW%
# 798    2    0    0    0    0   48   4.2   16:23    --
# 817   32    1    2    2   10  216  16.7   19:38  54.1
#
# [2 rows x 24 columns]

# %% [markdown]
# <h4>Create list of names in nhl['Player'] and capfriendly['PLAYER'] to compare later

# %%
capfriendly['PLAYER'].sort_values()
# Out:
# 900             AJ Greer
# 77          Aaron Ekblad
# 581         Adam Beckman
# 336         Adam Boqvist
# 664         Adam Edström
#              ...
# 712      Zachary Sanford
# 15      Zachary Werenski
# 797         Zack MacEwen
# 694       Zack Ostapchuk
# 341    Zemgus Girgensons
# Name: PLAYER, Length: 923, dtype: object

# %%
nhl_player_names = nhl['Player'].sort_values()
capfriendly_player_names = capfriendly['PLAYER'].sort_values()

# %% [markdown]
# <h3>'Season' - dropped

# %% [markdown]
# * all data is from the 2023-24 season. This is an unnecessary column.

# %%
#drop
nhl.drop(columns='Season', inplace = True)

# %%
#confirm and save nhl_columns_after_drop
nhl_columns_after_drop = nhl.columns.tolist()
nhl_columns_after_drop
# Out:
# ['Player',
#  'Team',
#  'S/C',
#  'Pos',
#  'GP',
#  'G',
#  'A',
#  'P',
#  '+/-',
#  'PIM',
#  'P/GP',
#  'EVG',
#  'EVP',
#  'PPG',
#  'PPP',
#  'SHG',
#  'SHP',
#  'OTG',
#  'GWG',
#  'S',
#  'S%',
#  'TOI/GP',
#  'FOW%']

# %% [markdown]
# <h3> 'Team' to category and split

# %%
nhl.Team.unique()
# Out:
# array(['CGY', 'PHI', 'FLA', 'ANA', 'STL', 'WPG', 'SJS,VGK', 'BOS', 'OTT',
#        'NYI', 'CHI', 'PIT', 'SEA', 'CAR', 'VAN', 'CBJ', 'WSH', 'ARI',
#        'NJD', 'NSH', 'TOR', 'COL', 'MTL', 'DET', 'TBL', 'BUF', 'VGK',
#        'ARI,NSH', 'EDM', 'CBJ,NYR', 'NYR', 'MIN', 'SEA,NYR', 'COL,BUF',
#        'PHI,COL', 'LAK', 'BUF,COL', 'NJD,WPG', 'OTT,FLA', 'CAR,PIT',
#        'DAL', 'ANA,EDM', 'CGY,VGK', 'VAN,CGY', 'SJS', 'WSH,VGK',
#        'CGY,VAN', 'SJS,TBL', 'MIN,TOR', 'CGY,DAL', 'NSH,COL',
#        'VAN,CHI,NSH', 'MIN,SJS', 'CBJ,PIT', 'MIN,BOS', 'PIT,CBJ',
#        'DET,SJS', 'STL,NYI', 'PIT,MTL', 'LAK,VGK,FLA', 'TBL,SJS',
#        'PIT,NYR', 'LAK,NSH', 'TOR,ANA', 'COL,NJD', 'COL,ANA', 'CBJ,NSH',
#        'NSH,PHI', 'VAN,SJS', 'NSH,LAK', 'COL,SEA', 'WSH,CAR', 'FLA,NYI',
#        'CHI,EDM', 'BUF,FLA', 'SJS,CGY', 'ANA,TOR', 'VGK,CGY', 'CGY,NJD',
#        'ARI,EDM', 'BUF,PHI', 'WSH,TOR', 'ARI,CHI', 'DAL,CGY',
#        'WSH,PIT,WSH', 'TBL,MIN', 'CHI,OTT', 'MIN,COL', 'ARI,TBL',
#        'MTL,ANA', 'CBJ,BUF', 'ANA,PHI', 'CBJ,BOS', 'CGY,ARI', 'WPG,MIN',
#        'PIT,CAR', 'MTL,WPG'], dtype=object)

# %% [markdown]
# <h4>explore value counts of 'Team"

# %%
nhl['Team'].value_counts()
# Out:
# Team
# CHI        31
# CBJ        31
# SEA        30
# ARI        30
# BOS        30
#            ..
# TBL,SJS     1
# PIT,NYR     1
# LAK,NSH     1
# TOR,ANA     1
# MTL,WPG     1
# Name: count, Length: 97, dtype: int64

# %%
# 23 is the roster size for a NHL team. Anything less will represent players with multiple teams
value_counts = nhl['Team'].value_counts()
value_counts[value_counts < 23]
# Out:
# Team
# CGY,VAN    2
# NJD,WPG    2
# VGK,CGY    2
# ANA,EDM    2
# WSH,TOR    1
#           ..
# TBL,SJS    1
# PIT,NYR    1
# LAK,NSH    1
# TOR,ANA    1
# MTL,WPG    1
# Name: count, Length: 65, dtype: int64

# %%
#find number of players with multiple teams
value_counts[value_counts < 23].sum()
# Out:
# 69

# %%
#calculate percentage of trades before halfway mark of season
40/59
# Out:
# 0.6779661016949152

# %% [markdown]
# * Players who were traded in the season and played a game with both teams will have multiple teams. Same is true for players aquired via wavers.
# NHL official trades of 23-24 season: https://www.nhl.com/news/2023-24-nhl-trades-344953916
#     * there were 60 trades during the season, often involving multiple players.
#     * 40 of the 59 (~70%) trades occured within a 3 days of the trade deadline which represents aproximately the 70% mark of the season.
#
# **Given that the vast majority of trades occured near the deadline, the team the player started the season with should be given more weight.  But, I will break them out into first team and last team for cases with more then 1 team. Players with only one team will have the same team for both start and end.**

# %% [markdown]
# **'Team_start'**

# %%
#add 'Team_start' based on the team the player started the season with (first team listed)
nhl['Team_start'] = nhl['Team'].str.split(',').str.get(0)
nhl
nhl['Team_start'].head()
# Out:
# 0    CGY
# 1    PHI
# 2    FLA
# 3    FLA
# 4    CGY
# Name: Team_start, dtype: object

# %%
#confirm
value_counts_start = nhl['Team_start'].value_counts()
value_counts_start[value_counts_start < 23]
# Out:
# Series([], Name: count, dtype: int64)

# %%
#strip whitespace and convert to category
nhl['Team_start'] = nhl['Team_start'].str.strip().astype('category')
nhl['Team_start'].unique()
# Out:
# ['CGY', 'PHI', 'FLA', 'ANA', 'STL', ..., 'EDM', 'NYR', 'MIN', 'LAK', 'DAL']
# Length: 32
# Categories (32, object): ['ANA', 'ARI', 'BOS', 'BUF', ..., 'VAN', 'VGK', 'WPG', 'WSH']

# %% [markdown]
# **'Team_end'**

# %%
#add 'Team_start' based on the team the player started the season with (first team listed)
nhl['Team_end'] = nhl['Team'].str.split(',').str.get(-1)
nhl['Team_end'].head()
# Out:
# 0    CGY
# 1    PHI
# 2    FLA
# 3    FLA
# 4    CGY
# Name: Team_end, dtype: object

# %%
#confirm
value_counts_start = nhl['Team_end'].value_counts()
value_counts_start[value_counts_start < 23]
# Out:
# Series([], Name: count, dtype: int64)

# %%
#strip whitespace and convert to category
nhl['Team_end'] = nhl['Team_end'].str.strip().astype('category')
nhl['Team_end'].unique()
# Out:
# ['CGY', 'PHI', 'FLA', 'ANA', 'STL', ..., 'NYR', 'MIN', 'LAK', 'DAL', 'SJS']
# Length: 32
# Categories (32, object): ['ANA', 'ARI', 'BOS', 'BUF', ..., 'VAN', 'VGK', 'WPG', 'WSH']

# %% [markdown]
# <h3> 'S/C' - Player Shoots / Goalie Catches - rename and to category

# %%
nhl['S/C'].unique()
# Out:
# array(['L', 'R'], dtype=object)

# %%
nhl['S/C'].value_counts()
# Out:
# S/C
# L    570
# R    354
# Name: count, dtype: int64

# %% [markdown]
# **Rename from 'SC' to 'Shoots'**
# * rename for clarity and because there is no goalie data to consider

# %%
nhl= nhl.rename(columns={'S/C':'Shoots'})
nhl.columns
# Out:
# Index(['Player', 'Team', 'Shoots', 'Pos', 'GP', 'G', 'A', 'P', '+/-', 'PIM',
#        'P/GP', 'EVG', 'EVP', 'PPG', 'PPP', 'SHG', 'SHP', 'OTG', 'GWG', 'S',
#        'S%', 'TOI/GP', 'FOW%', 'Team_start', 'Team_end'],
#       dtype='object')

# %%
#strip whitespace and convert to category
nhl['Shoots'] = nhl['Shoots'].str.strip().astype('category')

# %%
#confirm
nhl.Shoots.unique()
# Out:
# ['L', 'R']
# Categories (2, object): ['L', 'R']

# %% [markdown]
# <h3>'Pos' - to category

# %%
#check unique values
nhl.Pos.unique()
# Out:
# array(['C', 'D', 'L', 'R'], dtype=object)

# %%
nhl.Pos.value_counts()
# Out:
# Pos
# D    315
# C    297
# L    171
# R    141
# Name: count, dtype: int64

# %%
#strip whitespace and convert to category

# %%
nhl['Pos'] = nhl['Pos'].str.strip().astype('category')

# %%
#confirm
nhl.Pos.unique()
# Out:
# ['C', 'D', 'L', 'R']
# Categories (4, object): ['C', 'D', 'L', 'R']

# %% [markdown]
# <h3> Explore remaining numeric columns

# %%
nhl.columns
# Out:
# Index(['Player', 'Team', 'Shoots', 'Pos', 'GP', 'G', 'A', 'P', '+/-', 'PIM',
#        'P/GP', 'EVG', 'EVP', 'PPG', 'PPP', 'SHG', 'SHP', 'OTG', 'GWG', 'S',
#        'S%', 'TOI/GP', 'FOW%', 'Team_start', 'Team_end'],
#       dtype='object')

# %%
nhl_numeric= ['GP', 'G', 'A', 'P', '+/-', 'PIM', 'P/GP', 'EVG', 'EVP', 'PPG', 'PPP', 'SHG', 'SHP', 'OTG', 'GWG', 'S', 'S%', 'TOI/GP', 'FOW%']

# %%
nhl[nhl_numeric].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 924 entries, 0 to 923
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   GP      924 non-null    int64
#  1   G       924 non-null    int64
#  2   A       924 non-null    int64
#  3   P       924 non-null    int64
#  4   +/-     924 non-null    int64
#  5   PIM     924 non-null    int64
#  6   P/GP    924 non-null    float64
#  7   EVG     924 non-null    int64
#  8   EVP     924 non-null    int64
#  9   PPG     924 non-null    int64
#  10  PPP     924 non-null    int64
#  11  SHG     924 non-null    int64
#  12  SHP     924 non-null    int64
#  13  OTG     924 non-null    int64
#  14  GWG     924 non-null    int64
#  15  S       924 non-null    int64
#  16  S%      924 non-null    object
#  17  TOI/GP  924 non-null    object
#  18  FOW%    924 non-null    object
# dtypes: float64(1), int64(15), object(3)
# memory usage: 137.3+ KB

# %% [markdown]
# <h4> Explore 'S%' - shot percent

# %%
nhl['S%'].dtype
# Out:
# dtype('O')

# %%
#find number of Nan
nhl[nhl['S%'] == nhl['S%'].isna()]['G'].value_counts()
# Out:
# G
# 0    144
# Name: count, dtype: int64

# %%
nhl[nhl['S%'] == nhl['S%'].isna()]['G'].value_counts()
# Out:
# G
# 0    144
# Name: count, dtype: int64

# %% [markdown]
# **change 'S%' - Nan to 0**
# * Formula for 'S%' is 'G'/'S'
#     * players who score no goals have a nan

# %%
#replace nan with 0
nhl.loc[nhl['S%'].isna(), 'S%'] = 0

#confirm
nhl[nhl['S%'].isna()]
# Out:
# Empty DataFrame
# Columns: [Player, Team, Shoots, Pos, GP, G, A, P, +/-, PIM, P/GP, EVG, EVP, PPG, PPP, SHG, SHP, OTG, GWG, S, S%, TOI/GP, FOW%, Team_start, Team_end]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# **Convert 'S%' - '--' to 0**
# * Formula for 'S%' is 'G'/'S'
#     * players who have no shots ('S') have a '--' value

# %%
#check remaining iunique values in 'S%'
nhl['S%'].unique()
# Out:
# array([7.2, 7.8, 6.5, 6.3, 5.7, 4.6, 2.5, 18.6, 13.4, 13.7, 10.8, 11.6,
#        9.1, 11.3, 12.6, 4.0, 20.0, 18.8, 12.4, 14.3, 11.5, 14.2, 17.5,
#        10.7, 14.9, 10.3, 13.0, 10.1, 8.9, 10.6, 12.7, 15.5, 17.7, 15.6,
#        12.0, 13.3, 10.0, 11.9, 12.9, 10.9, 7.1, 4.8, 5.9, 5.6, 3.4, 2.8,
#        21.4, 9.3, 9.5, 8.3, 5.5, 7.3, 4.7, 3.3, 15.2, 10.4, 9.7, 10.2,
#        7.5, 7.7, 3.6, 13.9, 11.1, 8.1, 11.0, 9.8, 11.2, 7.6, 3.8, 1.5,
#        18.9, 14.6, 8.5, 13.1, 6.7, 5.3, 5.4, 7.4, 14.0, 9.9, 9.4, 11.4,
#        11.8, 15.0, 5.2, 14.4, 14.8, 13.8, 15.7, 14.1, 17.6, 14.7, 13.5,
#        16.2, 9.6, 13.2, 8.4, 17.1, 16.5, 6.1, 12.1, 13.6, 9.0, 7.0, 7.9,
#        6.6, 18.2, 9.2, 15.9, 12.5, 6.2, 20.4, 8.7, 6.9, 18.1, 11.7, 10.5,
#        8.6, 3.9, 1.4, 16.1, 5.8, 4.1, 2.7, 6.8, 3.1, 2.3, 1.3, 8.8, 3.2,
#        2.0, 2.9, 1.1, 0.0, 8.2, 6.0, 4.9, 12.2, 15.3, 8.0, 1.9, 4.2, 5.1,
#        '--', 2.2, 16.7, 5.0, 3.7, 28.6, 100.0, 3.5, 25.0, 33.3, 50.0, 4.4,
#        3.0, 20.8, 30.0, 17.9, 19.7, 12.8, 12.3, 2.4, 6.4, 1.6, 1.2, 15.4,
#        16.3, 1.0, 18.4, 2.6, 21.7, 18.7, 19.1, 16.6, 24.5, 15.1, 20.3,
#        16.4, 17.8, 14.5, 19.6, 19.0, 15.8, 16.0, 17.0, 17.3], dtype=object)

# %%
#preview
nhl[nhl['S%']=='--'].head(10)
# Out:
#                 Player Team Shoots Pos  GP  G  A  P  +/-  PIM  ...  SHG  SHP  \
# 308          Cal Foote  NJD      R   D   4  0  1  1    3   16  ...    0    0
# 315           Aku Raty  ARI      R   R   1  0  1  1    0    0  ...    0    0
# 329      Max McCormick  SEA      L   L   1  0  0  0    0    0  ...    0    0
# 332       Jayson Megna  BOS      R   C   1  0  0  0    0    0  ...    0    0
# 337    Gustav Olofsson  SEA      L   D   1  0  0  0    0    0  ...    0    0
# 339     Oskar Lindblom  SJS      L   L   1  0  0  0   -1    0  ...    0    0
# 342       Glenn Gawdin  ANA      R   C   1  0  0  0   -1    2  ...    0    0
# 343      Adam Gaudette  STL      R   C   2  0  0  0    0    4  ...    0    0
# 345     Samuel Laberge  NJD      L   L   2  0  0  0    0    0  ...    0    0
# 347  Andrew Poturalski  SEA      R   C   2  0  0  0   -1    0  ...    0    0
#
#      OTG  GWG  S  S%  TOI/GP  FOW%  Team_start  Team_end
# 308    0    0  0  --   14:46    --         NJD       NJD
# 315    0    0  0  --   11:45    --         ARI       ARI
# 329    0    0  0  --    5:38    --         SEA       SEA
# 332    0    0  0  --   11:45    --         BOS       BOS
# 337    0    0  0  --   14:57    --         SEA       SEA
# 339    0    0  0  --   11:56    --         SJS       SJS
# 342    0    0  0  --    7:35    40         ANA       ANA
# 343    0    0  0  --    9:48    --         STL       STL
# 345    0    0  0  --    3:06    --         NJD       NJD
# 347    0    0  0  --    6:53   100         SEA       SEA
#
# [10 rows x 25 columns]

# %%
#check 'S' for players with 'S%' == '--'
nhl[nhl['S%'] == '--']['S'].value_counts()
# Out:
# S
# 0    32
# Name: count, dtype: int64

# %%
#replace '--' with 0
nhl.loc[nhl['S%']=='--', 'S%'] = 0

#confirm
nhl[nhl['S%']=='--']
# Out:
# Empty DataFrame
# Columns: [Player, Team, Shoots, Pos, GP, G, A, P, +/-, PIM, P/GP, EVG, EVP, PPG, PPP, SHG, SHP, OTG, GWG, S, S%, TOI/GP, FOW%, Team_start, Team_end]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# **convert 'S%' to float**

# %%
#convert
nhl['S%'] = nhl['S%'].astype('float')

#confirm
nhl['S%'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 924 entries, 0 to 923
# Series name: S%
# Non-Null Count  Dtype
# --------------  -----
# 924 non-null    float64
# dtypes: float64(1)
# memory usage: 7.3 KB

# %% [markdown]
# <h4> Explore 'TOI/GP' - average Time On Ice per Game Played - to 'TOI_min'

# %%
nhl['TOI/GP'].head()
# Out:
# 0    19:14
# 1    15:39
# 2    15:10
# 3    22:09
# 4    23:50
# Name: TOI/GP, dtype: object

# %% [markdown]
# **change 'TOI/GP' from MM:SS to minutes saved as 'TOI_min' and as float type**

# %%
# convert MM:SS to minutes and save as 'TOI_min'
nhl['TOI_min'] = round((nhl['TOI/GP'].str.split(':').str[0].astype('float') + (nhl['TOI/GP'].str.split(':').str[-1].astype('float') / 60)),2)

#confirm
nhl['TOI_min'].head()
# Out:
# 0    19.23
# 1    15.65
# 2    15.17
# 3    22.15
# 4    23.83
# Name: TOI_min, dtype: float64

# %% [markdown]
# <h4> Explore 'FOW%' - Face Off Win percentage

# %%
nhl['FOW%'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 924 entries, 0 to 923
# Series name: FOW%
# Non-Null Count  Dtype
# --------------  -----
# 924 non-null    object
# dtypes: object(1)
# memory usage: 7.3+ KB

# %%
nhl['FOW%'].unique()
# Out:
# array([50.3, 48.9, 50, '--', 37.9, 37.6, 57.5, 47.6, 53.5, 100, 43.2,
#        52.4, 23.1, 47.4, 42.2, 36.3, 45.8, 35.9, 38.7, 52.9, 54.3, 36.7,
#        20.7, 54.8, 52.6, 0, 54.9, 49, 33.3, 45.6, 27.3, 46.5, 44, 44.9,
#        42.4, 46.7, 53.6, 48.3, 55.4, 47.8, 58.3, 47.2, 39.4, 50.5, 46.3,
#        44.4, 41.2, 52.3, 23.5, 27.6, 42.9, 52.2, 57.1, 44.1, 31.6, 50.8,
#        18.8, 29.4, 58.1, 30.8, 7.1, 49.3, 57, 34.8, 40.4, 29.6, 48, 49.2,
#        29.8, 29.2, 25.8, 47.1, 37.5, 43.3, 25, 51.8, 38, 30.4, 38.2, 46.4,
#        28.6, 34.1, 56.3, 48.4, 53.3, 20, 44.8, 51.9, 41.9, 49.4, 47, 42.5,
#        31.3, 32.9, 56.4, 66.7, 37, 31.1, 51.7, 45.5, 34.3, 46.8, 49.5,
#        46.1, 44.7, 45.4, 51.6, 49.7, 26.3, 56.5, 65, 45.1, 50.9, 37.1, 34,
#        54.4, 33.1, 43.8, 50.2, 48.1, 40, 23.9, 44.6, 45, 51.3, 53.4, 42.6,
#        35.5, 30, 43.4, 62.5, 40.5, 51.4, 53.1, 46.9, 38.4, 49.9, 43.7,
#        36.4, 47.7, 35.7, 64.7, 21.4, 35.3, 31.4, 31.8, 22.2, 14.3, 41.7,
#        75, 16.7, 26.8, 52, 55.6, 61.8, 50.6, 87.5, 40.7, 45.3, 39.9, 47.9,
#        55.7, 51.5, 43.6, 32, 55.3, 39.1, 43.9, 48.5, 31.7, 45.2, 27.9,
#        46.2, 48.8, 49.1, 60, 42.1, 22.1, 53.9, 53.2, 41.5, 38.9, 34.2,
#        61.3, 15.8, 46, 54.5, 54.6, 26.7, 51, 46.6, 38.5, 17.7, 22.7, 60.1,
#        45.7, 55.8, 54, 57.2, 42.7, 56, 52.8, 30.2, 49.8, 57.8, 39.7, 51.1,
#        10, 56.9, 53.8, 44.2, 58.2, 54.1, 57.3, 43, 26.1, 58.7, 36.5, 41,
#        37.2, 55.1, 40.2, 48.6, 56.6, 40.9, 56.2, 59.3, 58, 37.4, 61.2, 39,
#        32.1, 48.7], dtype=object)

# %% [markdown]
# **Convert 'FOW%' - '--' to 0**
# * Formula for 'FOW%' is Face-offs won / Face-offs taken
#     * players who have taken no face-offs will have a '--' value

# %%
#convert '--' to 0
nhl.loc[nhl['FOW%'] == '--', 'FOW%'] = 0

#confirm
nhl[nhl['FOW%'] == '--']
# Out:
# Empty DataFrame
# Columns: [Player, Team, Shoots, Pos, GP, G, A, P, +/-, PIM, P/GP, EVG, EVP, PPG, PPP, SHG, SHP, OTG, GWG, S, S%, TOI/GP, FOW%, Team_start, Team_end, TOI_min]
# Index: []
#
# [0 rows x 26 columns]

# %%
#convert to float
nhl['FOW%'] = nhl['FOW%'].astype('float')

#confirm
nhl['FOW%'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 924 entries, 0 to 923
# Series name: FOW%
# Non-Null Count  Dtype
# --------------  -----
# 924 non-null    float64
# dtypes: float64(1)
# memory usage: 7.3 KB

# %% [markdown]
# <h3>Confirm Changes and create cleand columns list

# %%
nhl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 924 entries, 0 to 923
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Player      924 non-null    object
#  1   Team        924 non-null    object
#  2   Shoots      924 non-null    category
#  3   Pos         924 non-null    category
#  4   GP          924 non-null    int64
#  5   G           924 non-null    int64
#  6   A           924 non-null    int64
#  7   P           924 non-null    int64
#  8   +/-         924 non-null    int64
#  9   PIM         924 non-null    int64
#  10  P/GP        924 non-null    float64
#  11  EVG         924 non-null    int64
#  12  EVP         924 non-null    int64
#  13  PPG         924 non-null    int64
#  14  PPP         924 non-null    int64
#  15  SHG         924 non-null    int64
#  16  SHP         924 non-null    int64
#  17  OTG         924 non-null    int64
#  18  GWG         924 non-null    int64
#  19  S           924 non-null    int64
#  20  S%          924 non-null    float64
#  21  TOI/GP      924 non-null    object
#  22  FOW%        924 non-null    float64
#  23  Team_start  924 non-null    category
#  24  Team_end    924 non-null    category
#  25  TOI_min     924 non-null    float64
# dtypes: category(4), float64(4), int64(15), object(3)
# memory usage: 165.5+ KB

# %% [markdown]
# **nhl cleaned columns list**
# * replace 'Team' with 'Team_start' and 'Team_end'
# * change 'S/C' to 'Shoots'
# * replace 'TOI/GP' = 'TOI_min'

# %%
#cleaned columns
nhl_cleaned_columns = []

for i in range(len(nhl_columns_after_drop)):
    
    #adjust modified columns
    if nhl_columns_after_drop[i] == 'Team':
        nhl_cleaned_columns.append('Team_start')
        nhl_cleaned_columns.append('Team_end')
    
    elif nhl_columns_after_drop[i] == 'S/C':
        nhl_cleaned_columns.append('Shoots')
    
    elif nhl_columns_after_drop[i] == 'TOI/GP':
        nhl_cleaned_columns.append('TOI_min')
    
    #add unchanged columns to nhl_cleaned_columns
    else: nhl_cleaned_columns.append(nhl_columns_after_drop[i])

# %%
#confirm
nhl_cleaned_columns
# Out:
# ['Player',
#  'Team_start',
#  'Team_end',
#  'Shoots',
#  'Pos',
#  'GP',
#  'G',
#  'A',
#  'P',
#  '+/-',
#  'PIM',
#  'P/GP',
#  'EVG',
#  'EVP',
#  'PPG',
#  'PPP',
#  'SHG',
#  'SHP',
#  'OTG',
#  'GWG',
#  'S',
#  'S%',
#  'TOI_min',
#  'FOW%']

# %% [markdown]
# <h3> Create nhl_cleaned for the cleaned database and export to .csv

# %%
#create new cleaned nhl database
nhl_cleaned = nhl[nhl_cleaned_columns]

#confirm
nhl_cleaned.T
# Out:
#                         0               1               2                3    \
# Player      Mikael Backlund  Scott Laughton  Evan Rodrigues  Gustav Forsling
# Team_start              CGY             PHI             FLA              FLA
# Team_end                CGY             PHI             FLA              FLA
# Shoots                    L               L               R                L
# Pos                       C               C               C                D
# GP                       82              82              80               79
# G                        15              13              12               10
# A                        24              26              27               29
# P                        39              39              39               39
# +/-                      -4              -9              26               56
# PIM                      24              69              34               43
# P/GP                   0.48            0.48            0.49             0.49
# EVG                      12              10               9                9
# EVP                      34              26              29               37
# PPG                       2               1               3                1
# PPP                       3               5              10                2
# SHG                       1               2               0                0
# SHP                       2               8               0                0
# OTG                       0               0               0                1
# GWG                       2               2               1                1
# S                       209             167             186              160
# S%                      7.2             7.8             6.5              6.3
# TOI_min               19.23           15.65           15.17            22.15
# FOW%                   50.3            48.9            50.0              0.0
#
#                          4           5           6                7    \
# Player      Rasmus Andersson  Cam Fowler  Torey Krug  Jake Neighbours
# Team_start               CGY         ANA         STL              STL
# Team_end                 CGY         ANA         STL              STL
# Shoots                     R           L           L                L
# Pos                        D           D           D                L
# GP                        78          81          77               77
# G                          9           5           4               27
# A                         30          34          35               11
# P                         39          39          39               38
# +/-                      -11         -36         -31              -16
# PIM                       47          24          32               21
# P/GP                     0.5        0.48        0.51             0.49
# EVG                        8           3           4               19
# EVP                       30          20          26               24
# PPG                        0           2           0                8
# PPP                        8          18          13               14
# SHG                        1           0           0                0
# SHP                        1           1           0                0
# OTG                        1           0           0                0
# GWG                        3           0           2                4
# S                        159         109         162              145
# S%                       5.7         4.6         2.5             18.6
# TOI_min                23.83       24.42       21.97             15.7
# FOW%                     0.0         0.0         0.0             37.9
#
#                       8            9    ...            914  \
# Player      Cole Perfetti  Tomas Hertl  ...  Pavol Regenda
# Team_start            WPG          SJS  ...            ANA
# Team_end              WPG          VGK  ...            ANA
# Shoots                  L            L  ...              L
# Pos                     C            C  ...              L
# GP                     71           54  ...              5
# G                      19           17  ...              0
# A                      19           21  ...              0
# P                      38           38  ...              0
# +/-                    13          -28  ...             -1
# PIM                    12           22  ...              2
# P/GP                 0.54          0.7  ...            0.0
# EVG                    14           10  ...              0
# EVP                    27           26  ...              0
# PPG                     5            6  ...              0
# PPP                    11           11  ...              0
# SHG                     0            1  ...              0
# SHP                     0            1  ...              0
# OTG                     0            2  ...              0
# GWG                     3            2  ...              0
# S                     142          124  ...              7
# S%                   13.4         13.7  ...            0.0
# TOI_min             13.58        20.48  ...          11.57
# FOW%                 37.6         57.5  ...           16.7
#
#                            915            916             917            918  \
# Player      Maksymilian Szuber  Pierrick Dube  Gavin Brindley  Bradly Nadeau
# Team_start                 ARI            WSH             CBJ            CAR
# Team_end                   ARI            WSH             CBJ            CAR
# Shoots                       L              R               R              R
# Pos                          D              R               C              L
# GP                           1              3               1              1
# G                            0              0               0              0
# A                            0              0               0              0
# P                            0              0               0              0
# +/-                         -1              1               0             -3
# PIM                          2              2               0              0
# P/GP                       0.0            0.0             0.0            0.0
# EVG                          0              0               0              0
# EVP                          0              0               0              0
# PPG                          0              0               0              0
# PPP                          0              0               0              0
# SHG                          0              0               0              0
# SHP                          0              0               0              0
# OTG                          0              0               0              0
# GWG                          0              0               0              0
# S                            1              3               0              3
# S%                         0.0            0.0             0.0            0.0
# TOI_min                  16.98           9.33           12.33          19.13
# FOW%                       0.0            0.0             0.0            0.0
#
#                      919           920          921                922  \
# Player      Akito Hirose  Ondrej Pavel  Cole McWard  Nikolas Matinpalo
# Team_start           VAN           COL          VAN                OTT
# Team_end             VAN           COL          VAN                OTT
# Shoots                 L             L            R                  R
# Pos                    D             C            D                  D
# GP                     3             2            1                  4
# G                      0             0            0                  0
# A                      0             0            0                  0
# P                      0             0            0                  0
# +/-                    1            -1            0                  1
# PIM                    0             2            0                  0
# P/GP                 0.0           0.0          0.0                0.0
# EVG                    0             0            0                  0
# EVP                    0             0            0                  0
# PPG                    0             0            0                  0
# PPP                    0             0            0                  0
# SHG                    0             0            0                  0
# SHP                    0             0            0                  0
# OTG                    0             0            0                  0
# GWG                    0             0            0                  0
# S                      0             3            1                  2
# S%                   0.0           0.0          0.0                0.0
# TOI_min             12.1           6.1         9.08                7.0
# FOW%                 0.0          33.3          0.0                0.0
#
#                     923
# Player      Patrik Koch
# Team_start          ARI
# Team_end            ARI
# Shoots                L
# Pos                   D
# GP                    1
# G                     0
# A                     0
# P                     0
# +/-                   0
# PIM                  10
# P/GP                0.0
# EVG                   0
# EVP                   0
# PPG                   0
# PPP                   0
# SHG                   0
# SHP                   0
# OTG                   0
# GWG                   0
# S                     1
# S%                  0.0
# TOI_min            9.33
# FOW%                0.0
#
# [24 rows x 924 columns]

# %% [markdown]
# <h4> Export cleaned nhl df to .csv

# %%
#Save nhl_cleaned to nhl_cleaned.csv
#comment out after saving to not save multiples

#create path
cleaned_path = "/Users/ness/Desktop/Springboard/Projects/-Capstone 2/NHL Salaries/clean_data/nhl_cleaned.csv"

#save
#nhl_cleaned.to_csv(cleaned_path, index=False)

# %% [markdown]
# <h2>Match capfriendly['PLAYER'] to nhl_cleaned['Player']

# %%
#save capfriendly players
capfriendly_players = capfriendly['PLAYER']

#save nhl_cleaned['Player']
nhl_players = nhl_cleaned['Player']

# %% [markdown]
# **Create unmatched list for manual changes**

# %%
#find players in nhl that are not in capfriendly
unmatched_nhl=nhl_cleaned[~nhl_players.isin(capfriendly['PLAYER'])]

# of players
len(unmatched_nhl)
# Out:
# 86

# %%
#find players in capfriendly that are not in nhl_cleaned
unmatched_cap = capfriendly[~capfriendly_players.isin(nhl_cleaned['Player'])]

# of players
len(unmatched_cap)
# Out:
# 85

# %% [markdown]
# <h3>Define functions to streamline name changes

# %% [markdown]
# **function to find nhl official name at given index**

# %%
def name(unmatched_index):
    '''Function to return the name of player from unmatched_nhl at the given index'''
    
    #identify NHL official name at provided index
    nhl_player_name = unmatched_nhl.iloc[unmatched_index,0]

    return nhl_player_name

# %% [markdown]
# **function to find nhl official name  and stats at given index**

# %%
def unmatched_name(unmatched_index):
    '''Function to return the name of player from unmatched_nhl at the given index'''
    
    #identify NHL official name at provided index
    nhl_player_name = unmatched_nhl.iloc[[unmatched_index]]

    return nhl_player_name

# %% [markdown]
# **function to return possible matches to name in unmatched_nhl at the given index**

# %%
def unmatched_matches(unmatched_index):
    '''Function to return possible matches to name in unmatched_nhl at the given index'''
    
    #identify NHL official name at provided index
    nhl_player_name = unmatched_nhl.iloc[unmatched_index,0]
    '------------------------'
    #DEFINE FIRST name from NHL official name
    first_name = nhl_player_name.split(' ')[0]
    
    #possible MATCHES from FIRST name
    first_name_matches = capfriendly[capfriendly.PLAYER.str.contains(first_name)]
    '------------------------'
    #DEFINE LAST name from NHL official name
    last_name = nhl_player_name.split(' ')[-1]
    
    #possible MATCHES from LAST name
    last_name_matches = capfriendly[capfriendly.PLAYER.str.contains(last_name)]
    '------------------------'
    #CREATE possible_matches DF 
    possible_matches = pd.concat([last_name_matches, first_name_matches],  ignore_index = False)

    return possible_matches

# %% [markdown]
# **Function to replace name in capfriendly with name in nhl_cleaned at given index**

# %%
def replace(unmatched_index, capfriendly_index):
    '''Function to replace name in capfriendly @ capfriendly_index with name in nhl_cleaned @ unmatched_index'''
    #change name to match nhl_cleaned
    capfriendly.iloc[[capfriendly_index],[0]]= name(unmatched_index)
    
    return capfriendly.iloc[[capfriendly_index]]

# %% [markdown]
# <h3> Change Names

# %% [markdown]
# **upgrades to process**
# **Note**: This process could be mostly automated but I currently do not have the skill to do it *efficiently*. If this were a personal project and not for a bootcamp I would invest the time.  But because of the time constraints of the bootcamp, I feel like my time is better spent moving through the material.
#
# The process would be:
# 1) Create function that:
#     * moves through a loop to to return 'unmatched_index' for the above functions based on len(unmatched_nhl). then for each for each 'unmatched_index' in loop:
#     * takes dataframes returned from unmatched_names() and unmatched_maches() and matches player based on exact values for the 'GP', 'G', 'A' and 'P' .
#      find and save the index of the df returned from unmatched_maches() for the matched player
#     * use saved index as the 'capfriendly_index' in replace()
#     * return list of players that do not have matches in capfriendly to be explored further
# 2) Manually explore returned list of players with no matches

# %% [markdown]
# **find length of unmatched list**

# %%
#this is number of manual changes that need to be made
len(unmatched_nhl)
# Out:
# 86

# %% [markdown]
# **Index 0**

# %%
unmatched_name(0)
# Out:
#            Player Team_start Team_end Shoots Pos  GP   G   A   P  +/-  ...  \
# 16  Matty Beniers        SEA      SEA      L   C  77  15  22  37  -11  ...
#
#     PPG  PPP  SHG  SHP  OTG  GWG    S    S%  TOI_min  FOW%
# 16    6   13    0    0    0    1  133  11.3    17.97  47.4
#
# [1 rows x 24 columns]

# %%
unmatched_matches(0)
# Out:
#               PLAYER  AGE        COUNTRY  WEIGHT HEIGHT POS HANDED  GP   G  \
# 563  Matthew Beniers   20  United States     175    6'2   C   Left  77  15
#
#       A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 563  22  ...    2022-04-10           18    None       3      ELC  restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 563       2024  1850000         74    17.95
#
# [1 rows x 48 columns]

# %%
replace(0,563)
# Out:
#             PLAYER  AGE        COUNTRY  WEIGHT HEIGHT POS HANDED  GP   G   A  \
# 563  Matty Beniers   20  United States     175    6'2   C   Left  77  15  22
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 563  ...    2022-04-10           18    None       3      ELC  restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 563       2024  1850000         74    17.95
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 1**

# %%
unmatched_name(1)
# Out:
#             Player Team_start Team_end Shoots Pos  GP   G   A   P  +/-  ...  \
# 20  Nils Hoglander        VAN      VAN      L   L  80  24  12  36   23  ...
#
#     PPG  PPP  SHG  SHP  OTG  GWG    S    S%  TOI_min  FOW%
# 20    0    0    0    0    0    5  120  20.0     12.1   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(1)
# Out:
#              PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP   G   A  \
# 451  Nils Höglander   22  Sweden     185    5'9  LW, RW   Left  80  24  12
# 529  Nils Lundkvist   22  Sweden     187   5'11      RD  Right  59   2  17
# 586       Nils Åman   23  Sweden     179    6'2       C   Left  43   3   4
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 451  ...    2023-07-09           22    None       2      RFA    restricted
# 529  ...    2021-06-03           20    None       3      ELC  unrestricted
# 586  ...    2022-06-07           22    None       2      ELC    restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 451       2025  1100000         69    12.10
# 529       2024  1775000         71    14.10
# 586       2024   925000         74    10.33
#
# [3 rows x 48 columns]

# %%
replace(1,451)
# Out:
#              PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP   G   A  \
# 451  Nils Hoglander   22  Sweden     185    5'9  LW, RW   Left  80  24  12
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 451  ...    2023-07-09           22    None       2      RFA  restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 451       2025  1100000         69     12.1
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 2**

# %%
unmatched_name(2)
# Out:
#          Player Team_start Team_end Shoots Pos  GP   G   A   P  +/-  ...  PPG  \
# 71  Josh Norris        OTT      OTT      L   C  50  16  14  30   -6  ...    5
#
#     PPP  SHG  SHP  OTG  GWG    S    S%  TOI_min  FOW%
# 71   12    0    1    0    3  115  13.9    17.63  52.2
#
# [1 rows x 24 columns]

# %%
unmatched_matches(2)
# Out:
#                PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  \
# 62      Joshua Norris   24  United States     199    6'1       C   Left  50
# 62      Joshua Norris   24  United States     199    6'1       C   Left  50
# 112  Joshua Morrissey   28         Canada     195    6'0      LD   Left  81
# 151     Josh Anderson   29         Canada     227    6'3  RW, LW  Right  78
# 212       Josh Manson   31  United States     218    6'3      RD  Right  76
# 438      Joshua Brown   29         Canada     217    6'5      RD  Right  51
# 512         Josh Doan   21  United States     183    6'1      RW  Right  11
# 514       Josh Mahura   25         Canada     190    6'0   LD/RD   Left  30
# 671        Joshua Roy   19         Canada     190    6'0  LW, RW   Left  23
# 691     Dakota Joshua   27  United States     183    6'2      LW   Left  63
#
#       G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 62   16  14  ...    2022-07-14           23    None       8      RFA
# 62   16  14  ...    2022-07-14           23    None       8      RFA
# 112  10  59  ...    2019-09-12           25     NMC       8      RFA
# 151   9  11  ...    2020-10-08           26   M-NTC       7      RFA
# 212   8  17  ...    2022-07-13           30     NTC       4      UFA
# 438   3   7  ...    2022-07-13           28    None       2      UFA
# 512   5   4  ...    2023-03-16           21    None       3      ELC
# 514   0   9  ...    2023-02-10           25    None       1      RFA
# 671   4   5  ...    2022-03-30           18    None       3      ELC
# 691  18  14  ...    2022-07-13           26    None       2      UFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 62   unrestricted       2030  7950000         73    17.63
# 62   unrestricted       2030  7950000         73    17.63
# 112  unrestricted       2028  6250000         72    24.17
# 151  unrestricted       2027  5500000         75    15.45
# 212  unrestricted       2026  4500000         75    17.77
# 438  unrestricted       2024  1275000         77    14.75
# 512    restricted       2026   925000         73    12.30
# 514  unrestricted       2024   925000         72    12.58
# 671    restricted       2026   881667         72    12.13
# 691  unrestricted       2024   825000         74    14.38
#
# [10 rows x 48 columns]

# %%
replace(2,62)
# Out:
#          PLAYER  AGE        COUNTRY  WEIGHT HEIGHT POS HANDED  GP   G   A  \
# 62  Josh Norris   24  United States     199    6'1   C   Left  50  16  14
#
#     ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 62  ...    2022-07-14           23    None       8      RFA  unrestricted
#
#     EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 62       2030  7950000         73    17.63
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 3**

# %%
unmatched_name(3)
# Out:
#         Player Team_start Team_end Shoots Pos  GP   G   A   P  +/-  ...  PPG  \
# 96  Joe Veleno        DET      DET      L   C  80  12  16  28  -16  ...    3
#
#     PPP  SHG  SHP  OTG  GWG   S    S%  TOI_min  FOW%
# 96    5    0    1    0    1  86  14.0    13.95  49.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(3)
# Out:
#                PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  \
# 683     Joseph Veleno   23         Canada     191    6'1       C   Left  80
# 161  Joel Eriksson Ek   26         Sweden     210    6'1       C   Left  77
# 181      Joel Farabee   23  United States     164    6'0  LW, RW   Left  82
# 267      Joe Pavelski   38  United States     195   5'11      RW  Right  82
# 270    Joel Edmundson   30         Canada     224    6'5   LD/RD   Left  53
# 277        Joel Armia   30        Finland     218    6'4  RW, LW  Right  66
# 723     Joey Anderson   25  United States     190   5'11      RW  Right  55
# 734       Joe Snively   27  United States     165    5'9      LW   Left   3
# 751       Joel Hanley   32         Canada     190   5'11   LD/RD   Left  42
# 762    Joel Kiviranta   27        Finland     175   5'10  RW, LW   Left  56
#
#       G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 683  12  16  ...    2023-08-22           23    None       1      RFA
# 161  30  34  ...    2021-07-02           24    None       8      RFA
# 181  22  28  ...    2021-09-02           22    None       6      RFA
# 267  27  40  ...    2023-01-01           38     NMC       1      UFA
# 270   1   5  ...    2020-09-16           27   M-NTC       4      UFA
# 277  17   8  ...    2021-07-27           28    None       4      UFA
# 723   5  12  ...    2023-06-22           25    None       1      RFA
# 734   0   0  ...    2022-03-16           26    None       2      UFA
# 751   1   4  ...    2023-07-01           32    None       2      UFA
# 762   3   6  ...    2023-11-12           27    None       1      UFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 683    restricted       2024   825000         73    13.95
# 161  unrestricted       2029  5250000         73    20.52
# 181  unrestricted       2028  5000000         72    16.18
# 267  unrestricted       2024  5500000         71    16.80
# 270  unrestricted       2024  3500000         77    16.67
# 277  unrestricted       2025  3400000         76    15.55
# 723  unrestricted       2024   800000         71    13.53
# 734  unrestricted       2024   800000         69     8.33
# 751  unrestricted       2025   787500         71    13.88
# 762  unrestricted       2024   775000         70     9.83
#
# [10 rows x 48 columns]

# %%
replace(3,683)
# Out:
#          PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP   G   A  ...  \
# 683  Joe Veleno   23  Canada     191    6'1   C   Left  80  12  16  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 683    2023-08-22           23    None       1      RFA  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 683       2024  825000         73    13.95
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 4**

# %%
unmatched_name(4)
# Out:
#             Player Team_start Team_end Shoots Pos  GP   G   A   P  +/-  ...  \
# 104  Zach Werenski        CBJ      CBJ      L   D  70  11  46  57    0  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG    S   S%  TOI_min  FOW%
# 104    2   12    0    0    0    0  202  5.5    24.45   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(4)
# Out:
#                PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  \
# 15   Zachary Werenski   25  United States     212    6'2      LD   Left  70
# 15   Zachary Werenski   25  United States     212    6'2      LD   Left  70
# 150        Zach Hyman   31         Canada     211    6'1  RW, LW  Right  80
# 196       Pavel Zacha   26          Other     210    6'3   C, LW   Left  78
# 325   Zach Whitecloud   26         Canada     209    6'2      RD  Right  61
# 489       Zach Benson   18         Canada     170   5'10      LW   Left  71
# 608    Zachary Bolduc   20         Canada     175    6'1      LW   Left  25
# 643         Zach Dean   20         Canada     176    6'0       C   Left   9
# 659     Zach Bogosian   32  United States     226    6'3      RD  Right  65
# 681       Zach Parise   38  United States     195   5'11      LW   Left  30
# 704     Zachary Jones   22  United States     175   5'11      LD   Left  31
# 712   Zachary Sanford   28  United States     207    6'4  LW, RW   Left  29
# 767  Zach Aston-Reese   28  United States     204    6'0  LW, RW   Left   3
#
#       G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 15   11  46  ...    2021-07-29           24     NMC       6      RFA
# 15   11  46  ...    2021-07-29           24     NMC       6      RFA
# 150  54  23  ...    2021-07-28           29     NMC       7      UFA
# 196  21  38  ...    2023-01-14           26   M-NTC       4      UFA
# 325   2  12  ...    2021-10-28           25    None       6      RFA
# 489  11  19  ...    2023-07-28           18    None       3      ELC
# 608   5   4  ...    2021-08-24           18    None       3      ELC
# 643   0   0  ...    2021-12-02           18    None       3      ELC
# 659   3  11  ...    2021-07-28           30   M-NTC       3      UFA
# 681   5   5  ...    2024-01-26           38    None       1      UFA
# 704   2   7  ...    2023-06-16           22    None       2      RFA
# 712   0   6  ...    2023-07-14           28    None       1      UFA
# 767   0   0  ...    2023-10-08           28    None       1      UFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 15   unrestricted       2028  9583333         74    24.45
# 15   unrestricted       2028  9583333         74    24.45
# 150  unrestricted       2028  5500000         73    19.50
# 196  unrestricted       2027  4750000         75    18.10
# 325  unrestricted       2028  2750000         74    17.58
# 489    restricted       2026  1600000         70    14.52
# 608    restricted       2026  1275833         73    12.00
# 643    restricted       2026   863333         72    10.55
# 659  unrestricted       2024   850000         75    17.88
# 681  unrestricted       2024   825000         71    12.97
# 704    restricted       2025   812500         71    14.62
# 712  unrestricted       2024   800000         76    10.83
# 767  unrestricted       2024   775000         72     5.15
#
# [13 rows x 48 columns]

# %%
replace(4,15)
# Out:
#            PLAYER  AGE        COUNTRY  WEIGHT HEIGHT POS HANDED  GP   G   A  \
# 15  Zach Werenski   25  United States     212    6'2  LD   Left  70  11  46
#
#     ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 15  ...    2021-07-29           24     NMC       6      RFA  unrestricted
#
#     EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 15       2028  9583333         74    24.45
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 5**

# %%
unmatched_name(5)
# Out:
#                Player Team_start Team_end Shoots Pos  GP   G   A   P  +/-  \
# 121  Teuvo Teravainen        CAR      CAR      L   L  76  25  28  53   15
#
#      ...  PPG  PPP  SHG  SHP  OTG  GWG    S    S%  TOI_min  FOW%
# 121  ...    9   17    1    4    0    4  142  17.6     16.4  47.1
#
# [1 rows x 24 columns]

# %%
unmatched_matches(5)
# Out:
#                PLAYER  AGE  COUNTRY  WEIGHT HEIGHT     POS HANDED  GP   G   A  \
# 155  Teuvo Teräväinen   28  Finland     191   5'11  LW, RW   Left  76  25  28
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 155  ...    2019-01-21           24   M-NTC       5      RFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 155       2024  5400000         71     16.4
#
# [1 rows x 48 columns]

# %%
replace(5,155)
# Out:
#                PLAYER  AGE  COUNTRY  WEIGHT HEIGHT     POS HANDED  GP   G   A  \
# 155  Teuvo Teravainen   28  Finland     191   5'11  LW, RW   Left  76  25  28
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 155  ...    2019-01-21           24   M-NTC       5      RFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 155       2024  5400000         71     16.4
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 6**

# %%
unmatched_name(6)
# Out:
#          Player Team_start Team_end Shoots Pos  GP   G   A   P  +/-  ...  PPG  \
# 134  JJ Peterka        BUF      BUF      L   R  82  28  22  50   10  ...    3
#
#      PPP  SHG  SHP  OTG  GWG    S    S%  TOI_min  FOW%
# 134    7    0    0    0    5  226  12.4     16.4  20.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(6)
# Out:
#                  PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP   G  \
# 637  John-Jason Peterka   21   Other     192   5'11  LW, RW   Left  82  28
#
#       A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 637  22  ...    2021-06-11           19    None       3      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 637       2025  894167         71    16.38
#
# [1 rows x 48 columns]

# %%
replace(6,637)
# Out:
#          PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP   G   A  ...  \
# 637  JJ Peterka   21   Other     192   5'11  LW, RW   Left  82  28  22  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 637    2021-06-11           19    None       3      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 637       2025  894167         71    16.38
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 7**

# %%
unmatched_name(7)
# Out:
#           Player Team_start Team_end Shoots Pos  GP   G   A   P  +/-  ...  \
# 162  Tommy Novak        NSH      NSH      L   C  71  18  27  45   -3  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG    S    S%  TOI_min  FOW%
# 162    6   12    0    0    0    1  113  15.9     14.2  42.2
#
# [1 rows x 24 columns]

# %%
unmatched_matches(7)
# Out:
#            PLAYER  AGE        COUNTRY  WEIGHT HEIGHT POS HANDED  GP   G   A  \
# 728  Thomas Novak   26  United States     179    6'1   C   Left  71  18  27
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 728  ...    2023-02-08           26    None       1      RFA  unrestricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 728       2024  800000         73     14.2
#
# [1 rows x 48 columns]

# %%
replace(7,728)
# Out:
#           PLAYER  AGE        COUNTRY  WEIGHT HEIGHT POS HANDED  GP   G   A  \
# 728  Tommy Novak   26  United States     179    6'1   C   Left  71  18  27
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 728  ...    2023-02-08           26    None       1      RFA  unrestricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 728       2024  800000         73     14.2
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 8**

# %%
unmatched_name(8)
# Out:
#            Player Team_start Team_end Shoots Pos  GP   G   A   P  +/-  ...  \
# 164  Alex Kerfoot        ARI      ARI      L   C  82  13  32  45  -15  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG    S    S%  TOI_min  FOW%
# 164    2   12    2    3    0    3  103  12.6    17.43  47.8
#
# [1 rows x 24 columns]

# %%
unmatched_matches(8)
# Out:
#                   PLAYER  AGE        COUNTRY  WEIGHT HEIGHT        POS HANDED  \
# 265    Alexander Kerfoot   28         Canada     185   5'10  LW, C, RW   Left
# 20         Alex Ovechkin   37         Russia     236    6'3         LW  Right
# 35      Alex Pietrangelo   33         Canada     210    6'3         RD  Right
# 63        Alex DeBrincat   25  United States     165    5'7     LW, RW  Right
# 105         Alex Killorn   33         Canada     199    6'1     RW, LW   Left
# 201            Alex Tuch   27  United States     220    6'4     RW, LW  Right
# 215   Alexander Wennberg   28         Sweden     197    6'2          C   Left
# 253         Alex Iafallo   29  United States     188    6'0     LW, RW   Left
# 265    Alexander Kerfoot   28         Canada     185   5'10  LW, C, RW   Left
# 314         Alex Newhook   22         Canada     199   5'11      C, LW   Left
# 337    Alexandre Carrier   26         Canada     174   5'11         RD  Right
# 344    Alexander Romanov   23         Russia     209    6'1         LD   Left
# 348  Alexander Barabanov   29         Russia     192   5'10     RW, LW   Left
# 359    Alexis Lafrenière   21         Canada     193    6'1     LW, RW   Left
# 388       Alex Goligoski   37  United States     185   5'11      LD/RD   Left
# 411     Alexandre Texier   23          Other     192    6'1  LW, C, RW   Left
# 439   Alexey Toropchenko   24         Russia     187    6'3     LW, RW   Left
# 552          Alex Vlasic   22  United States     200    6'6         LD   Left
# 574      Alexander Holtz   21         Sweden     192    6'0     RW, LW  Right
# 582        Alex Turcotte   22  United States     185   5'11          C   Left
# 591      Alex Laferriere   21  United States     173    6'0         RW  Right
# 672         Alex Steeves   23  United States     185   5'11     LW, RW   Left
# 688   Alexander Alexeyev   23         Russia     196    6'4      LD/RD   Left
# 700    Nikita Alexandrov   22          Other     190    6'0          C   Left
# 863        Alex Petrovic   31         Canada     216    6'4         RD  Right
# 869   Alexander Nylander   25         Canada     192    6'1     RW, LW  Right
# 922    Alex Barré-Boulet   26         Canada     168    5'9     RW, LW   Left
#
#      GP   G   A  ...  SIGNING DATE  SIGNING AGE      CLAUSE  LENGTH  SIGNING  \
# 265  82  13  32  ...    2023-07-01           28       M-NTC       2      UFA
# 20   79  31  34  ...    2021-07-27           35  M-NTC, NMC       5      UFA
# 35   64   4  29  ...    2020-10-12           30         NMC       7      UFA
# 63   82  27  40  ...    2023-07-09           25        None       4      RFA
# 105  63  18  18  ...    2023-07-01           33         NTC       4      UFA
# 201  75  22  37  ...    2018-10-19           23       M-NTC       7      RFA
# 215  79  10  20  ...    2021-07-28           26       M-NTC       3      UFA
# 253  82  11  16  ...    2021-04-12           27        None       4      UFA
# 265  82  13  32  ...    2023-07-01           28       M-NTC       2      UFA
# 314  55  15  19  ...    2023-07-11           22        None       4      RFA
# 337  73   4  16  ...    2023-07-01           26        None       1      RFA
# 344  81   7  15  ...    2022-08-22           22        None       3      RFA
# 348  46   4   9  ...    2022-05-09           28       M-NTC       2      UFA
# 359  82  28  29  ...    2023-08-23           21        None       2      RFA
# 388  36   0  10  ...    2022-03-30           36         NMC       2      UFA
# 411  78  12  18  ...    2021-07-28           21        None       3      RFA
# 439  82  14   7  ...    2023-07-16           24        None       2      RFA
# 552  76   2  14  ...    2022-03-15           20        None       3      ELC
# 574  82  16  12  ...    2021-04-19           19        None       3      ELC
# 582  20   1   3  ...    2020-03-11           19        None       3      ELC
# 591  81  12  11  ...    2023-04-09           20        None       3      ELC
# 672   1   0   0  ...    2021-03-29           21        None       3      ELC
# 688  39   1   2  ...    2023-05-02           23        None       2      RFA
# 700  23   0   2  ...    2019-08-01           18        None       3      ELC
# 863   1   0   0  ...    2023-06-07           31        None       1      UFA
# 869  28  11   4  ...    2023-04-29           25        None       1      RFA
# 922  36   6   3  ...    2021-07-30           24        None       3      RFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 265  unrestricted       2025  3500000         70    17.43
# 20   unrestricted       2026  9500000         75    19.22
# 35   unrestricted       2027  8800000         75    23.55
# 63   unrestricted       2027  7875000         67    17.88
# 105  unrestricted       2027  6250000         73    18.72
# 201  unrestricted       2026  4750000         76    19.50
# 215  unrestricted       2024  4500000         74    17.98
# 253  unrestricted       2025  4000000         72    15.30
# 265  unrestricted       2025  3500000         70    17.43
# 314    restricted       2027  2900000         71    16.92
# 337  unrestricted       2024  2500000         71    18.80
# 344    restricted       2025  2500000         73    20.83
# 348  unrestricted       2024  2500000         70    15.87
# 359    restricted       2025  2325000         73    17.27
# 388  unrestricted       2024  2000000         71    14.80
# 411    restricted       2024  1525000         73    15.17
# 439    restricted       2025  1250000         75    12.52
# 552    restricted       2024  1491667         78    21.47
# 574    restricted       2025  1744167         72    11.63
# 582    restricted       2024  2444167         71     9.27
# 591    restricted       2025   875000         72    13.22
# 672    restricted       2024   834167         71    10.23
# 688    restricted       2025   825000         76    13.68
# 700    restricted       2024   880000         72     8.52
# 863  unrestricted       2024   775000         76    12.87
# 869  unrestricted       2024   775000         73    16.23
# 922  unrestricted       2024   758333         69    11.18
#
# [27 rows x 48 columns]

# %%
replace(8,265)
# Out:
#            PLAYER  AGE COUNTRY  WEIGHT HEIGHT        POS HANDED  GP   G   A  \
# 265  Alex Kerfoot   28  Canada     185   5'10  LW, C, RW   Left  82  13  32
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 265  ...    2023-07-01           28   M-NTC       2      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 265       2025  3500000         70    17.43
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 9**

# %%
unmatched_name(9)
# Out:
#               Player Team_start Team_end Shoots Pos  GP  G   A   P  +/-  ...  \
# 202  Erik Brannstrom        OTT      OTT      L   D  76  3  17  20    5  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 202    0    0    0    1    0    0  77  3.9    16.58   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(9)
# Out:
#                PLAYER  AGE        COUNTRY  WEIGHT HEIGHT        POS HANDED  \
# 4       Erik Karlsson   33         Sweden     190    6'0         RD  Right
# 161  Joel Eriksson Ek   26         Sweden     210    6'1          C   Left
# 165       Erik Cernak   26          Other     233    6'3         RD  Right
# 246   Erik Gudbranson   31         Canada     217    6'5         RD  Right
# 282      Erik Johnson   35  United States     225    6'4         RD  Right
# 291        Erik Haula   32        Finland     193    6'0      C, LW   Left
# 383   Erik Brännström   23         Sweden     185   5'10  LD/RD, LW   Left
# 686   Erik Gustafsson   31         Sweden     197    6'0         LD   Left
#
#      GP   G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 4    82  11  45  ...    2019-06-17           29     NMC       8      UFA
# 161  77  30  34  ...    2021-07-02           24    None       8      RFA
# 165  69   2  11  ...    2022-07-13           26    None       8      RFA
# 246  78   6  20  ...    2022-07-13           30   M-NTC       4      UFA
# 282  67   5   1  ...    2023-07-01           35    None       1      UFA
# 291  76  16  19  ...    2023-06-23           32     NTC       3      UFA
# 383  76   3  17  ...    2023-07-01           23    None       1      RFA
# 686  76   6  25  ...    2023-07-01           31    None       1      UFA
#
#            EXPIRY  EXP. YEAR       AAV  HEIGHT_in  TOI_min
# 4    unrestricted       2027  11500000         72    24.27
# 161  unrestricted       2029   5250000         73    20.52
# 165  unrestricted       2031   5200000         75    19.18
# 246  unrestricted       2026   4000000         77    19.65
# 282  unrestricted       2024   3250000         76    14.47
# 291  unrestricted       2026   3150000         72    16.87
# 383  unrestricted       2024   2000000         70    16.58
# 686  unrestricted       2024    825000         72    17.38
#
# [8 rows x 48 columns]

# %%
replace(9,383)
# Out:
#               PLAYER  AGE COUNTRY  WEIGHT HEIGHT        POS HANDED  GP  G   A  \
# 383  Erik Brannstrom   23  Sweden     185   5'10  LD/RD, LW   Left  76  3  17
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 383  ...    2023-07-01           23    None       1      RFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 383       2024  2000000         70    16.58
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 10**

# %%
unmatched_name(10)
# Out:
#           Player Team_start Team_end Shoots Pos  GP  G   A   P  +/-  ...  PPG  \
# 209  David Kampf        TOR      TOR      L   C  78  8  11  19   -4  ...    0
#
#      PPP  SHG  SHP  OTG  GWG   S    S%  TOI_min  FOW%
# 209    0    0    0    0    1  79  10.1    13.48  50.9
#
# [1 rows x 24 columns]

# %%
unmatched_matches(10)
# Out:
#                PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP   G    A  \
# 1      Connor McDavid   26  Canada     193    6'1       C   Left  76  32  100
# 5      David Pastrnak   27   Other     194    6'0      RW  Right  82  47   63
# 197      David Perron   35  Canada     200    6'0  RW, LW  Right  76  17   30
# 268      David Savard   32  Canada     234    6'2      RD  Right  60   6   18
# 356       David Kämpf   28   Other     190    6'2       C   Left  78   8   11
# 546     David Jiricek   19   Other     189    6'3      RD  Right  43   1    9
# 879  David Gustafsson   23  Sweden     196    6'2   LW, C   Left  39   3    4
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 1    ...    2017-07-05           21     NMC       8      RFA  unrestricted
# 5    ...    2023-03-02           27     NMC       8      UFA  unrestricted
# 197  ...    2022-07-13           34   M-NTC       2      UFA  unrestricted
# 268  ...    2021-07-28           30    None       4      UFA  unrestricted
# 356  ...    2023-06-28           28   M-NTC       4      UFA  unrestricted
# 546  ...    2022-07-13           18    None       3      ELC    restricted
# 879  ...    2022-08-10           22    None       2      RFA    restricted
#
#      EXP. YEAR       AAV  HEIGHT_in  TOI_min
# 1         2026  12500000         73    21.35
# 5         2031  11250000         72    19.92
# 197       2024   4750000         72    15.62
# 268       2025   3500000         74    20.23
# 356       2027   2400000         74    13.48
# 546       2026   1918333         75    14.58
# 879       2024    775000         74     9.25
#
# [7 rows x 48 columns]

# %%
replace(10,356)
# Out:
#           PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G   A  ...  \
# 356  David Kampf   28   Other     190    6'2   C   Left  78  8  11  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 356    2023-06-28           28   M-NTC       4      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 356       2027  2400000         74    13.48
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 11**

# %%
unmatched_name(11)
# Out:
#           Player Team_start Team_end Shoots Pos  GP  G   A   P  +/-  ...  PPG  \
# 221  Chris Tanev        CGY      DAL      R   D  75  2  17  19   22  ...    0
#
#      PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 221    0    0    0    0    0  56  3.6    19.68   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(11)
# Out:
#                 PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  \
# 217  Christopher Tanev   33         Canada     197    6'2      RD  Right  75
# 271      Brandon Tanev   31         Canada     180    6'0  LW, RW   Left  66
# 101      Chris Kreider   32  United States     217    6'3      LW   Left  82
# 217  Christopher Tanev   33         Canada     197    6'2      RD  Right  75
# 219   Christian Dvorak   27  United States     200    6'1       C   Left  30
# 447  Christian Fischer   26  United States     214    6'2  RW, LW  Right  79
# 784      Chris Tierney   29         Canada     195    6'1       C   Left  52
# 818       Chris Wagner   32  United States     198    6'0   RW, C  Right  13
# 864  Jake Christiansen   23         Canada     195    6'1   LD/RD   Left  12
#
#       G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 217   2  17  ...    2020-10-09           30   M-NTC       4      UFA
# 271   7   9  ...    2019-07-01           27   M-NTC       6      UFA
# 101  39  36  ...    2020-02-24           29     NMC       7      UFA
# 217   2  17  ...    2020-10-09           30   M-NTC       4      UFA
# 219   5   4  ...    2018-08-09           23   M-NTC       6      RFA
# 447   5  14  ...    2023-07-02           26    None       1      UFA
# 784   4   8  ...    2023-07-14           28    None       1      UFA
# 818   1   1  ...    2023-07-01           32    None       1      UFA
# 864   0   2  ...    2023-06-05           23    None       1      RFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 217  unrestricted       2024  4500000         74    19.68
# 271  unrestricted       2025  3500000         72    14.58
# 101  unrestricted       2027  6500000         75    18.78
# 217  unrestricted       2024  4500000         74    19.68
# 219  unrestricted       2025  4450000         73    15.52
# 447  unrestricted       2024  1125000         74    11.40
# 784  unrestricted       2024   775000         73     9.02
# 818  unrestricted       2024   775000         72     7.45
# 864    restricted       2024   775000         73    13.22
#
# [9 rows x 48 columns]

# %%
replace(11,217)
# Out:
#           PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G   A  ...  \
# 217  Chris Tanev   33  Canada     197    6'2  RD  Right  75  2  17  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 217    2020-10-09           30   M-NTC       4      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 217       2024  4500000         74    19.68
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 12**

# %%
unmatched_name(12)
# Out:
#           Player Team_start Team_end Shoots Pos  GP  G   A   P  +/-  ...  PPG  \
# 232  Olli Maatta        DET      DET      L   D  72  4  14  18   14  ...    0
#
#      PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 232    0    0    0    0    0  48  8.3    16.05   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(12)
# Out:
#           PLAYER  AGE  COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G   A  ...  \
# 303  Olli Määttä   28  Finland     206    6'2  LD   Left  72  4  14  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 303    2023-02-16           28    None       2      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 303       2025  3000000         74    16.05
#
# [1 rows x 48 columns]

# %%
replace(12,303)
# Out:
#           PLAYER  AGE  COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G   A  ...  \
# 303  Olli Maatta   28  Finland     206    6'2  LD   Left  72  4  14  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 303    2023-02-16           28    None       2      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 303       2025  3000000         74    16.05
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 13**

# %%
unmatched_name(13)
# Out:
#              Player Team_start Team_end Shoots Pos  GP  G   A   P  +/-  ...  \
# 236  Mikey Anderson        LAK      LAK      L   D  74  2  16  18   22  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 236    0    0    0    1    0    0  89  2.3    20.63   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(13)
# Out:
#                    PLAYER  AGE        COUNTRY  WEIGHT HEIGHT        POS  \
# 151         Josh Anderson   29         Canada     227    6'3     RW, LW
# 235      Michael Anderson   24  United States     194   5'11         LD
# 723         Joey Anderson   25  United States     190   5'11         RW
# 844  Jaret Anderson-Dolan   23         Canada     188   5'11  C, LW, RW
#
#     HANDED  GP  G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  \
# 151  Right  78  9  11  ...    2020-10-08           26   M-NTC       7
# 235   Left  74  2  16  ...    2023-02-15           24    None       8
# 723  Right  55  5  12  ...    2023-06-22           25    None       1
# 844   Left  31  1   3  ...    2023-07-01           23    None       1
#
#      SIGNING        EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 151      RFA  unrestricted       2027  5500000         75    15.45
# 235      RFA  unrestricted       2031  4125000         71    20.62
# 723      RFA  unrestricted       2024   800000         71    13.53
# 844      UFA  unrestricted       2024   775000         71    11.03
#
# [4 rows x 48 columns]

# %%
replace(13,235)
# Out:
#              PLAYER  AGE        COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G   A  \
# 235  Mikey Anderson   24  United States     194   5'11  LD   Left  74  2  16
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 235  ...    2023-02-15           24    None       8      RFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 235       2031  4125000         71    20.62
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 14**

# %%
unmatched_name(14)
# Out:
#              Player Team_start Team_end Shoots Pos  GP  G   A   P  +/-  ...  \
# 248  Juuso Valimaki        ARI      ARI      L   D  68  2  15  17   12  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 248    0    4    0    0    0    0  69  2.9     19.1   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(14)
# Out:
#               PLAYER  AGE  COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G   A  ...  \
# 479   Juuso Välimäki   24  Finland     212    6'2  LD   Left  68  2  15  ...
# 645  Juuso Pärssinen   22  Finland     203    6'2   C   Left  44  8   4  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 479    2023-01-24           24    None       1      RFA  restricted
# 645    2021-05-28           20    None       3      ELC  restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 479       2024  1000000         74    19.08
# 645       2024   925000         74    14.58
#
# [2 rows x 48 columns]

# %%
replace(14,479)
# Out:
#              PLAYER  AGE  COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G   A  ...  \
# 479  Juuso Valimaki   24  Finland     212    6'2  LD   Left  68  2  15  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 479    2023-01-24           24    None       1      RFA  restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 479       2024  1000000         74    19.08
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 15**

# %%
unmatched_name(15)
# Out:
#             Player Team_start Team_end Shoots Pos  GP  G  A   P  +/-  ...  \
# 255  Emil Bemstrom        CBJ      PIT      R   C  56  8  8  16   -5  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 255    4    5    0    0    0    1  83  9.6    11.13  37.5
#
# [1 rows x 24 columns]

# %%
unmatched_matches(15)
# Out:
# /Users/ness/anaconda3/lib/python3.11/site-packages/IPython/core/displayhook.py:281: UserWarning: Output cache limit (currently 1000 entries) hit.
# Flushing oldest 200 entries.
#   warn('Output cache limit (currently {sz} entries) hit.\n'
#                        PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  \
# 556               Emil Andrae   21  Sweden     181    5'9      LD   Left   4
# 560             Emil Bemström   24  Sweden     190    6'0  RW, LW  Right  56
# 564             Emil Heineman   21  Sweden     185    6'1  LW, RW   Left   4
# 596  Emil Martinsen Lilleberg   22   Other     185    6'2      LD   Left  37
#
#      G  A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 556  0  0  ...    2023-03-27           21    None       3      ELC
# 560  8  8  ...    2022-08-03           23    None       2      RFA
# 564  0  0  ...    2022-04-04           20    None       3      ELC
# 596  0  5  ...    2023-06-05           22    None       2      ELC
#
#            EXPIRY  EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 556    restricted       2026  925000         69    13.00
# 560  unrestricted       2024  900000         72    11.13
# 564    restricted       2025  925000         73     9.95
# 596    restricted       2025  950000         74    16.20
#
# [4 rows x 48 columns]

# %%
replace(15,560)
# Out:
#             PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  G  A  ...  \
# 560  Emil Bemstrom   24  Sweden     190    6'0  RW, LW  Right  56  8  8  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 560    2022-08-03           23    None       2      RFA  unrestricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 560       2024  900000         72    11.13
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 16**

# %%
unmatched_name(16)
# Out:
#                Player Team_start Team_end Shoots Pos  GP  G  A   P  +/-  ...  \
# 256  Andre Burakovsky        SEA      SEA      L   L  49  7  9  16  -15  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 256    5    9    0    0    0    1  92  7.6    14.57  50.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(16)
# Out:
#                  PLAYER  AGE        COUNTRY  WEIGHT HEIGHT        POS HANDED  \
# 146    André Burakovsky   28          Other     201    6'3     RW, LW   Left
# 74    Andrei Svechnikov   23         Russia     195    6'2     LW, RW   Left
# 135   Andrew Mangiapane   27         Canada     184   5'10     RW, LW   Left
# 142         Andrew Copp   28  United States     206    6'1  C, LW, RW   Left
# 145     Andrei Kuzmenko   27         Russia     194   5'11     LW, RW  Right
# 227  Andreas Athanasiou   28         Canada     188    6'2     LW, RW   Left
# 257      K'Andre Miller   23  United States     210    6'5         LD   Left
# 320        Andrew Peeke   25  United States     194    6'3         RD  Right
# 471     Andreas Englund   27         Sweden     189    6'3         LD   Left
# 685     Andrew Cogliano   36         Canada     175   5'10         LW   Left
# 899   Andrew Poturalski   29  United States     190   5'10          C  Right
#
#      GP   G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 146  49   7   9  ...    2022-07-13           27   M-NTC       5      UFA
# 74   59  19  33  ...    2021-08-26           21    None       8      RFA
# 135  75  14  26  ...    2022-08-02           26   M-NTC       3      RFA
# 142  79  13  20  ...    2022-07-13           27   M-NTC       5      UFA
# 145  72  22  24  ...    2023-01-26           27   M-NTC       2      UFA
# 227  28   2   7  ...    2023-06-07           28    None       2      UFA
# 257  80   8  22  ...    2023-07-11           23    None       2      RFA
# 320  38   1   9  ...    2022-09-28           25    None       3      RFA
# 471  82   1   9  ...    2023-07-01           27    None       2      UFA
# 685  75   6  13  ...    2023-07-01           36    None       1      UFA
# 899   2   0   0  ...    2022-07-13           28    None       2      UFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 146  unrestricted       2027  5500000         75    14.55
# 74   unrestricted       2029  7750000         74    16.97
# 135  unrestricted       2025  5800000         70    15.98
# 142  unrestricted       2027  5625000         73    16.27
# 145  unrestricted       2025  5500000         71    14.88
# 227  unrestricted       2025  4250000         74    13.08
# 257    restricted       2025  3872000         77    21.55
# 320  unrestricted       2026  2750000         75    16.38
# 471  unrestricted       2025  1000000         75    13.22
# 685  unrestricted       2024   825000         70    10.60
# 899  unrestricted       2024   762500         70     6.87
#
# [11 rows x 48 columns]

# %%
replace(16,146)
# Out:
#                PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  G  A  \
# 146  Andre Burakovsky   28   Other     201    6'3  RW, LW   Left  49  7  9
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 146  ...    2022-07-13           27   M-NTC       5      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 146       2027  5500000         75    14.55
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 17**

# %%
unmatched_name(17)
# Out:
#                  Player Team_start Team_end Shoots Pos  GP  G   A   P  +/-  \
# 259  Nicolas Aube-Kubel        WSH      WSH      R   R  60  6  10  16    4
#
#      ...  PPG  PPP  SHG  SHP  OTG  GWG   S    S%  TOI_min  FOW%
# 259  ...    0    0    0    0    0    0  58  10.3     12.2  33.3
#
# [1 rows x 24 columns]

# %%
unmatched_matches(17)
# Out:
#                   PLAYER  AGE COUNTRY  WEIGHT HEIGHT        POS HANDED  GP  \
# 305          Nicolas Roy   26  Canada     200    6'4      C, RW  Right  70
# 363        Nicolas Hague   24  Canada     221    6'6         LD   Left  73
# 398  Nicolas Deslauriers   32  Canada     219    6'3     LW, RW   Left  60
# 443   Nicolas Aubé-Kubel   27  Canada     187   5'11         RW  Right  60
# 897        Nicolas Petan   28  Canada     175    5'9  C, LW, RW   Left   6
#
#       G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 305  13  28  ...    2022-08-08           25    None       5      RFA
# 363   2  10  ...    2022-10-10           23    None       3      RFA
# 398   1   3  ...    2022-07-13           31   M-NTC       4      UFA
# 443   6  10  ...    2023-03-03           27    None       1      UFA
# 897   0   2  ...    2022-07-13           27    None       2      UFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 305  unrestricted       2027  3000000         76    15.45
# 363    restricted       2025  2294150         78    18.55
# 398  unrestricted       2026  1750000         75     8.13
# 443  unrestricted       2024  1225000         71    12.20
# 897  unrestricted       2024   762500         69    10.83
#
# [5 rows x 48 columns]

# %%
replace(17,443)
# Out:
#                  PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G   A  \
# 443  Nicolas Aube-Kubel   27  Canada     187   5'11  RW  Right  60  6  10
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 443  ...    2023-03-03           27    None       1      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 443       2024  1225000         71     12.2
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 18**

# %%
unmatched_name(18)
# Out:
#          Player Team_start Team_end Shoots Pos  GP  G   A   P  +/-  ...  PPG  \
# 263  Pat Maroon        MIN      BOS      L   L  51  4  12  16  -11  ...    0
#
#      PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 263    1    0    0    0    0  56  7.1    12.85  37.5
#
# [1 rows x 24 columns]

# %%
unmatched_matches(18)
# Out:
#              PLAYER  AGE        COUNTRY  WEIGHT HEIGHT        POS HANDED  GP  \
# 481  Patrick Maroon   35  United States     236    6'2     LW, RW   Left  51
# 37     Patrik Laine   25        Finland     206    6'5  C, RW, LW  Right  18
# 318    Patrick Kane   34  United States     177   5'10         RW   Left  50
# 481  Patrick Maroon   35  United States     236    6'2     LW, RW   Left  51
# 661     Patrik Koch   26          Other     190    6'1          D   Left   1
# 718   Patrick Brown   31  United States     214   5'11      C, RW  Right  11
#
#       G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 481   4  12  ...    2022-02-08           34   M-NTC       2      UFA
# 37    6   3  ...    2022-07-22           24   M-NTC       4      RFA
# 318  20  27  ...    2023-11-28           34     NTC       1      UFA
# 481   4  12  ...    2022-02-08           34   M-NTC       2      UFA
# 661   0   0  ...    2023-06-05           26    None       1      ELC
# 718   0   1  ...    2023-07-01           31    None       2      UFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 481  unrestricted       2024  1000000         74    12.83
# 37   unrestricted       2026  8700000         77    15.22
# 318  unrestricted       2024  2750000         70    18.37
# 481  unrestricted       2024  1000000         74    12.83
# 661  unrestricted       2024   847500         73     9.33
# 718  unrestricted       2025   800000         71     8.82
#
# [6 rows x 48 columns]

# %%
replace(18,481)
# Out:
#          PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  G   A  \
# 481  Pat Maroon   35  United States     236    6'2  LW, RW   Left  51  4  12
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 481  ...    2022-02-08           34   M-NTC       2      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 481       2024  1000000         74    12.83
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 19**

# %%
unmatched_name(19)
# Out:
#                Player Team_start Team_end Shoots Pos  GP  G   A   P  +/-  ...  \
# 266  Martin Fehervary        WSH      WSH      L   D  66  3  13  16   -7  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 266    0    0    0    1    0    0  61  4.9    19.63   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(19)
# Out:
#                        PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS  \
# 160             Alec Martinez   35  United States     209    6'1      LD
# 304              Martin Necas   24          Other     189    6'2      RW
# 330          Martin Fehérváry   23          Other     200    6'2   LD/RD
# 396          Jordan Martinook   30         Canada     196    6'0  LW, RW
# 418               Matt Martin   34         Canada     220    6'3  LW, RW
# 596  Emil Martinsen Lilleberg   22          Other     185    6'2      LD
# 809           Martin Pospisil   23          Other     181    6'2      RW
#
#     HANDED  GP   G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  \
# 160   Left  55   4  13  ...    2021-07-28           33   M-NTC       3
# 304  Right  77  24  29  ...    2022-08-09           23    None       2
# 330   Left  66   3  13  ...    2023-07-04           23    None       3
# 396   Left  82  14  18  ...    2021-07-28           28    None       3
# 418   Left  57   4   4  ...    2021-01-11           31    None       4
# 596   Left  37   0   5  ...    2023-06-05           22    None       2
# 809   Left  63   8  16  ...    2023-07-02           23    None       1
#
#      SIGNING        EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 160      UFA  unrestricted       2024  5250000         73    19.03
# 304      RFA    restricted       2024  3000000         74    17.35
# 330      RFA    restricted       2026  2675000         74    19.62
# 396      UFA  unrestricted       2024  1800000         72    14.63
# 418      UFA  unrestricted       2024  1500000         75     9.30
# 596      ELC    restricted       2025   950000         74    16.20
# 809      RFA    restricted       2024   775000         74    12.72
#
# [7 rows x 48 columns]

# %%
replace(19,330)
# Out:
#                PLAYER  AGE COUNTRY  WEIGHT HEIGHT    POS HANDED  GP  G   A  \
# 330  Martin Fehervary   23   Other     200    6'2  LD/RD   Left  66  3  13
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 330  ...    2023-07-04           23    None       3      RFA  restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 330       2026  2675000         74    19.62
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 20**

# %%
unmatched_name(20)
# Out:
#             Player Team_start Team_end Shoots Pos  GP   G  A   P  +/-  ...  \
# 272  Alex Nylander        PIT      CBJ      R   L  28  11  4  15   -1  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG   S    S%  TOI_min  FOW%
# 272    2    2    0    0    0    2  72  15.3    16.25  47.4
#
# [1 rows x 24 columns]

# %%
unmatched_matches(20)
# Out:
#                   PLAYER  AGE        COUNTRY  WEIGHT HEIGHT        POS HANDED  \
# 91      William Nylander   27         Canada     202    6'0         RW  Right
# 869   Alexander Nylander   25         Canada     192    6'1     RW, LW  Right
# 20         Alex Ovechkin   37         Russia     236    6'3         LW  Right
# 35      Alex Pietrangelo   33         Canada     210    6'3         RD  Right
# 63        Alex DeBrincat   25  United States     165    5'7     LW, RW  Right
# 105         Alex Killorn   33         Canada     199    6'1     RW, LW   Left
# 201            Alex Tuch   27  United States     220    6'4     RW, LW  Right
# 215   Alexander Wennberg   28         Sweden     197    6'2          C   Left
# 253         Alex Iafallo   29  United States     188    6'0     LW, RW   Left
# 265         Alex Kerfoot   28         Canada     185   5'10  LW, C, RW   Left
# 314         Alex Newhook   22         Canada     199   5'11      C, LW   Left
# 337    Alexandre Carrier   26         Canada     174   5'11         RD  Right
# 344    Alexander Romanov   23         Russia     209    6'1         LD   Left
# 348  Alexander Barabanov   29         Russia     192   5'10     RW, LW   Left
# 359    Alexis Lafrenière   21         Canada     193    6'1     LW, RW   Left
# 388       Alex Goligoski   37  United States     185   5'11      LD/RD   Left
# 411     Alexandre Texier   23          Other     192    6'1  LW, C, RW   Left
# 439   Alexey Toropchenko   24         Russia     187    6'3     LW, RW   Left
# 552          Alex Vlasic   22  United States     200    6'6         LD   Left
# 574      Alexander Holtz   21         Sweden     192    6'0     RW, LW  Right
# 582        Alex Turcotte   22  United States     185   5'11          C   Left
# 591      Alex Laferriere   21  United States     173    6'0         RW  Right
# 672         Alex Steeves   23  United States     185   5'11     LW, RW   Left
# 688   Alexander Alexeyev   23         Russia     196    6'4      LD/RD   Left
# 700    Nikita Alexandrov   22          Other     190    6'0          C   Left
# 863        Alex Petrovic   31         Canada     216    6'4         RD  Right
# 869   Alexander Nylander   25         Canada     192    6'1     RW, LW  Right
# 922    Alex Barré-Boulet   26         Canada     168    5'9     RW, LW   Left
#
#      GP   G   A  ...  SIGNING DATE  SIGNING AGE      CLAUSE  LENGTH  SIGNING  \
# 91   82  40  58  ...    2018-12-01           22         NMC       6      RFA
# 869  28  11   4  ...    2023-04-29           25        None       1      RFA
# 20   79  31  34  ...    2021-07-27           35  M-NTC, NMC       5      UFA
# 35   64   4  29  ...    2020-10-12           30         NMC       7      UFA
# 63   82  27  40  ...    2023-07-09           25        None       4      RFA
# 105  63  18  18  ...    2023-07-01           33         NTC       4      UFA
# 201  75  22  37  ...    2018-10-19           23       M-NTC       7      RFA
# 215  79  10  20  ...    2021-07-28           26       M-NTC       3      UFA
# 253  82  11  16  ...    2021-04-12           27        None       4      UFA
# 265  82  13  32  ...    2023-07-01           28       M-NTC       2      UFA
# 314  55  15  19  ...    2023-07-11           22        None       4      RFA
# 337  73   4  16  ...    2023-07-01           26        None       1      RFA
# 344  81   7  15  ...    2022-08-22           22        None       3      RFA
# 348  46   4   9  ...    2022-05-09           28       M-NTC       2      UFA
# 359  82  28  29  ...    2023-08-23           21        None       2      RFA
# 388  36   0  10  ...    2022-03-30           36         NMC       2      UFA
# 411  78  12  18  ...    2021-07-28           21        None       3      RFA
# 439  82  14   7  ...    2023-07-16           24        None       2      RFA
# 552  76   2  14  ...    2022-03-15           20        None       3      ELC
# 574  82  16  12  ...    2021-04-19           19        None       3      ELC
# 582  20   1   3  ...    2020-03-11           19        None       3      ELC
# 591  81  12  11  ...    2023-04-09           20        None       3      ELC
# 672   1   0   0  ...    2021-03-29           21        None       3      ELC
# 688  39   1   2  ...    2023-05-02           23        None       2      RFA
# 700  23   0   2  ...    2019-08-01           18        None       3      ELC
# 863   1   0   0  ...    2023-06-07           31        None       1      UFA
# 869  28  11   4  ...    2023-04-29           25        None       1      RFA
# 922  36   6   3  ...    2021-07-30           24        None       3      RFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 91   unrestricted       2024  6962366         72    19.90
# 869  unrestricted       2024   775000         73    16.23
# 20   unrestricted       2026  9500000         75    19.22
# 35   unrestricted       2027  8800000         75    23.55
# 63   unrestricted       2027  7875000         67    17.88
# 105  unrestricted       2027  6250000         73    18.72
# 201  unrestricted       2026  4750000         76    19.50
# 215  unrestricted       2024  4500000         74    17.98
# 253  unrestricted       2025  4000000         72    15.30
# 265  unrestricted       2025  3500000         70    17.43
# 314    restricted       2027  2900000         71    16.92
# 337  unrestricted       2024  2500000         71    18.80
# 344    restricted       2025  2500000         73    20.83
# 348  unrestricted       2024  2500000         70    15.87
# 359    restricted       2025  2325000         73    17.27
# 388  unrestricted       2024  2000000         71    14.80
# 411    restricted       2024  1525000         73    15.17
# 439    restricted       2025  1250000         75    12.52
# 552    restricted       2024  1491667         78    21.47
# 574    restricted       2025  1744167         72    11.63
# 582    restricted       2024  2444167         71     9.27
# 591    restricted       2025   875000         72    13.22
# 672    restricted       2024   834167         71    10.23
# 688    restricted       2025   825000         76    13.68
# 700    restricted       2024   880000         72     8.52
# 863  unrestricted       2024   775000         76    12.87
# 869  unrestricted       2024   775000         73    16.23
# 922  unrestricted       2024   758333         69    11.18
#
# [28 rows x 48 columns]

# %%
replace(20,869)
# Out:
#             PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP   G  A  ...  \
# 869  Alex Nylander   25  Canada     192    6'1  RW, LW  Right  28  11  4  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 869    2023-04-29           25    None       1      RFA  unrestricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 869       2024  775000         73    16.23
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 21**

# %%
unmatched_name(21)
# Out:
#                  Player Team_start Team_end Shoots Pos  GP  G   A   P  +/-  \
# 281  Frederick Gaudreau        MIN      MIN      R   C  67  5  10  15  -23
#
#      ...  PPG  PPP  SHG  SHP  OTG  GWG    S   S%  TOI_min  FOW%
# 281  ...    2    7    0    0    0    1  105  4.8    13.95  49.9
#
# [1 rows x 24 columns]

# %%
unmatched_matches(21)
# Out:
#                  PLAYER  AGE        COUNTRY  WEIGHT HEIGHT    POS HANDED  GP  \
# 14      Johnny Gaudreau   29  United States     165    5'9     LW   Left  81
# 371  Frédérick Gaudreau   30         Canada     179    6'0  C, LW  Right  67
#
#       G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 14   12  48  ...    2022-07-13           28     NMC       7      UFA
# 371   5  10  ...    2023-04-13           30   M-NTC       5      UFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 14   unrestricted       2029  9750000         69    18.80
# 371  unrestricted       2028  2100000         72    13.93
#
# [2 rows x 48 columns]

# %%
replace(21,371)
# Out:
#                  PLAYER  AGE COUNTRY  WEIGHT HEIGHT    POS HANDED  GP  G   A  \
# 371  Frederick Gaudreau   30  Canada     179    6'0  C, LW  Right  67  5  10
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 371  ...    2023-04-13           30   M-NTC       5      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 371       2028  2100000         72    13.93
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 22**

# %%
unmatched_name(22)
# Out:
#             Player Team_start Team_end Shoots Pos  GP  G  A   P  +/-  ...  \
# 291  Jeremy Lauzon        NSH      NSH      L   D  79  6  8  14   -3  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG    S   S%  TOI_min  FOW%
# 291    0    0    0    0    0    0  103  5.8    18.62   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(22)
# Out:
#             PLAYER  AGE COUNTRY  WEIGHT HEIGHT    POS HANDED  GP  G  A  ...  \
# 387  Jérémy Lauzon   26  Canada     204    6'1  LD/RD   Left  79  6  8  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 387    2022-06-13           25    None       4      RFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 387       2026  2000000         73     18.6
#
# [1 rows x 48 columns]

# %%
replace(22,387)
# Out:
#             PLAYER  AGE COUNTRY  WEIGHT HEIGHT    POS HANDED  GP  G  A  ...  \
# 387  Jeremy Lauzon   26  Canada     204    6'1  LD/RD   Left  79  6  8  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 387    2022-06-13           25    None       4      RFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 387       2026  2000000         73     18.6
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 23**

# %%
unmatched_name(23)
# Out:
#          Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  PPG  \
# 303  Max Lajoie        TOR      TOR      L   D   7  0  1  1    1  ...    0
#
#      PPP  SHG  SHP  OTG  GWG  S   S%  TOI_min  FOW%
# 303    1    0    0    0    0  1  0.0    12.72   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(23)
# Out:
#                PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  \
# 823     Maxime Lajoie   25         Canada     196    6'1      LD   Left   7
# 297          Max Domi   28         Canada     208   5'10   C, RW   Left  80
# 380    Max Pacioretty   34  United States     215    6'2      LW   Left  47
# 437         Max Jones   25  United States     220    6'3  LW, RW   Left  52
# 606   Maxwell Crozier   23         Canada     192    6'2      RD  Right  13
# 703  Maxence Guénette   22         Canada     196    6'3      RD  Right   7
# 754    Maxime Comtois   24         Canada     214    6'2      LW   Left   1
# 769       Max Willman   28  United States     198    6'1      LW   Left  18
# 823     Maxime Lajoie   25         Canada     196    6'1      LD   Left   7
# 913     Max McCormick   31  United States     188   5'11      LW   Left   1
#
#      G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 823  0   1  ...    2023-07-01           25    None       1      UFA
# 297  9  38  ...    2023-07-02           28   M-NTC       1      UFA
# 380  4  19  ...    2023-07-01           34     NMC       1      UFA
# 437  5  10  ...    2021-08-09           23    None       3      RFA
# 606  0   2  ...    2023-03-21           23    None       2      ELC
# 703  0   0  ...    2021-04-03           20    None       3      ELC
# 754  0   1  ...    2024-03-05           24    None       1      UFA
# 769  3   1  ...    2023-10-07           28    None       1      UFA
# 823  0   1  ...    2023-07-01           25    None       1      UFA
# 913  0   0  ...    2022-05-09           30    None       2      UFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 823  unrestricted       2024   775000         73    12.72
# 297  unrestricted       2024  3000000         70    13.78
# 380  unrestricted       2024  4000000         74    14.43
# 437  unrestricted       2024  1295000         75    12.05
# 606    restricted       2025   925000         74    12.93
# 703    restricted       2024   813333         75    13.78
# 754  unrestricted       2024   775000         74    13.07
# 769  unrestricted       2024   775000         73     8.32
# 823  unrestricted       2024   775000         73    12.72
# 913  unrestricted       2024   762500         71     5.63
#
# [10 rows x 48 columns]

# %%
replace(23,823)
# Out:
#          PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 823  Max Lajoie   25  Canada     196    6'1  LD   Left   7  0  1  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 823    2023-07-01           25    None       1      UFA  unrestricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 823       2024  775000         73    12.72
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 24**

# %%
unmatched_name(24)
# Out:
#                  Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  \
# 307  Hardy Haman Aktell        WSH      WSH      L   D   6  0  1  1   -2  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG  S   S%  TOI_min  FOW%
# 307    0    0    0    0    0    0  5  0.0    10.63   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(24)
# Out:
#                  PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 600  Hardy Häman Aktell   24  Sweden     198    6'3  LD   Left   6  0  1  ...
# 600  Hardy Häman Aktell   24  Sweden     198    6'3  LD   Left   6  0  1  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 600    2023-04-27           24    None       1      ELC  restricted
# 600    2023-04-27           24    None       1      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 600       2024  950000         75    10.62
# 600       2024  950000         75    10.62
#
# [2 rows x 48 columns]

# %%
replace(24,600)
# Out:
#                  PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 600  Hardy Haman Aktell   24  Sweden     198    6'3  LD   Left   6  0  1  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 600    2023-04-27           24    None       1      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 600       2024  950000         75    10.62
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 25**

# %%
unmatched_name(25)
# Out:
#           Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  PPG  \
# 310  Calle Rosen        STL      STL      L   D   6  0  1  1   -1  ...    0
#
#      PPP  SHG  SHP  OTG  GWG  S   S%  TOI_min  FOW%
# 310    0    0    0    0    0  5  0.0    12.67   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(25)
# Out:
#              PLAYER  AGE COUNTRY  WEIGHT HEIGHT        POS HANDED  GP   G   A  \
# 373  Calle Järnkrok   31  Sweden     190    6'0  RW, C, LW  Right  52  10  11
# 911     Calle Rosén   29  Sweden     186    6'1         LD   Left   6   0   1
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 373  ...    2022-07-15           30   M-NTC       4      UFA  unrestricted
# 911  ...    2022-06-01           28    None       2      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 373       2026  2100000         72    15.25
# 911       2024   762500         73    12.65
#
# [2 rows x 48 columns]

# %%
replace(25,911)
# Out:
#           PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 911  Calle Rosen   29  Sweden     186    6'1  LD   Left   6  0  1  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 911    2022-06-01           28    None       2      UFA  unrestricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 911       2024  762500         73    12.65
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 26**

# %%
unmatched_name(26)
# Out:
#         Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  PPG  \
# 312  Jan Jenik        ARI      ARI      L   R   5  0  1  1   -1  ...    0
#
#      PPP  SHG  SHP  OTG  GWG  S   S%  TOI_min  FOW%
# 312    0    0    0    0    0  2  0.0     8.38  46.7
#
# [1 rows x 24 columns]

# %%
unmatched_matches(26)
# Out:
#               PLAYER  AGE  COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  G   A  \
# 322        Jan Rutta   32    Other     204    6'2   LD/RD  Right  69  5  14
# 417    Jani Hakanpää   31  Finland     218    6'5      RD  Right  64  2  10
# 477  Mattias Janmark   30   Sweden     195    6'1  LW, RW   Left  71  4   8
# 656   Jansen Harkins   26   Canada     183    6'1      LW   Left  45  0   4
# 770        Jan Jeník   22    Other     171    6'1       C   Left   5  0   1
# 875   Mark Jankowski   28   Canada     212    6'4   C, LW   Left  32  7   8
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 322  ...    2022-07-13           31    None       3      UFA  unrestricted
# 417  ...    2021-07-29           29    None       3      UFA  unrestricted
# 477  ...    2023-06-30           30    None       1      UFA  unrestricted
# 656  ...    2022-07-16           25    None       2      RFA  unrestricted
# 770  ...    2023-09-20           22    None       1      RFA    restricted
# 875  ...    2023-03-13           28    None       1      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 322       2025  2750000         74    19.72
# 417       2024  1500000         77    18.63
# 477       2024  1000000         73    11.88
# 656       2024   850000         73     8.20
# 770       2024   775000         73     8.37
# 875       2024   775000         76    12.67
#
# [6 rows x 48 columns]

# %%
replace(26,770)
# Out:
#         PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 770  Jan Jenik   22   Other     171    6'1   C   Left   5  0  1  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 770    2023-09-20           22    None       1      RFA  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 770       2024  775000         73     8.37
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 27**

# %%
unmatched_name(27)
# Out:
#        Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  PPG  PPP  \
# 315  Aku Raty        ARI      ARI      R   R   1  0  1  1    0  ...    0    0
#
#      SHG  SHP  OTG  GWG  S   S%  TOI_min  FOW%
# 315    0    0    0    0  0  0.0    11.75   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(27)
# Out:
#        PLAYER  AGE  COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 566  Aku Räty   21  Finland     165    6'0   C  Right   1  0  1  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 566    2023-05-03           22    None       2      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 566       2025  925000         72    11.75
#
# [1 rows x 48 columns]

# %%
replace(27,566)
# Out:
#        PLAYER  AGE  COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 566  Aku Raty   21  Finland     165    6'0   C  Right   1  0  1  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 566    2023-05-03           22    None       2      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 566       2025  925000         72    11.75
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 28**

# %%
unmatched_name(28)
# Out:
#              Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  \
# 320  Roby Jarventie        OTT      OTT      L   L   7  0  1  1   -5  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG  S   S%  TOI_min  FOW%
# 320    0    0    0    0    0    0  5  0.0     7.52  31.4
#
# [1 rows x 24 columns]

# %%
unmatched_matches(28)
# Out:
#              PLAYER  AGE  COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 573  Roby Järventie   20  Finland     213    6'3  LW   Left   7  0  1  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 573    2021-04-27           18    None       3      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 573       2025  894167         75     7.52
#
# [1 rows x 48 columns]

# %%
replace(28,573)
# Out:
#              PLAYER  AGE  COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 573  Roby Jarventie   20  Finland     213    6'3  LW   Left   7  0  1  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 573    2021-04-27           18    None       3      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 573       2025  894167         75     7.52
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 29**

# %%
unmatched_name(29)
# Out:
#                  Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  \
# 328  Alexander Petrovic        DAL      DAL      R   D   1  0  0  0   -1  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG  S   S%  TOI_min  FOW%
# 328    0    0    0    0    0    0  2  0.0    12.87   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(29)
# Out:
#                   PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP   G  \
# 863        Alex Petrovic   31  Canada     216    6'4      RD  Right   1   0
# 215   Alexander Wennberg   28  Sweden     197    6'2       C   Left  79  10
# 344    Alexander Romanov   23  Russia     209    6'1      LD   Left  81   7
# 348  Alexander Barabanov   29  Russia     192   5'10  RW, LW   Left  46   4
# 574      Alexander Holtz   21  Sweden     192    6'0  RW, LW  Right  82  16
# 688   Alexander Alexeyev   23  Russia     196    6'4   LD/RD   Left  39   1
#
#       A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 863   0  ...    2023-06-07           31    None       1      UFA
# 215  20  ...    2021-07-28           26   M-NTC       3      UFA
# 344  15  ...    2022-08-22           22    None       3      RFA
# 348   9  ...    2022-05-09           28   M-NTC       2      UFA
# 574  12  ...    2021-04-19           19    None       3      ELC
# 688   2  ...    2023-05-02           23    None       2      RFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 863  unrestricted       2024   775000         76    12.87
# 215  unrestricted       2024  4500000         74    17.98
# 344    restricted       2025  2500000         73    20.83
# 348  unrestricted       2024  2500000         70    15.87
# 574    restricted       2025  1744167         72    11.63
# 688    restricted       2025   825000         76    13.68
#
# [6 rows x 48 columns]

# %%
replace(29,863)
# Out:
#                  PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 863  Alexander Petrovic   31  Canada     216    6'4  RD  Right   1  0  0  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 863    2023-06-07           31    None       1      UFA  unrestricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 863       2024  775000         76    12.87
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 30**

# %%
unmatched_name(30)
# Out:
#           Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  PPG  \
# 336  Robert Hagg        ANA      ANA      L   D   5  0  0  0   -4  ...    0
#
#      PPP  SHG  SHP  OTG  GWG  S   S%  TOI_min  FOW%
# 336    0    0    0    0    0  6  0.0    12.78   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(30)
# Out:
#                  PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  \
# 53        Robert Thomas   23         Canada     188    6'0   C, RW  Right  82
# 72      Jason Robertson   23  United States     194    6'2  LW, RW   Left  82
# 498     Robert Bortuzzo   34         Canada     216    6'4      RD  Right  27
# 739  Nicholas Robertson   21  United States     178    5'9  LW, RW   Left  56
# 802         Robert Hägg   28         Sweden     204    6'2      LD   Left   5
#
#       G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 53   26  60  ...    2022-07-13           23    None       8      RFA
# 72   29  51  ...    2022-10-06           22    None       4      RFA
# 498   0   0  ...    2022-02-08           33    None       2      UFA
# 739  14  13  ...    2019-09-19           17    None       3      ELC
# 802   0   0  ...    2023-07-04           28    None       1      UFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 53   unrestricted       2031  8125000         72    20.95
# 72     restricted       2026  7750000         74    18.32
# 498  unrestricted       2024   950000         76    13.72
# 739    restricted       2024   796667         69    11.37
# 802  unrestricted       2024   775000         74    12.78
#
# [5 rows x 48 columns]

# %%
replace(30,802)
# Out:
#           PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 802  Robert Hagg   28  Sweden     204    6'2  LD   Left   5  0  0  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 802    2023-07-04           28    None       1      UFA  unrestricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 802       2024  775000         74    12.78
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 31**

# %%
unmatched_name(31)
# Out:
#               Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  \
# 361  Marián Studenic        SEA      SEA      L   R   2  0  0  0   -1  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG  S   S%  TOI_min  FOW%
# 361    0    0    0    0    0    0  1  0.0     8.12   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(31)
# Out:
#               PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  G  A  \
# 835  Marian Studenic   24   Other     165    6'0  LW, RW   Left   2  0  0
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 835  ...    2023-07-01           24    None       1      UFA  unrestricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 835       2024  775000         72      8.1
#
# [1 rows x 48 columns]

# %%
replace(31,835)
# Out:
#               PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  G  A  \
# 835  Marián Studenic   24   Other     165    6'0  LW, RW   Left   2  0  0
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 835  ...    2023-07-01           24    None       1      UFA  unrestricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 835       2024  775000         72      8.1
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 32**

# %%
unmatched_name(32)
# Out:
#            Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  PPG  \
# 362  Sammy Walker        MIN      MIN      R   C   4  0  0  0   -3  ...    0
#
#      PPP  SHG  SHP  OTG  GWG  S   S%  TOI_min  FOW%
# 362    0    0    0    0    0  3  0.0     9.37   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(32)
# Out:
#             PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS HANDED  GP   G  \
# 334    Sean Walker   28         Canada     196   5'11   LD/RD  Right  81  10
# 639  Samuel Walker   24  United States     180   5'11  RW, LW  Right   4   0
# 689   Walker Duehr   25  United States     210    6'2      RW  Right  40   2
# 880  Nathan Walker   29          Other     186    5'9      LW   Left  45   7
#
#       A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 334  19  ...    2020-09-11           25    None       4      RFA
# 639   0  ...    2022-08-18           23    None       2      ELC
# 689   5  ...    2023-04-24           25    None       2      RFA
# 880   6  ...    2022-07-14           29    None       1      UFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 334  unrestricted       2024  2650000         71    19.22
# 639    restricted       2024   925000         71     9.35
# 689  unrestricted       2025   825000         74     8.12
# 880  unrestricted       2024   775000         69    10.80
#
# [4 rows x 48 columns]

# %%
replace(32,639)
# Out:
#            PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  G  A  \
# 639  Sammy Walker   24  United States     180   5'11  RW, LW  Right   4  0  0
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 639  ...    2022-08-18           23    None       2      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 639       2024  925000         71     9.35
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 33**

# %%
unmatched_name(33)
# Out:
#          Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  PPG  \
# 372  Sam Poulin        PIT      PIT      L   R   3  0  0  0   -1  ...    0
#
#      PPP  SHG  SHP  OTG  GWG  S   S%  TOI_min  FOW%
# 372    0    0    0    0    0  2  0.0     7.78  41.7
#
# [1 rows x 24 columns]

# %%
unmatched_matches(33)
# Out:
#                  PLAYER  AGE        COUNTRY  WEIGHT HEIGHT        POS HANDED  \
# 624       Samuel Poulin   22         Canada     208    6'1      C, LW   Left
# 98         Sam Reinhart   27         Canada     194    6'1         RW  Right
# 186       Samuel Girard   25         Canada     170   5'10      LD/RD   Left
# 221         Sam Bennett   27         Canada     195    6'1          C   Left
# 226  Mattias Samuelsson   23  United States     218    6'4         LD   Left
# 422       Dylan Samberg   24  United States     190    6'3         LD   Left
# 446        Sam Lafferty   28  United States     205    6'2  RW, C, LW  Right
# 478        Samuel Blais   27         Canada     205    6'2     LW, RW   Left
# 499       Sam Colangelo   21  United States     205    6'2         RW  Right
# 505  Mackie Samoskevich   20  United States     190   5'11         RW  Right
# 624       Samuel Poulin   22         Canada     208    6'1      C, LW   Left
# 639        Sammy Walker   24  United States     180   5'11     RW, LW  Right
# 653           Sam Steel   25         Canada     189   5'11      C, LW   Left
# 654        Sam Malinski   24  United States     190   5'11         RD  Right
# 657         Sam Carrick   31         Canada     197    6'0      C, RW  Right
# 724       Samuel Bolduc   22         Canada     210    6'4         LD   Left
# 761      Samuel Laberge   26         Canada     205    6'2          C   Left
# 763          Sam Gagner   33         Canada     200   5'11      RW, C  Right
# 796       Samuel Fagemo   23         Sweden     190    6'0     LW, RW  Right
#
#      GP   G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 624   3   0   0  ...    2019-09-22           18    None       3      ELC
# 98   82  57  37  ...    2021-08-11           25    None       3      RFA
# 186  59   3  15  ...    2019-07-31           22    None       7      RFA
# 221  69  20  21  ...    2021-07-26           25    None       4      RFA
# 226  41   1   6  ...    2022-10-12           23    None       7      RFA
# 422  78   1  17  ...    2023-07-05           24    None       2      RFA
# 446  79  13  11  ...    2022-04-29           27    None       2      UFA
# 478  53   1   6  ...    2023-03-02           27    None       1      UFA
# 499   3   1   0  ...    2024-04-11           21    None       2      ELC
# 505   7   0   0  ...    2023-05-08           19    None       3      ELC
# 624   3   0   0  ...    2019-09-22           18    None       3      ELC
# 639   4   0   0  ...    2022-08-18           23    None       2      ELC
# 653  77   9  15  ...    2023-07-01           25    None       1      UFA
# 654  23   3   7  ...    2023-03-30           24    None       2      UFA
# 657  77  10   6  ...    2022-04-26           30    None       2      UFA
# 724  34   2   3  ...    2023-06-20           22    None       2      RFA
# 761   2   0   0  ...    2023-11-25           26    None       1      UFA
# 763  28   5   5  ...    2023-10-31           33    None       1      UFA
# 796   8   1   0  ...    2023-07-06           23    None       1      RFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 624    restricted       2024   863333         73     7.78
# 98   unrestricted       2024  6500000         73    20.28
# 186  unrestricted       2027  5000000         70    19.37
# 221  unrestricted       2025  4425000         73    16.60
# 226  unrestricted       2030  4285714         76    20.50
# 422    restricted       2025  1400000         75    15.62
# 446  unrestricted       2024  1150000         74    11.87
# 478  unrestricted       2024  1000000         74     9.68
# 499    restricted       2025  1300000         74    12.55
# 505    restricted       2025   925000         71    12.03
# 624    restricted       2024   863333         73     7.78
# 639    restricted       2024   925000         71     9.35
# 653  unrestricted       2024   850000         71    13.23
# 654    restricted       2025   850000         71    14.22
# 657  unrestricted       2024   850000         72    12.22
# 724    restricted       2025   800000         76    13.13
# 761  unrestricted       2024   775000         74     3.08
# 763  unrestricted       2024   775000         71    10.20
# 796    restricted       2024   775000         72     9.18
#
# [19 rows x 48 columns]

# %%
replace(33,624)
# Out:
#          PLAYER  AGE COUNTRY  WEIGHT HEIGHT    POS HANDED  GP  G  A  ...  \
# 624  Sam Poulin   22  Canada     208    6'1  C, LW   Left   3  0  0  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 624    2019-09-22           18    None       3      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 624       2024  863333         73     7.78
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 34**

# %%
unmatched_name(34)
# Out:
#                 Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  \
# 373  Victor Soderstrom        ARI      ARI      R   D   3  0  0  0   -1  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG  S   S%  TOI_min  FOW%
# 373    0    0    0    0    0    0  1  0.0    15.18   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(34)
# Out:
#                 PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP   G   A  \
# 67       Victor Hedman   32  Sweden     229    6'6      LD   Left  78  13  63
# 200    Victor Olofsson   27  Sweden     183   5'11  RW, LW   Left  51   7   8
# 628  Victor Söderström   22  Sweden     182    6'0      RD  Right   3   0   0
# 799        Victor Mete   25  Canada     187    5'9   LD/RD   Left   1   0   0
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 67   ...    2016-07-01           25   M-NTC       8      UFA  unrestricted
# 200  ...    2022-07-13           26    None       2      RFA  unrestricted
# 628  ...    2019-07-07           18    None       3      ELC    restricted
# 799  ...    2023-07-05           25    None       1      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 67        2025  7875000         78    24.80
# 200       2024  4750000         71    11.57
# 628       2024  1523333         72    15.18
# 799       2024   775000         69    10.87
#
# [4 rows x 48 columns]

# %%
replace(34,628)
# Out:
#                 PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 628  Victor Soderstrom   22  Sweden     182    6'0  RD  Right   3  0  0  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 628    2019-07-07           18    None       3      ELC  restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 628       2024  1523333         72    15.18
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 35**

# %%
unmatched_name(35)
# Out:
#               Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  \
# 374  Tobias Bjornfot        LAK      FLA      L   D   4  0  0  0   -2  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG  S   S%  TOI_min  FOW%
# 374    0    0    0    0    0    0  1  0.0    13.82   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(35)
# Out:
#               PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 793  Tobias Björnfot   22  Sweden     202    6'0  LD   Left   4  0  0  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 793    2023-07-07           22    None       2      RFA  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 793       2025  775000         72     13.8
#
# [1 rows x 48 columns]

# %%
replace(35,793)
# Out:
#               PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 793  Tobias Bjornfot   22  Sweden     202    6'0  LD   Left   4  0  0  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 793    2023-07-07           22    None       2      RFA  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 793       2025  775000         72     13.8
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 36**

# %%
unmatched_name(36)
# Out:
#                Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  \
# 376  Maxence Guenette        OTT      OTT      R   D   7  0  0  0   -1  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG  S   S%  TOI_min  FOW%
# 376    0    0    0    0    0    0  6  0.0    13.78   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(36)
# Out:
#                PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 703  Maxence Guénette   22  Canada     196    6'3  RD  Right   7  0  0  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 703    2021-04-03           20    None       3      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 703       2024  813333         75    13.78
#
# [1 rows x 48 columns]

# %%
replace(36,703)
# Out:
#                PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 703  Maxence Guenette   22  Canada     196    6'3  RD  Right   7  0  0  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 703    2021-04-03           20    None       3      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 703       2024  813333         75    13.78
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 37**

# %%
unmatched_name(37)
# Out:
#          Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  PPG  \
# 394  Isak Rosen        BUF      BUF      L   R   7  0  0  0   -3  ...    0
#
#      PPP  SHG  SHP  OTG  GWG  S   S%  TOI_min  FOW%
# 394    0    0    0    0    0  8  0.0     8.58  16.7
#
# [1 rows x 24 columns]

# %%
unmatched_matches(37)
# Out:
#           PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 911  Calle Rosen   29  Sweden     186    6'1  LD   Left   6  0  1  ...
# 567   Isak Rosén   20  Sweden     156   5'11  RW   Left   7  0  0  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 911    2022-06-01           28    None       2      UFA  unrestricted
# 567    2022-05-31           19    None       3      ELC    restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 911       2024   762500         73    12.65
# 567       2026  1419167         71     8.58
#
# [2 rows x 48 columns]

# %%
replace(37,567)
# Out:
#          PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 567  Isak Rosen   20  Sweden     156   5'11  RW   Left   7  0  0  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 567    2022-05-31           19    None       3      ELC  restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 567       2026  1419167         71     8.58
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 38**

# %%
unmatched_name(38)
# Out:
#               Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  \
# 426  Jonas Rondbjerg        VGK      VGK      L   R  20  1  2  3    2  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 426    0    0    0    0    0    0  25  4.0    11.28   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(38)
# Out:
#                  PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  G   A  \
# 122        Jonas Brodin   29  Sweden     194    6'1      LD   Left  62  7  20
# 276  Jonas Siegenthaler   26   Other     210    6'3      LD   Left  57  1   8
# 888     Jonas Røndbjerg   24   Other     176    6'0  LW, RW   Left  20  1   2
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 122  ...    2020-09-15           27     NMC       7      UFA  unrestricted
# 276  ...    2022-07-26           26    None       5      RFA  unrestricted
# 888  ...    2022-07-13           23    None       3      RFA    restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 122       2028  6000000         73    23.37
# 276       2028  3400000         75    19.33
# 888       2025   766667         72    11.27
#
# [3 rows x 48 columns]

# %%
replace(38,888)
# Out:
#               PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  G  A  \
# 888  Jonas Rondbjerg   24   Other     176    6'0  LW, RW   Left  20  1  2
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 888  ...    2022-07-13           23    None       3      RFA  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 888       2025  766667         72    11.27
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 39**

# %%
unmatched_name(39)
# Out:
#            Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  PPG  \
# 436  Adam Edstrom        NYR      NYR      L   C  11  2  0  2    2  ...    0
#
#      PPP  SHG  SHP  OTG  GWG  S    S%  TOI_min  FOW%
# 436    0    0    0    0    0  7  28.6     8.42   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(39)
# Out:
#             PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS HANDED  GP   G  \
# 17        Adam Fox   25  United States     181   5'11      RD  Right  72  17
# 134  Adam Henrique   33         Canada     195    6'0   LW, C   Left  82  24
# 139    Adam Pelech   28         Canada     218    6'3      LD   Left  58   1
# 252   Adam Larsson   30         Sweden     208    6'3      RD  Right  81   4
# 285     Adam Lowry   30  United States     210    6'5       C   Left  81  12
# 336   Adam Boqvist   22         Sweden     179   5'11      RD  Right  35   1
# 493  Adam Fantilli   18         Canada     195    6'2       C   Left  49  12
# 581   Adam Beckman   22         Canada     168    6'1      LW   Left  11   0
# 588   Adam Ginning   23         Sweden     206    6'4      LD   Left   9   1
# 660     Adam Raska   21          Other     178   5'10  LW, RW  Right   5   0
# 664   Adam Edström   22         Sweden     210    6'6   C, LW   Left  11   2
# 673    Adam Klapka   22          Other     245    6'8   RW, C  Right   6   1
# 765      Adam Erne   28  United States     212    6'1  LW, RW   Left  24   1
# 857  Adam Gaudette   26  United States     170    6'1   C, RW  Right   2   0
# 889   Adam Ruzicka   24          Other     220    6'4   LW, C   Left  42   3
#
#       A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 17   56  ...    2021-11-01           24    None       7      RFA
# 134  27  ...    2018-07-16           29   M-NTC       5      UFA
# 139  15  ...    2021-08-06           26     NTC       8      RFA
# 252  14  ...    2021-07-21           28   M-NTC       4      UFA
# 285  23  ...    2021-04-16           28   M-NTC       5      UFA
# 336   9  ...    2022-07-06           21    None       3      RFA
# 493  15  ...    2023-07-01           18    None       3      ELC
# 581   2  ...    2020-03-23           19    None       3      ELC
# 588   0  ...    2022-05-17           22    None       2      ELC
# 660   0  ...    2021-05-12           19    None       3      ELC
# 664   0  ...    2022-05-07           21    None       3      ELC
# 673   0  ...    2022-05-16           21    None       2      ELC
# 765   1  ...    2023-10-13           28    None       1      UFA
# 857   0  ...    2023-06-21           26    None       1      RFA
# 889   6  ...    2022-09-21           23    None       2      RFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 17   unrestricted       2029  9500000         71    23.43
# 134  unrestricted       2024  5825000         72    16.83
# 139  unrestricted       2029  5750000         75    20.27
# 252  unrestricted       2025  4000000         75    22.93
# 285  unrestricted       2026  3250000         77    16.10
# 336    restricted       2025  2600000         71    18.28
# 493    restricted       2026  4150000         74    15.70
# 581    restricted       2024   894167         73     9.40
# 588    restricted       2024   925000         76    14.15
# 660    restricted       2024   900000         70     6.80
# 664    restricted       2025   846667         78     8.40
# 673    restricted       2024   832500         80     6.75
# 765  unrestricted       2024   775000         73     7.82
# 857  unrestricted       2024   775000         73     9.80
# 889    restricted       2024   762500         76    10.02
#
# [15 rows x 48 columns]

# %%
replace(39,664)
# Out:
#            PLAYER  AGE COUNTRY  WEIGHT HEIGHT    POS HANDED  GP  G  A  ...  \
# 664  Adam Edstrom   22  Sweden     210    6'6  C, LW   Left  11  2  0  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 664    2022-05-07           21    None       3      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 664       2025  846667         78      8.4
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 40**

# %%
unmatched_name(40)
# Out:
#              Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  \
# 445  Danil Gushchin        SJS      SJS      L   L   4  1  1  2   -2  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG  S    S%  TOI_min  FOW%
# 445    0    0    0    0    0    0  4  25.0    14.68   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(40)
# Out:
#               PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 677  Daniil Gushchin   21  Russia     165    5'8  LW   Left   4  1  1  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 677    2021-05-17           19    None       3      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 677       2025  902500         68    14.68
#
# [1 rows x 48 columns]

# %%
replace(40,677)
# Out:
#              PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 677  Danil Gushchin   21  Russia     165    5'8  LW   Left   4  1  1  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 677    2021-05-17           19    None       3      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 677       2025  902500         68    14.68
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 41**

# %%
unmatched_name(41)
# Out:
#                Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  \
# 446  Vasily Ponomarev        CAR      CAR      L   C   2  1  1  2    1  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG  S     S%  TOI_min  FOW%
# 446    0    0    0    0    0    0  1  100.0     9.68  55.6
#
# [1 rows x 24 columns]

# %%
unmatched_matches(41)
# Out:
#                PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  G  A  \
# 740  Vasili Ponomarev   21  Russia     180   5'10       C   Left   2  1  1
# 530  Vasily Podkolzin   22  Russia     190    6'1  RW, LW   Left  19  0  2
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 740  ...    2020-10-13           18    None       3      ELC  restricted
# 530  ...    2021-05-30           20    None       3      ELC  restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 740       2025   830000         70     9.67
# 530       2024  1775000         73    10.80
#
# [2 rows x 48 columns]

# %%
replace(41,740)
# Out:
#                PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 740  Vasily Ponomarev   21  Russia     180   5'10   C   Left   2  1  1  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 740    2020-10-13           18    None       3      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 740       2025  830000         70     9.67
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 42**

# %%
unmatched_name(42)
# Out:
#           Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  PPG  \
# 449  Liam Ohgren        MIN      MIN      L   L   4  1  1  2    0  ...    0
#
#      PPP  SHG  SHP  OTG  GWG  S    S%  TOI_min  FOW%
# 449    0    0    0    0    1  8  12.5    14.52   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(42)
# Out:
#            PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  G  A  ...  \
# 540   Liam Öhgren   19  Sweden     201    6'1      LW   Left   4  1  1  ...
# 885  Liam O'Brien   28  Canada     215    6'1  LW, RW   Left  75  5  9  ...
# 909    Liam Foudy   23  Canada     174    6'0   LW, C   Left  13  0  3  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 540    2022-07-16           18    None       3      ELC    restricted
# 885    2022-03-06           27    None       2      UFA  unrestricted
# 909    2022-06-17           22    None       2      RFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 540       2027  1410000         73    14.50
# 885       2024   775000         73     9.72
# 909       2024   762500         72     9.97
#
# [3 rows x 48 columns]

# %%
replace(42,540)
# Out:
#           PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 540  Liam Ohgren   19  Sweden     201    6'1  LW   Left   4  1  1  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 540    2022-07-16           18    None       3      ELC  restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 540       2027  1410000         73     14.5
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 43**

# %%
unmatched_name(43)
# Out:
#            Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  PPG  \
# 452  Matt Benning        SJS      SJS      R   D  14  0  2  2   -5  ...    0
#
#      PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 452    0    0    0    0    0  13  0.0    18.48   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(43)
# Out:
#                  PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  \
# 442     Matthew Benning   29         Canada     203    6'1      RD  Right  14
# 3       Auston Matthews   25  United States     215    6'3       C   Left  81
# 16      Matthew Tkachuk   25  United States     202    6'2      RW   Left  80
# 87        Matthew Boldy   22  United States     196    6'2  RW, LW   Left  75
# 110      Mattias Ekholm   33         Sweden     215    6'4   LD/RD   Left  79
# 226  Mattias Samuelsson   23  United States     218    6'4      LD   Left  41
# 255          Matt Dumba   28         Canada     180    6'0      RD  Right  76
# 261       Matt Grzelcyk   29  United States     174    5'9      LD   Left  63
# 293            Matt Roy   28  United States     200    6'1      RD  Right  81
# 300        Matt Duchene   32         Canada     195   5'11   RW, C   Left  80
# 418         Matt Martin   34         Canada     220    6'3  LW, RW   Left  57
# 442     Matthew Benning   29         Canada     203    6'1      RD  Right  14
# 477     Mattias Janmark   30         Sweden     195    6'1  LW, RW   Left  71
# 508       Matthew Knies   20  United States     217    6'3  LW, RW   Left  80
# 511    Matthew Coronato   20  United States     183   5'10      RW  Right  34
# 542      Matthew Savoie   19         Canada     175    5'9       C  Right   1
# 558          Matt Nieto   30  United States     185   5'11  LW, RW   Left  22
# 563       Matty Beniers   20  United States     175    6'2       C   Left  77
# 589      Matthew Kessel   23  United States     205    6'2      RD  Right  39
# 598     Matthew Poitras   19         Canada     177   5'11       C  Right  33
# 695          Matt Rempe   21         Canada     205    6'8   C, RW  Right  17
# 807    Matthew Phillips   25         Canada     140    5'7   RW, C  Right  31
# 837    Matthew Highmore   27         Canada     188   5'11  LW, RW   Left   7
#
#       G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 442   0   2  ...    2022-07-14           28    None       4      UFA
# 3    69  38  ...    2019-02-05           21     NMC       5      RFA
# 16   26  62  ...    2022-07-22           24     NMC       8      RFA
# 87   29  40  ...    2023-01-16           22    None       7      RFA
# 110  11  34  ...    2021-10-13           32    None       4      UFA
# 226   1   6  ...    2022-10-12           23    None       7      RFA
# 255   4   8  ...    2023-08-06           28    None       1      UFA
# 261   2   9  ...    2020-10-17           26    None       4      RFA
# 293   5  20  ...    2021-03-21           26    None       3      RFA
# 300  25  40  ...    2023-07-01           32    None       1      UFA
# 418   4   4  ...    2021-01-11           31    None       4      UFA
# 442   0   2  ...    2022-07-14           28    None       4      UFA
# 477   4   8  ...    2023-06-30           30    None       1      UFA
# 508  15  20  ...    2023-04-09           19    None       3      ELC
# 511   3   6  ...    2023-03-26           19    None       3      ELC
# 542   0   0  ...    2022-07-15           18    None       3      ELC
# 558   1   3  ...    2023-07-01           30    None       2      UFA
# 563  15  22  ...    2022-04-10           18    None       3      ELC
# 589   1   6  ...    2022-03-27           22    None       2      ELC
# 598   5  10  ...    2023-05-05           19    None       3      ELC
# 695   1   1  ...    2021-11-04           19    None       3      ELC
# 807   1   4  ...    2023-07-02           25    None       1      UFA
# 837   0   2  ...    2023-07-01           27    None       1      UFA
#
#            EXPIRY  EXP. YEAR       AAV  HEIGHT_in  TOI_min
# 442  unrestricted       2026   1250000         73    18.47
# 3    unrestricted       2024  11640250         75    20.95
# 16   unrestricted       2030   9500000         74    18.63
# 87   unrestricted       2030   7000000         74    18.90
# 110  unrestricted       2026   6250000         76    21.03
# 226  unrestricted       2030   4285714         76    20.50
# 255  unrestricted       2024   3900000         72    19.73
# 261  unrestricted       2024   3687500         69    17.58
# 293  unrestricted       2024   3150000         73    20.88
# 300  unrestricted       2024   3000000         71    16.75
# 418  unrestricted       2024   1500000         75     9.30
# 442  unrestricted       2026   1250000         73    18.47
# 477  unrestricted       2024   1000000         73    11.88
# 508    restricted       2025    925000         75    13.67
# 511    restricted       2025   1491667         70    12.60
# 542    restricted       2027   1918333         69     3.92
# 558  unrestricted       2025    900000         71    11.60
# 563    restricted       2024   1850000         74    17.95
# 589    restricted       2024    925000         74    16.78
# 598    restricted       2026    950000         71    13.38
# 695    restricted       2025    820000         80     5.62
# 807  unrestricted       2024    775000         67    10.17
# 837  unrestricted       2024    775000         71     7.70
#
# [23 rows x 48 columns]

# %%
replace(43,442)
# Out:
#            PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 442  Matt Benning   29  Canada     203    6'1  RD  Right  14  0  2  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 442    2022-07-14           28    None       4      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 442       2026  1250000         73    18.47
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 44**

# %%
unmatched_name(44)
# Out:
#         Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  PPG  \
# 454  Nic Petan        MIN      MIN      L   C   6  0  2  2   -2  ...    0
#
#      PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 454    1    0    0    0    0  11  0.0    10.83  40.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(44)
# Out:
#                   PLAYER  AGE        COUNTRY  WEIGHT HEIGHT        POS HANDED  \
# 897        Nicolas Petan   28         Canada     175    5'9  C, LW, RW   Left
# 27     Nicklas Bäckström   35         Sweden     206    6'1          C   Left
# 66           Nick Suzuki   23         Canada     212   5'11          C  Right
# 80         Nico Hischier   24          Other     175    6'1          C   Left
# 114    Valeri Nichushkin   28         Russia     210    6'4     RW, LW   Left
# 133        Nick Schmaltz   27  United States     177    6'0      RW, C  Right
# 238          Nick Jensen   32  United States     196    6'1         RD  Right
# 243         Nick Foligno   35  United States     208    6'0  LW, C, RW   Left
# 247           Nick Leddy   32  United States     207    6'0         LD   Left
# 292        Nicholas Paul   28         Canada     219    6'3      C, LW   Left
# 305          Nicolas Roy   26         Canada     200    6'4      C, RW  Right
# 363        Nicolas Hague   24         Canada     221    6'6         LD   Left
# 370        Nick Bjugstad   30  United States     215    6'6      C, RW  Right
# 386           Nico Sturm   28          Other     207    6'3          C   Left
# 398  Nicolas Deslauriers   32         Canada     219    6'3     LW, RW   Left
# 436             Nic Dowd   33  United States     195    6'1          C  Right
# 443   Nicolas Aube-Kubel   27         Canada     187   5'11         RW  Right
# 448          Nick Perbix   25  United States     200    6'4         RD  Right
# 460         Nick Cousins   29         Canada     183   5'11      LW, C   Left
# 690     Nick Blankenburg   25  United States     175    5'9      LD/RD  Right
# 717          Nick Bonino   35  United States     196    6'1      C, LW   Left
# 739   Nicholas Robertson   21  United States     178    5'9     LW, RW   Left
# 883          Nick Seeler   30  United States     201    6'2      LD/RD   Left
# 896        Nick DeSimone   28  United States     190    6'2         RD  Right
# 897        Nicolas Petan   28         Canada     175    5'9  C, LW, RW   Left
#
#      GP   G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 897   6   0   2  ...    2022-07-13           27    None       2      UFA
# 27    8   0   1  ...    2020-01-14           32   M-NTC       5      UFA
# 66   82  33  44  ...    2021-10-12           22    None       8      RFA
# 80   71  27  40  ...    2019-10-18           21    None       7      RFA
# 114  54  28  25  ...    2022-07-11           27     NMC       8      UFA
# 133  79  22  39  ...    2019-03-30           23   M-NTC       7      RFA
# 238  78   1  13  ...    2023-02-28           32    None       3      UFA
# 243  74  17  20  ...    2023-06-27           35    None       1      UFA
# 247  82   3  25  ...    2022-07-13           31     NTC       4      UFA
# 292  82  24  22  ...    2022-07-01           27     NTC       7      UFA
# 305  70  13  28  ...    2022-08-08           25    None       5      RFA
# 363  73   2  10  ...    2022-10-10           23    None       3      RFA
# 370  76  22  23  ...    2023-07-01           30    None       2      UFA
# 386  63   5   8  ...    2022-07-13           27    None       3      UFA
# 398  60   1   3  ...    2022-07-13           31   M-NTC       4      UFA
# 436  64  12  10  ...    2021-11-14           32    None       3      UFA
# 443  60   6  10  ...    2023-03-03           27    None       1      UFA
# 448  77   2  22  ...    2023-01-02           25    None       2      RFA
# 460  69   7   8  ...    2022-07-13           28    None       2      UFA
# 690  12   1   0  ...    2022-07-15           24    None       2      RFA
# 717  45   1   4  ...    2023-07-01           35    None       1      UFA
# 739  56  14  13  ...    2019-09-19           17    None       3      ELC
# 883  71   1  12  ...    2022-05-19           29    None       2      UFA
# 896  34   2   5  ...    2022-07-13           27    None       2      UFA
# 897   6   0   2  ...    2022-07-13           27    None       2      UFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 897  unrestricted       2024   762500         69    10.83
# 27   unrestricted       2025  9200000         73    14.55
# 66   unrestricted       2030  7875000         71    21.25
# 80   unrestricted       2027  7250000         73    19.47
# 114  unrestricted       2030  6125000         76    21.35
# 133  unrestricted       2026  5850000         72    19.17
# 238  unrestricted       2026  4050000         73    19.62
# 243  unrestricted       2024  4000000         72    17.75
# 247  unrestricted       2026  4000000         72    22.35
# 292  unrestricted       2029  3150000         75    17.25
# 305  unrestricted       2027  3000000         76    15.45
# 363    restricted       2025  2294150         78    18.55
# 370  unrestricted       2025  2100000         78    17.43
# 386  unrestricted       2025  2000000         75    14.65
# 398  unrestricted       2026  1750000         75     8.13
# 436  unrestricted       2025  1300000         73    15.20
# 443  unrestricted       2024  1225000         71    12.20
# 448  unrestricted       2025  1125000         76    17.07
# 460  unrestricted       2024  1100000         71    12.18
# 690  unrestricted       2024   825000         69    16.20
# 717  unrestricted       2024   800000         73    12.25
# 739    restricted       2024   796667         69    11.37
# 883  unrestricted       2024   775000         74    16.93
# 896  unrestricted       2024   762500         74    13.47
# 897  unrestricted       2024   762500         69    10.83
#
# [25 rows x 48 columns]

# %%
replace(44,897)
# Out:
#         PLAYER  AGE COUNTRY  WEIGHT HEIGHT        POS HANDED  GP  G  A  ...  \
# 897  Nic Petan   28  Canada     175    5'9  C, LW, RW   Left   6  0  2  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 897    2022-07-13           27    None       2      UFA  unrestricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 897       2024  762500         69    10.83
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 45**

# %%
unmatched_name(45)
# Out:
#         Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  PPG  \
# 458  Bo Groulx        ANA      ANA      L   C  45  0  2  2   -9  ...    0
#
#      PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 458    0    0    0    0    0  32  0.0    12.18  44.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(45)
# Out:
#                     PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS HANDED  \
# 781  Benoit-Olivier Groulx   23          Other     198    6'2       C   Left
# 40               Bo Horvat   28         Canada     215    6'0       C   Left
# 87           Matthew Boldy   22  United States     196    6'2  RW, LW   Left
# 94            Brock Boeser   26  United States     208    6'1      RW  Right
# 254          Evan Bouchard   23         Canada     194    6'3      RD  Right
# 258            Bowen Byram   22         Canada     195    6'0   LD/RD   Left
# 260           Boone Jenner   30         Canada     208    6'2   C, LW   Left
# 329         William Borgen   26  United States     196    6'3      RD  Right
# 336           Adam Boqvist   22         Sweden     179   5'11      RD  Right
# 400            Travis Boyd   29  United States     190    6'0   C, RW  Right
# 498        Robert Bortuzzo   34         Canada     216    6'4      RD  Right
# 519            Bobby Brink   21  United States     165    5'8      RW  Right
# 550       Thomas Bordeleau   21  United States     175   5'10   C, LW   Left
# 575         Mavrik Bourque   21         Canada     178   5'10       C  Right
# 608         Zachary Bolduc   20         Canada     175    6'1      LW   Left
# 659          Zach Bogosian   32  United States     226    6'3      RD  Right
# 717            Nick Bonino   35  United States     196    6'1   C, LW   Left
# 724          Samuel Bolduc   22         Canada     210    6'4      LD   Left
# 787         Jesper Boqvist   24         Sweden     180    6'0   C, LW   Left
# 838         Bokondji Imama   26         Canada     214    6'1      LW   Left
# 849           Shane Bowers   23         Canada     170    6'0       C   Left
# 914           Bobby McMann   27         Canada     220    6'2  RW, LW   Left
# 920         Boris Katchouk   25         Canada     179    6'1      LW   Left
# 922      Alex Barré-Boulet   26         Canada     168    5'9  RW, LW   Left
#
#      GP   G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 781  45   0   2  ...    2023-07-14           23    None       1      RFA
# 40   81  33  35  ...    2023-02-05           28     NTC       8      UFA
# 87   75  29  40  ...    2023-01-16           22    None       7      RFA
# 94   81  40  33  ...    2022-07-01           25    None       3      RFA
# 254  81  18  64  ...    2023-08-24           23    None       2      RFA
# 258  73  11  18  ...    2023-07-01           22    None       2      RFA
# 260  58  22  13  ...    2021-07-28           29   M-NTC       4      UFA
# 329  82   3  22  ...    2023-07-07           26    None       2      RFA
# 336  35   1   9  ...    2022-07-06           21    None       3      RFA
# 400  16   2   6  ...    2022-03-05           28    None       2      UFA
# 498  27   0   0  ...    2022-02-08           33    None       2      UFA
# 519  57  11  12  ...    2022-04-10           19    None       3      ELC
# 550  27   6   5  ...    2022-04-16           19    None       3      ELC
# 575   1   0   0  ...    2021-03-01           19    None       3      ELC
# 608  25   5   4  ...    2021-08-24           18    None       3      ELC
# 659  65   3  11  ...    2021-07-28           30   M-NTC       3      UFA
# 717  45   1   4  ...    2023-07-01           35    None       1      UFA
# 724  34   2   3  ...    2023-06-20           22    None       2      RFA
# 787  47   6   8  ...    2023-07-12           24    None       1      UFA
# 838   6   0   0  ...    2023-07-01           26    None       1      UFA
# 849   8   0   0  ...    2023-06-29           23    None       1      RFA
# 914  56  15   9  ...    2022-04-29           26    None       2      UFA
# 920  59   7   6  ...    2021-07-31           23    None       3      RFA
# 922  36   6   3  ...    2021-07-30           24    None       3      RFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 781  unrestricted       2024   775000         74    12.18
# 40   unrestricted       2031  8500000         72    19.68
# 87   unrestricted       2030  7000000         74    18.90
# 94   unrestricted       2025  6650000         73    18.60
# 254    restricted       2025  3900000         75    22.98
# 258    restricted       2025  3850000         72    20.33
# 260  unrestricted       2026  3750000         74    20.08
# 329  unrestricted       2025  2700000         75    17.58
# 336    restricted       2025  2600000         71    18.28
# 400  unrestricted       2024  1750000         72     9.62
# 498  unrestricted       2024   950000         76    13.72
# 519    restricted       2024  1137500         68    13.78
# 550    restricted       2024   925000         70    15.02
# 575    restricted       2025   894167         70    10.93
# 608    restricted       2026  1275833         73    12.00
# 659  unrestricted       2024   850000         75    17.88
# 717  unrestricted       2024   800000         73    12.25
# 724    restricted       2025   800000         76    13.13
# 787  unrestricted       2024   775000         72    11.15
# 838  unrestricted       2024   775000         73     5.58
# 849    restricted       2024   775000         72     9.45
# 914  unrestricted       2024   762500         74    11.55
# 920  unrestricted       2024   758333         73    11.47
# 922  unrestricted       2024   758333         69    11.18
#
# [24 rows x 48 columns]

# %%
replace(45,781)
# Out:
#         PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 781  Bo Groulx   23   Other     198    6'2   C   Left  45  0  2  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 781    2023-07-14           23    None       1      RFA  unrestricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 781       2024  775000         74    12.18
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 46**

# %%
unmatched_name(46)
# Out:
#              Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  \
# 470  Mikael Pyyhtia        CBJ      CBJ      L   L  17  0  2  2   -5  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 470    0    0    0    0    0    0  22  0.0    13.15  25.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(46)
# Out:
#               PLAYER  AGE  COUNTRY  WEIGHT HEIGHT    POS HANDED  GP   G   A  \
# 156  Mikael Backlund   34   Sweden     200    6'0      C   Left  82  15  24
# 183  Mikael Granlund   31  Finland     185   5'10  C, RW   Left  69  12  48
# 561   Mikael Pyyhtiä   21  Finland     174   5'11      C   Left  17   0   2
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 156  ...    2018-02-16           29     NMC       6      UFA  unrestricted
# 183  ...    2021-07-28           29    None       4      UFA  unrestricted
# 561  ...    2022-05-05           20    None       3      ELC    restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 156       2024  5350000         72    19.23
# 183       2025  5000000         70    20.95
# 561       2025   925000         71    13.15
#
# [3 rows x 48 columns]

# %%
replace(46,561)
# Out:
#              PLAYER  AGE  COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 561  Mikael Pyyhtia   21  Finland     174   5'11   C   Left  17  0  2  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 561    2022-05-05           20    None       3      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 561       2025  925000         71    13.15
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 47**

# %%
unmatched_name(47)
# Out:
#           Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  PPG  \
# 472  Collin Graf        SJS      SJS      R   R   7  0  2  2   -4  ...    0
#
#      PPP  SHG  SHP  OTG  GWG  S   S%  TOI_min  FOW%
# 472    1    0    0    0    0  7  0.0     16.6   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(47)
# Out:
# Empty DataFrame
# Columns: [PLAYER, AGE, COUNTRY, WEIGHT, HEIGHT, POS, HANDED, GP, G, A, P, P/GP, +/-, Sh, Sh%, TOI, ixG, iSh, iCF, iFF, ixG60, iSh60, iCF60, iFF60, SF, SA, SF%, CF, CA, CF%, FF, FA, FF%, xGF, xGA, xGF%, SIGNING TEAM, EXTENSION, SIGNING DATE, SIGNING AGE, CLAUSE, LENGTH, SIGNING, EXPIRY, EXP. YEAR, AAV, HEIGHT_in, TOI_min]
# Index: []
#
# [0 rows x 48 columns]

# %% [markdown]
# there are no matches for 'Collin Graf' in capfriendly

# %%
nhl_follow_up.append({'collin graf missing':'missing from capfriendly - unmatched index 47'})

# %% [markdown]
# **Index 48**

# %%
unmatched_name(48)
# Out:
#               Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  \
# 494  Waltteri Merela        TBL      TBL      R   C  19  1  0  1    2  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 494    0    0    0    0    0    0  17  5.9     9.82  25.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(48)
# Out:
#               PLAYER  AGE  COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 597  Waltteri Merelä   24  Finland     196    6'2  RW  Right  19  1  0  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 597    2023-06-05           24    None       1      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 597       2024  950000         74      9.8
#
# [1 rows x 48 columns]

# %%
replace(48,597)
# Out:
#               PLAYER  AGE  COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 597  Waltteri Merela   24  Finland     196    6'2  RW  Right  19  1  0  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 597    2023-06-05           24    None       1      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 597       2024  950000         74      9.8
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 49**

# %%
unmatched_name(49)
# Out:
#                 Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  \
# 495  Nicklas Backstrom        WSH      WSH      L   C   8  0  1  1   -3  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 495    0    0    0    0    0    0  12  0.0    14.57  52.4
#
# [1 rows x 24 columns]

# %%
unmatched_matches(49)
# Out:
#                PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 27  Nicklas Bäckström   35  Sweden     206    6'1   C   Left   8  0  1  ...
#
#     SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 27    2020-01-14           32   M-NTC       5      UFA  unrestricted
#
#     EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 27       2025  9200000         73    14.55
#
# [1 rows x 48 columns]

# %%
replace(49,27)
# Out:
#                PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 27  Nicklas Backstrom   35  Sweden     206    6'1   C   Left   8  0  1  ...
#
#     SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 27    2020-01-14           32   M-NTC       5      UFA  unrestricted
#
#     EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 27       2025  9200000         73    14.55
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 50**

# %%
unmatched_name(50)
# Out:
#               Player Team_start Team_end Shoots Pos  GP   G   A   P  +/-  ...  \
# 531  Simon Holmstrom        NYI      NYI      L   R  75  15  10  25    2  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG   S    S%  TOI_min  FOW%
# 531    0    0    5    7    0    3  72  20.8    13.32  31.6
#
# [1 rows x 24 columns]

# %%
unmatched_matches(50)
# Out:
#               PLAYER  AGE        COUNTRY  WEIGHT HEIGHT POS HANDED  GP   G  \
# 544      Simon Nemec   19          Other     190    6'0  RD  Right  60   3
# 568  Simon Edvinsson   20         Sweden     198    6'4  LD   Left  16   1
# 625  Simon Holmström   22         Sweden     193    6'0  RW   Left  75  15
# 774     Simon Benoit   24         Canada     208    6'3  LD   Left  64   1
# 896    Nick DeSimone   28  United States     190    6'2  RD  Right  34   2
#
#       A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 544  16  ...    2022-07-14           18    None       3      ELC
# 568   1  ...    2022-04-24           19    None       3      ELC
# 625  10  ...    2019-07-15           18    None       3      ELC
# 774   4  ...    2023-08-28           24    None       1      UFA
# 896   5  ...    2022-07-13           27    None       2      UFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 544    restricted       2026  4168333         72    19.85
# 568    restricted       2026  1744167         76    18.25
# 625    restricted       2024   863333         72    13.32
# 774    restricted       2024   775000         75    17.22
# 896  unrestricted       2024   762500         74    13.47
#
# [5 rows x 48 columns]

# %%
replace(50,625)
# Out:
#               PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP   G   A  ...  \
# 625  Simon Holmstrom   22  Sweden     193    6'0  RW   Left  75  15  10  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 625    2019-07-15           18    None       3      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 625       2024  863333         72    13.32
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 51**

# %%
unmatched_name(51)
# Out:
#           Player Team_start Team_end Shoots Pos  GP  G   A   P  +/-  ...  PPG  \
# 543  Will Borgen        SEA      SEA      R   D  82  3  22  25   -5  ...    0
#
#      PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 543    0    0    0    0    0  97  3.1    17.58   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(51)
# Out:
#                PLAYER  AGE        COUNTRY  WEIGHT HEIGHT    POS HANDED  GP  \
# 329    William Borgen   26  United States     196    6'3     RD  Right  82
# 91   William Nylander   27         Canada     202    6'0     RW  Right  82
# 129  William Karlsson   30         Sweden     195    6'0      C   Left  70
# 329    William Borgen   26  United States     196    6'3     RD  Right  82
# 430   William Carrier   28         Canada     218    6'2     LW   Left  39
# 609    William Eklund   20         Sweden     176   5'10     LW   Left  80
# 679       Will Cuylle   21         Canada     204    6'3     LW   Left  81
# 769       Max Willman   28  United States     198    6'1     LW   Left  18
# 811  William Lockwood   25  United States     172   5'11     RW  Right  26
# 824  William Lagesson   27         Sweden     196    6'2  LD/RD   Left  40
#
#       G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 329   3  22  ...    2023-07-07           26    None       2      RFA
# 91   40  58  ...    2018-12-01           22     NMC       6      RFA
# 129  30  30  ...    2019-06-24           26   M-NTC       8      RFA
# 329   3  22  ...    2023-07-07           26    None       2      RFA
# 430   6   2  ...    2020-02-27           25    None       4      RFA
# 609  16  29  ...    2021-08-14           18    None       3      ELC
# 679  13   8  ...    2021-04-19           19    None       3      ELC
# 769   3   1  ...    2023-10-07           28    None       1      UFA
# 811   0   1  ...    2023-07-02           25    None       2      UFA
# 824   0   4  ...    2023-07-01           27    None       1      UFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 329  unrestricted       2025  2700000         75    17.58
# 91   unrestricted       2024  6962366         72    19.90
# 129  unrestricted       2027  5900000         72    17.60
# 329  unrestricted       2025  2700000         75    17.58
# 430  unrestricted       2024  1400000         74    11.17
# 609    restricted       2026  1713333         70    18.65
# 679    restricted       2025   902500         75    11.12
# 769  unrestricted       2024   775000         73     8.32
# 811  unrestricted       2025   775000         71     8.18
# 824  unrestricted       2024   775000         74    14.78
#
# [10 rows x 48 columns]

# %%
replace(51,329)
# Out:
#           PLAYER  AGE        COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G   A  \
# 329  Will Borgen   26  United States     196    6'3  RD  Right  82  3  22
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 329  ...    2023-07-07           26    None       2      RFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 329       2025  2700000         75    17.58
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 52**

# %%
unmatched_name(52)
# Out:
#               Player Team_start Team_end Shoots Pos  GP   G   A   P  +/-  ...  \
# 560  Evgenii Dadonov        DAL      DAL      L   R  51  12  11  23   -6  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG   S    S%  TOI_min  FOW%
# 560    1    2    0    0    0    3  67  17.9    13.18   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(52)
# Out:
#              PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP   G   A  \
# 366  Evgeni Dadonov   34  Russia     189   5'11  RW, LW   Left  51  12  11
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 366  ...    2023-06-27           34   M-NTC       2      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 366       2025  2250000         71    13.17
#
# [1 rows x 48 columns]

# %%
replace(52,366)
# Out:
#               PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP   G   A  \
# 366  Evgenii Dadonov   34  Russia     189   5'11  RW, LW   Left  51  12  11
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 366  ...    2023-06-27           34   M-NTC       2      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 366       2025  2250000         71    13.17
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 53**

# %%
unmatched_name(53)
# Out:
#              Player Team_start Team_end Shoots Pos  GP   G   A   P  +/-  ...  \
# 585  Calle Jarnkrok        TOR      TOR      R   C  52  10  11  21   16  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG   S    S%  TOI_min  FOW%
# 585    0    1    1    2    1    3  92  10.9    15.27  49.2
#
# [1 rows x 24 columns]

# %%
unmatched_matches(53)
# Out:
#              PLAYER  AGE COUNTRY  WEIGHT HEIGHT        POS HANDED  GP   G   A  \
# 373  Calle Järnkrok   31  Sweden     190    6'0  RW, C, LW  Right  52  10  11
# 911     Calle Rosen   29  Sweden     186    6'1         LD   Left   6   0   1
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 373  ...    2022-07-15           30   M-NTC       4      UFA  unrestricted
# 911  ...    2022-06-01           28    None       2      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 373       2026  2100000         72    15.25
# 911       2024   762500         73    12.65
#
# [2 rows x 48 columns]

# %%
replace(53,373)
# Out:
#              PLAYER  AGE COUNTRY  WEIGHT HEIGHT        POS HANDED  GP   G   A  \
# 373  Calle Jarnkrok   31  Sweden     190    6'0  RW, C, LW  Right  52  10  11
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 373  ...    2022-07-15           30   M-NTC       4      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 373       2026  2100000         72    15.25
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 54**

# %%
unmatched_name(54)
# Out:
#           Player Team_start Team_end Shoots Pos  GP  G   A   P  +/-  ...  PPG  \
# 590  Egor Zamula        PHI      PHI      L   D  66  5  16  21    3  ...    2
#
#      PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 590    9    0    1    0    1  61  8.2    16.05   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(54)
# Out:
#              PLAYER  AGE COUNTRY  WEIGHT HEIGHT    POS HANDED  GP  G   A  ...  \
# 867    Yegor Zamula   23  Russia     170    6'3  LD/RD   Left  66  5  16  ...
# 744  Egor Afanasyev   22  Russia     204    6'2  C, LW   Left   2  0   0  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 867    2023-05-02           23    None       1      RFA  restricted
# 744    2019-10-19           18    None       3      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 867       2024  775000         75    16.05
# 744       2024  896667         74    12.98
#
# [2 rows x 48 columns]

# %%
replace(54,867)
# Out:
#           PLAYER  AGE COUNTRY  WEIGHT HEIGHT    POS HANDED  GP  G   A  ...  \
# 867  Egor Zamula   23  Russia     170    6'3  LD/RD   Left  66  5  16  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 867    2023-05-02           23    None       1      RFA  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 867       2024  775000         75    16.05
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 55**

# %%
unmatched_name(55)
# Out:
#         Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  PPG  \
# 600  Zac Jones        NYR      NYR      L   D  31  2  7  9    1  ...    0
#
#      PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 600    0    0    0    0    1  42  4.8    14.63   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(55)
# Out:
#                PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  \
# 21         Seth Jones   28  United States     209    6'4      RD  Right  67
# 437         Max Jones   25  United States     220    6'3  LW, RW   Left  52
# 704     Zachary Jones   22  United States     175   5'11      LD   Left  31
# 775       Caleb Jones   26  United States     194    6'1   LD/RD   Left  25
# 15      Zach Werenski   25  United States     212    6'2      LD   Left  70
# 150        Zach Hyman   31         Canada     211    6'1  RW, LW  Right  80
# 196       Pavel Zacha   26          Other     210    6'3   C, LW   Left  78
# 325   Zach Whitecloud   26         Canada     209    6'2      RD  Right  61
# 489       Zach Benson   18         Canada     170   5'10      LW   Left  71
# 608    Zachary Bolduc   20         Canada     175    6'1      LW   Left  25
# 643         Zach Dean   20         Canada     176    6'0       C   Left   9
# 659     Zach Bogosian   32  United States     226    6'3      RD  Right  65
# 681       Zach Parise   38  United States     195   5'11      LW   Left  30
# 694    Zack Ostapchuk   20         Canada     203    6'4       C   Left   7
# 704     Zachary Jones   22  United States     175   5'11      LD   Left  31
# 712   Zachary Sanford   28  United States     207    6'4  LW, RW   Left  29
# 767  Zach Aston-Reese   28  United States     204    6'0  LW, RW   Left   3
# 797      Zack MacEwen   26         Canada     205    6'3   RW, C  Right  30
#
#       G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 21    8  23  ...    2021-07-23           27     NMC       8      UFA
# 437   5  10  ...    2021-08-09           23    None       3      RFA
# 704   2   7  ...    2023-06-16           22    None       2      RFA
# 775   0   5  ...    2023-08-10           26    None       1      UFA
# 15   11  46  ...    2021-07-29           24     NMC       6      RFA
# 150  54  23  ...    2021-07-28           29     NMC       7      UFA
# 196  21  38  ...    2023-01-14           26   M-NTC       4      UFA
# 325   2  12  ...    2021-10-28           25    None       6      RFA
# 489  11  19  ...    2023-07-28           18    None       3      ELC
# 608   5   4  ...    2021-08-24           18    None       3      ELC
# 643   0   0  ...    2021-12-02           18    None       3      ELC
# 659   3  11  ...    2021-07-28           30   M-NTC       3      UFA
# 681   5   5  ...    2024-01-26           38    None       1      UFA
# 694   0   0  ...    2021-09-29           18    None       3      ELC
# 704   2   7  ...    2023-06-16           22    None       2      RFA
# 712   0   6  ...    2023-07-14           28    None       1      UFA
# 767   0   0  ...    2023-10-08           28    None       1      UFA
# 797   2   1  ...    2023-07-06           26    None       3      UFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 21   unrestricted       2030  9500000         76    25.48
# 437  unrestricted       2024  1295000         75    12.05
# 704    restricted       2025   812500         71    14.62
# 775  unrestricted       2024   775000         73    12.20
# 15   unrestricted       2028  9583333         74    24.45
# 150  unrestricted       2028  5500000         73    19.50
# 196  unrestricted       2027  4750000         75    18.10
# 325  unrestricted       2028  2750000         74    17.58
# 489    restricted       2026  1600000         70    14.52
# 608    restricted       2026  1275833         73    12.00
# 643    restricted       2026   863333         72    10.55
# 659  unrestricted       2024   850000         75    17.88
# 681  unrestricted       2024   825000         71    12.97
# 694    restricted       2026   880000         76    10.48
# 704    restricted       2025   812500         71    14.62
# 712  unrestricted       2024   800000         76    10.83
# 767  unrestricted       2024   775000         72     5.15
# 797  unrestricted       2026   775000         75     6.38
#
# [18 rows x 48 columns]

# %%
replace(55,704)
# Out:
#         PLAYER  AGE        COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 704  Zac Jones   22  United States     175   5'11  LD   Left  31  2  7  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 704    2023-06-16           22    None       2      RFA  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 704       2025  812500         71    14.62
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 56**

# %%
unmatched_name(56)
# Out:
#                        Player Team_start Team_end Shoots Pos  GP  G  A  P  \
# 626  Pierre-Edouard Bellemare        SEA      SEA      L   L  40  4  3  7
#
#      +/-  ...  PPG  PPP  SHG  SHP  OTG  GWG   S    S%  TOI_min  FOW%
# 626    4  ...    0    0    1    1    0    0  36  11.1     9.83  53.5
#
# [1 rows x 24 columns]

# %%
unmatched_matches(56)
# Out:
#                        PLAYER  AGE COUNTRY  WEIGHT HEIGHT    POS HANDED  GP  \
# 795  Pierre-Édouard Bellemare   38   Other     198    6'0  C, LW   Left  40
#
#      G  A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 795  4  3  ...    2023-07-07           38    None       1      UFA
#
#            EXPIRY  EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 795  unrestricted       2024  775000         72     9.83
#
# [1 rows x 48 columns]

# %%
replace(56,795)
# Out:
#                        PLAYER  AGE COUNTRY  WEIGHT HEIGHT    POS HANDED  GP  \
# 795  Pierre-Edouard Bellemare   38   Other     198    6'0  C, LW   Left  40
#
#      G  A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 795  4  3  ...    2023-07-07           38    None       1      UFA
#
#            EXPIRY  EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 795  unrestricted       2024  775000         72     9.83
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 57**

# %%
unmatched_name(57)
# Out:
#           Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  PPG  \
# 630  Dillon Dube        CGY      CGY      L   C  43  3  4  7  -13  ...    1
#
#      PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 630    1    0    0    0    0  42  7.1    11.17  53.1
#
# [1 rows x 24 columns]

# %%
unmatched_matches(57)
# Out:
#              PLAYER  AGE COUNTRY  WEIGHT HEIGHT        POS HANDED  GP  G   A  \
# 256  Brenden Dillon   32  Canada     225    6'4         LD   Left  77  8  12
# 362     Dillon Dubé   24  Canada     187   5'11  LW, RW, C   Left  43  3   4
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 256  ...    2020-10-06           29    None       4      UFA  unrestricted
# 362  ...    2021-08-26           22    None       3      RFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 256       2024  3900000         76    18.73
# 362       2024  2300000         71    11.15
#
# [2 rows x 48 columns]

# %%
replace(57,362)
# Out:
#           PLAYER  AGE COUNTRY  WEIGHT HEIGHT        POS HANDED  GP  G  A  ...  \
# 362  Dillon Dube   24  Canada     187   5'11  LW, RW, C   Left  43  3  4  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 362    2021-08-26           22    None       3      RFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 362       2024  2300000         71    11.15
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 58**

# %%
unmatched_name(58)
# Out:
#         Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  PPG  \
# 632  Nils Aman        VAN      VAN      L   C  43  3  4  7   -3  ...    0
#
#      PPP  SHG  SHP  OTG  GWG   S    S%  TOI_min  FOW%
# 632    0    0    0    0    0  28  10.7    10.33  45.6
#
# [1 rows x 24 columns]

# %%
unmatched_matches(58)
# Out:
#              PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP   G   A  \
# 451  Nils Hoglander   22  Sweden     185    5'9  LW, RW   Left  80  24  12
# 529  Nils Lundkvist   22  Sweden     187   5'11      RD  Right  59   2  17
# 586       Nils Åman   23  Sweden     179    6'2       C   Left  43   3   4
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 451  ...    2023-07-09           22    None       2      RFA    restricted
# 529  ...    2021-06-03           20    None       3      ELC  unrestricted
# 586  ...    2022-06-07           22    None       2      ELC    restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 451       2025  1100000         69    12.10
# 529       2024  1775000         71    14.10
# 586       2024   925000         74    10.33
#
# [3 rows x 48 columns]

# %%
replace(58,586)
# Out:
#         PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 586  Nils Aman   23  Sweden     179    6'2   C   Left  43  3  4  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 586    2022-06-07           22    None       2      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 586       2024  925000         74    10.33
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 59**

# %%
unmatched_name(59)
# Out:
#           Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  PPG  \
# 640  Sammy Blais        STL      STL      L   L  53  1  6  7  -11  ...    0
#
#      PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 640    0    0    0    0    0  33  3.0     9.68  22.2
#
# [1 rows x 24 columns]

# %%
unmatched_matches(59)
# Out:
#            PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  G  A  \
# 478  Samuel Blais   27         Canada     205    6'2  LW, RW   Left  53  1  6
# 639  Sammy Walker   24  United States     180   5'11  RW, LW  Right   4  0  0
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 478  ...    2023-03-02           27    None       1      UFA  unrestricted
# 639  ...    2022-08-18           23    None       2      ELC    restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 478       2024  1000000         74     9.68
# 639       2024   925000         71     9.35
#
# [2 rows x 48 columns]

# %%
replace(59,478)
# Out:
#           PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  G  A  ...  \
# 478  Sammy Blais   27  Canada     205    6'2  LW, RW   Left  53  1  6  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 478    2023-03-02           27    None       1      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 478       2024  1000000         74     9.68
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 60**

# %%
unmatched_name(60)
# Out:
#           Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  PPG  \
# 654  Jakub Vrana        STL      STL      L   L  21  2  4  6   -7  ...    0
#
#      PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 654    0    0    0    0    0  42  4.8    12.13   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(60)
# Out:
#           PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  G  A  ...  \
# 159  Jakub Vrána   27   Other     195    6'0      LW   Left  21  2  4  ...
# 748  Jakub Lauko   23   Other     179    6'0  LW, RW   Left  60  2  8  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 159    2021-08-10           25    None       3      RFA  unrestricted
# 748    2023-07-05           23    None       2      RFA    restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 159       2024  5250000         72    12.12
# 748       2025   787500         72     9.82
#
# [2 rows x 48 columns]

# %%
replace(60,159)
# Out:
#           PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 159  Jakub Vrana   27   Other     195    6'0  LW   Left  21  2  4  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 159    2021-08-10           25    None       3      RFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 159       2024  5250000         72    12.12
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 61**

# %%
unmatched_name(61)
# Out:
#                    Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  \
# 666  Axel Jonsson-Fjallby        WPG      WPG      L   L  26  2  3  5    6
#
#      ...  PPG  PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 666  ...    0    0    0    0    0    1  23  8.7     8.12  50.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(61)
# Out:
#                    PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  \
# 804  Axel Jonsson-Fjällby   25  Sweden     170    6'0  LW   Left  26  2  3
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 804  ...    2023-07-03           25    None       2      UFA  unrestricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 804       2025  775000         72      8.1
#
# [1 rows x 48 columns]

# %%
replace(61,804)
# Out:
#                    PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  \
# 804  Axel Jonsson-Fjallby   25  Sweden     170    6'0  LW   Left  26  2  3
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 804  ...    2023-07-03           25    None       2      UFA  unrestricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 804       2025  775000         72      8.1
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 62**

# %%
unmatched_name(62)
# Out:
#              Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  \
# 683  Emil Lilleberg        TBL      TBL      L   D  37  0  5  5  -15  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 683    0    0    0    0    0    0  31  0.0     16.2   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(62)
# Out:
#                        PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  \
# 596  Emil Martinsen Lilleberg   22   Other     185    6'2      LD   Left  37
# 556               Emil Andrae   21  Sweden     181    5'9      LD   Left   4
# 560             Emil Bemstrom   24  Sweden     190    6'0  RW, LW  Right  56
# 564             Emil Heineman   21  Sweden     185    6'1  LW, RW   Left   4
# 596  Emil Martinsen Lilleberg   22   Other     185    6'2      LD   Left  37
#
#      G  A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 596  0  5  ...    2023-06-05           22    None       2      ELC
# 556  0  0  ...    2023-03-27           21    None       3      ELC
# 560  8  8  ...    2022-08-03           23    None       2      RFA
# 564  0  0  ...    2022-04-04           20    None       3      ELC
# 596  0  5  ...    2023-06-05           22    None       2      ELC
#
#            EXPIRY  EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 596    restricted       2025  950000         74    16.20
# 556    restricted       2026  925000         69    13.00
# 560  unrestricted       2024  900000         72    11.13
# 564    restricted       2025  925000         73     9.95
# 596    restricted       2025  950000         74    16.20
#
# [5 rows x 48 columns]

# %%
replace(62,596)
# Out:
#              PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 596  Emil Lilleberg   22   Other     185    6'2  LD   Left  37  0  5  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 596    2023-06-05           22    None       2      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 596       2025  950000         74     16.2
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 63**

# %%
unmatched_name(63)
# Out:
#                Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  \
# 686  Jesse Puljujarvi        PIT      PIT      R   R  22  3  1  4    2  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG   S    S%  TOI_min  FOW%
# 686    0    0    0    0    0    0  29  10.3     9.18  16.7
#
# [1 rows x 24 columns]

# %%
unmatched_matches(63)
# Out:
#                PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  \
# 709  Jesse Puljujärvi   25         Sweden     201    6'4      RW  Right  22
# 777      Jesse Ylönen   23  United States     201    6'1  RW, LW  Right  59
#
#      G  A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 709  3  1  ...    2024-02-04           25    None       2      UFA
# 777  4  4  ...    2023-07-31           23    None       1      RFA
#
#            EXPIRY  EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 709  unrestricted       2025  800000         76     9.18
# 777  unrestricted       2024  775000         73    10.23
#
# [2 rows x 48 columns]

# %%
replace(63,709)
# Out:
#                PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 709  Jesse Puljujarvi   25  Sweden     201    6'4  RW  Right  22  3  1  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 709    2024-02-04           25    None       2      UFA  unrestricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 709       2025  800000         76     9.18
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 64**

# %%
unmatched_name(64)
# Out:
#              Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  \
# 692  Louie Belpedio        PHI      PHI      R   D  12  2  2  4    6  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG   S    S%  TOI_min  FOW%
# 692    0    0    0    0    0    1  12  16.7     13.2   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(64)
# Out:
#              PLAYER  AGE        COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  \
# 853  Louis Belpedio   27  United States     196   5'11  RD  Right  12  2  2
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 853  ...    2023-06-24           27    None       2      UFA  unrestricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 853       2025  775000         71     13.2
#
# [1 rows x 48 columns]

# %%
replace(64,853)
# Out:
#              PLAYER  AGE        COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  \
# 853  Louie Belpedio   27  United States     196   5'11  RD  Right  12  2  2
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 853  ...    2023-06-24           27    None       2      UFA  unrestricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 853       2025  775000         71     13.2
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 65**

# %%
unmatched_name(65)
# Out:
#               Player Team_start Team_end Shoots Pos  GP  G  A   P  +/-  ...  \
# 724  Carl Grundstrom        LAK      LAK      L   R  50  8  4  12   -2  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 724    1    1    1    1    0    1  95  8.4    10.93  20.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(65)
# Out:
#               PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  \
# 59      John Carlson   33  United States     217    6'3      RD  Right  82
# 236    Brandon Carlo   26  United States     212    6'5      RD  Right  76
# 435  Carl Grundström   25         Sweden     201    6'0  LW, RW   Left  50
# 492     Leo Carlsson   18         Sweden     193    6'3       C   Left  55
# 642   Declan Carlile   23  United States     190    6'1      LD   Left   1
#
#       G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 59   10  42  ...    2018-06-25           28   M-NTC       8      UFA
# 236   4  10  ...    2021-07-14           24   M-NTC       6      RFA
# 435   8   4  ...    2022-07-11           24    None       2      RFA
# 492  12  17  ...    2023-07-12           18    None       3      ELC
# 642   0   0  ...    2022-03-16           22    None       2      ELC
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 59   unrestricted       2026  8000000         75    25.88
# 236  unrestricted       2027  4100000         77    19.90
# 435    restricted       2024  1300000         72    10.93
# 492    restricted       2026  4200000         75    18.10
# 642    restricted       2024   925000         73    11.45
#
# [5 rows x 48 columns]

# %%
replace(65,435)
# Out:
#               PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  G  A  \
# 435  Carl Grundstrom   25  Sweden     201    6'0  LW, RW   Left  50  8  4
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 435  ...    2022-07-11           24    None       2      RFA  restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 435       2024  1300000         72    10.93
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 66**

# %%
unmatched_name(66)
# Out:
#               Player Team_start Team_end Shoots Pos  GP  G  A   P  +/-  ...  \
# 725  Juuso Parssinen        NSH      NSH      L   C  44  8  4  12   -6  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG   S    S%  TOI_min  FOW%
# 725    2    3    0    0    0    0  54  14.8     14.6  37.5
#
# [1 rows x 24 columns]

# %%
unmatched_matches(66)
# Out:
#               PLAYER  AGE  COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G   A  ...  \
# 479   Juuso Valimaki   24  Finland     212    6'2  LD   Left  68  2  15  ...
# 645  Juuso Pärssinen   22  Finland     203    6'2   C   Left  44  8   4  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 479    2023-01-24           24    None       1      RFA  restricted
# 645    2021-05-28           20    None       3      ELC  restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 479       2024  1000000         74    19.08
# 645       2024   925000         74    14.58
#
# [2 rows x 48 columns]

# %%
replace(66,645)
# Out:
#               PLAYER  AGE  COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 645  Juuso Parssinen   22  Finland     203    6'2   C   Left  44  8  4  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 645    2021-05-28           20    None       3      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 645       2024  925000         74    14.58
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 67**

# %%
unmatched_name(67)
# Out:
#                   Player Team_start Team_end Shoots Pos  GP  G  A   P  +/-  \
# 726  Marc-Edouard Vlasic        SJS      SJS      L   D  57  6  6  12  -27
#
#      ...  PPG  PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 726  ...    0    0    0    0    0    1  72  8.3    16.28   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(67)
# Out:
#                   PLAYER  AGE        COUNTRY  WEIGHT HEIGHT    POS HANDED  GP  \
# 90   Marc-Édouard Vlasic   36         Canada     205    6'1  LD/RD   Left  57
# 552          Alex Vlasic   22  United States     200    6'6     LD   Left  76
#
#      G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 90   6   6  ...    2017-07-01           31   M-NTC       8      UFA
# 552  2  14  ...    2022-03-15           20    None       3      ELC
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 90   unrestricted       2026  7000000         73    16.27
# 552    restricted       2024  1491667         78    21.47
#
# [2 rows x 48 columns]

# %%
replace(67,90)
# Out:
#                  PLAYER  AGE COUNTRY  WEIGHT HEIGHT    POS HANDED  GP  G  A  \
# 90  Marc-Edouard Vlasic   36  Canada     205    6'1  LD/RD   Left  57  6  6
#
#     ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 90  ...    2017-07-01           31   M-NTC       8      UFA  unrestricted
#
#     EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 90       2026  7000000         73    16.27
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 68**

# %%
unmatched_name(68)
# Out:
#          Player Team_start Team_end Shoots Pos  GP  G  A   P  +/-  ...  PPG  \
# 727  A.J. Greer        CGY      CGY      L   L  59  6  6  12   -7  ...    1
#
#      PPP  SHG  SHP  OTG  GWG   S    S%  TOI_min  FOW%
# 727    1    0    0    0    0  57  10.5     8.83  50.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(68)
# Out:
#        PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  G  A  ...  \
# 900  AJ Greer   26  Canada     210    6'3  RW, LW   Left  59  6  6  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 900    2022-07-13           25    None       2      UFA  unrestricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 900       2024  762500         75     8.82
#
# [1 rows x 48 columns]

# %%
replace(68,900)
# Out:
#          PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  G  A  ...  \
# 900  A.J. Greer   26  Canada     210    6'3  RW, LW   Left  59  6  6  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 900    2022-07-13           25    None       2      UFA  unrestricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 900       2024  762500         75     8.82
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 69**

# %%
unmatched_name(69)
# Out:
#            Player Team_start Team_end Shoots Pos  GP  G  A   P  +/-  ...  PPG  \
# 734  Mathew Dumba        ARI      TBL      R   D  76  4  8  12  -18  ...    0
#
#      PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 734    0    0    0    0    0  86  4.7    19.73   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(69)
# Out:
#             PLAYER  AGE COUNTRY  WEIGHT HEIGHT    POS HANDED  GP   G   A  ...  \
# 255     Matt Dumba   28  Canada     180    6'0     RD  Right  76   4   8  ...
# 28   Mathew Barzal   26  Canada     187    6'0  C, RW  Right  80  23  57  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 255    2023-08-06           28    None       1      UFA  unrestricted
# 28     2022-10-04           26    None       8      RFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 255       2024  3900000         72    19.73
# 28        2031  9150000         72    20.12
#
# [2 rows x 48 columns]

# %%
replace(69,255)
# Out:
#            PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 255  Mathew Dumba   28  Canada     180    6'0  RD  Right  76  4  8  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 255    2023-08-06           28    None       1      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 255       2024  3900000         72    19.73
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 70**

# %%
unmatched_name(70)
# Out:
#                   Player Team_start Team_end Shoots Pos  GP  G  A   P  +/-  \
# 743  MacKenzie Entwistle        CHI      CHI      R   R  67  5  6  11  -29
#
#      ...  PPG  PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 743  ...    0    0    0    0    0    1  66  7.6    11.38  43.8
#
# [1 rows x 24 columns]

# %%
unmatched_matches(70)
# Out:
#                   PLAYER  AGE COUNTRY  WEIGHT HEIGHT    POS HANDED  GP   G  \
# 737  Mackenzie Entwistle   23  Canada     181    6'3  LW, C  Right  67   5
# 108     MacKenzie Weegar   29  Canada     200    6'0  LD/RD  Right  82  20
#
#       A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 737   6  ...    2021-08-18           22    None       2      RFA
# 108  32  ...    2022-10-07           29     NTC       8      UFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 737  unrestricted       2024   800000         75    11.38
# 108  unrestricted       2031  6250000         72    22.92
#
# [2 rows x 48 columns]

# %%
replace(70,737)
# Out:
#                   PLAYER  AGE COUNTRY  WEIGHT HEIGHT    POS HANDED  GP  G  A  \
# 737  MacKenzie Entwistle   23  Canada     181    6'3  LW, C  Right  67  5  6
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 737  ...    2021-08-18           22    None       2      RFA  unrestricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 737       2024  800000         75    11.38
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 71**

# %%
unmatched_name(71)
# Out:
#               Player Team_start Team_end Shoots Pos  GP  G  A   P  +/-  ...  \
# 744  Isac Lundestrom        ANA      ANA      L   C  46  5  6  11   -1  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG   S    S%  TOI_min  FOW%
# 744    0    1    1    1    0    0  38  13.2    14.33  44.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(71)
# Out:
#               PLAYER  AGE COUNTRY  WEIGHT HEIGHT    POS HANDED  GP  G  A  ...  \
# 395  Isac Lundeström   23  Sweden     191    6'0  C, LW   Left  46  5  6  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 395    2022-07-25           22    None       2      RFA  restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 395       2024  1800000         72    14.33
#
# [1 rows x 48 columns]

# %%
replace(71,395)
# Out:
#               PLAYER  AGE COUNTRY  WEIGHT HEIGHT    POS HANDED  GP  G  A  ...  \
# 395  Isac Lundestrom   23  Sweden     191    6'0  C, LW   Left  46  5  6  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 395    2022-07-25           22    None       2      RFA  restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 395       2024  1800000         72    14.33
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 72**

# %%
unmatched_name(72)
# Out:
#             Player Team_start Team_end Shoots Pos  GP  G  A   P  +/-  ...  \
# 746  Tony DeAngelo        CAR      CAR      R   D  31  3  8  11   -7  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 746    2    6    0    0    0    0  44  6.8    14.33   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(72)
# Out:
# Empty DataFrame
# Columns: [PLAYER, AGE, COUNTRY, WEIGHT, HEIGHT, POS, HANDED, GP, G, A, P, P/GP, +/-, Sh, Sh%, TOI, ixG, iSh, iCF, iFF, ixG60, iSh60, iCF60, iFF60, SF, SA, SF%, CF, CA, CF%, FF, FA, FF%, xGF, xGA, xGF%, SIGNING TEAM, EXTENSION, SIGNING DATE, SIGNING AGE, CLAUSE, LENGTH, SIGNING, EXPIRY, EXP. YEAR, AAV, HEIGHT_in, TOI_min]
# Index: []
#
# [0 rows x 48 columns]

# %%
nhl_follow_up.append({'Tony DeAngelo':'no match - unmatched index 72'})

# %% [markdown]
# **Index 73**

# %%
unmatched_name(73)
# Out:
#              Player Team_start Team_end Shoots Pos  GP  G  A   P  +/-  ...  \
# 758  Calvin de Haan        TBL      TBL      L   D  59  3  7  10   -9  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 758    0    0    0    0    0    0  56  5.4    16.63   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(73)
# Out:
#              PLAYER  AGE COUNTRY  WEIGHT HEIGHT    POS HANDED  GP  G  A  ...  \
# 806  Calvin De Haan   32  Canada     195    6'1  LD/RD   Left  59  3  7  ...
# 806  Calvin De Haan   32  Canada     195    6'1  LD/RD   Left  59  3  7  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 806    2023-07-02           32    None       1      UFA  unrestricted
# 806    2023-07-02           32    None       1      UFA  unrestricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 806       2024  775000         73    16.62
# 806       2024  775000         73    16.62
#
# [2 rows x 48 columns]

# %%
replace(73,806)
# Out:
#              PLAYER  AGE COUNTRY  WEIGHT HEIGHT    POS HANDED  GP  G  A  ...  \
# 806  Calvin de Haan   32  Canada     195    6'1  LD/RD   Left  59  3  7  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 806    2023-07-02           32    None       1      UFA  unrestricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 806       2024  775000         73    16.62
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 74**

# %%
unmatched_name(74)
# Out:
#          Player Team_start Team_end Shoots Pos  GP  G  A   P  +/-  ...  PPG  \
# 759  Josh Brown        ARI      ARI      R   D  51  3  7  10    2  ...    0
#
#      PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 759    0    0    0    0    1  44  6.8    14.75   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(74)
# Out:
#                PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  \
# 438      Joshua Brown   29         Canada     217    6'5      RD  Right  51
# 718     Patrick Brown   31  United States     214   5'11   C, RW  Right  11
# 843      Connor Brown   29         Canada     186    6'0  RW, LW  Right  71
# 62        Josh Norris   24  United States     199    6'1       C   Left  50
# 112  Joshua Morrissey   28         Canada     195    6'0      LD   Left  81
# 151     Josh Anderson   29         Canada     227    6'3  RW, LW  Right  78
# 212       Josh Manson   31  United States     218    6'3      RD  Right  76
# 438      Joshua Brown   29         Canada     217    6'5      RD  Right  51
# 512         Josh Doan   21  United States     183    6'1      RW  Right  11
# 514       Josh Mahura   25         Canada     190    6'0   LD/RD   Left  30
# 671        Joshua Roy   19         Canada     190    6'0  LW, RW   Left  23
# 691     Dakota Joshua   27  United States     183    6'2      LW   Left  63
#
#       G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 438   3   7  ...    2022-07-13           28    None       2      UFA
# 718   0   1  ...    2023-07-01           31    None       2      UFA
# 843   4   8  ...    2023-07-01           29    None       1      UFA
# 62   16  14  ...    2022-07-14           23    None       8      RFA
# 112  10  59  ...    2019-09-12           25     NMC       8      RFA
# 151   9  11  ...    2020-10-08           26   M-NTC       7      RFA
# 212   8  17  ...    2022-07-13           30     NTC       4      UFA
# 438   3   7  ...    2022-07-13           28    None       2      UFA
# 512   5   4  ...    2023-03-16           21    None       3      ELC
# 514   0   9  ...    2023-02-10           25    None       1      RFA
# 671   4   5  ...    2022-03-30           18    None       3      ELC
# 691  18  14  ...    2022-07-13           26    None       2      UFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 438  unrestricted       2024  1275000         77    14.75
# 718  unrestricted       2025   800000         71     8.82
# 843  unrestricted       2024  4000000         72    12.78
# 62   unrestricted       2030  7950000         73    17.63
# 112  unrestricted       2028  6250000         72    24.17
# 151  unrestricted       2027  5500000         75    15.45
# 212  unrestricted       2026  4500000         75    17.77
# 438  unrestricted       2024  1275000         77    14.75
# 512    restricted       2026   925000         73    12.30
# 514  unrestricted       2024   925000         72    12.58
# 671    restricted       2026   881667         72    12.13
# 691  unrestricted       2024   825000         74    14.38
#
# [12 rows x 48 columns]

# %%
replace(74,438)
# Out:
#          PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 438  Josh Brown   29  Canada     217    6'5  RD  Right  51  3  7  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 438    2022-07-13           28    None       2      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 438       2024  1275000         77    14.75
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 75**

# %%
unmatched_name(75)
# Out:
#                Player Team_start Team_end Shoots Pos  GP  G  A   P  +/-  ...  \
# 760  Gustav Lindstrom        MTL      ANA      R   D  46  3  7  10   12  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG   S    S%  TOI_min  FOW%
# 760    0    0    0    0    0    0  29  10.3     15.4   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(75)
# Out:
#                PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP   G   A  \
# 289    Gustav Nyquist   33  Sweden     179   5'11  LW, RW   Left  81  23  52
# 331   Gustav Forsling   27  Sweden     186    6'0      LD   Left  79  10  29
# 494  Gustav Lindström   24  Sweden     194    6'2      RD  Right  46   3   7
# 851   Gustav Olofsson   28  Sweden     200    6'2      LD   Left   1   0   0
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 289  ...    2023-07-01           33    None       2      UFA  unrestricted
# 331  ...    2021-07-15           25    None       3      RFA  unrestricted
# 494  ...    2023-07-01           24    None       1      UFA  unrestricted
# 851  ...    2023-06-27           28    None       2      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 289       2025  3185000         71    17.73
# 331       2024  2666667         72    22.13
# 494       2024   950000         74    15.40
# 851       2025   775000         74    14.95
#
# [4 rows x 48 columns]

# %%
replace(75,494)
# Out:
#                PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 494  Gustav Lindstrom   24  Sweden     194    6'2  RD  Right  46  3  7  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 494    2023-07-01           24    None       1      UFA  unrestricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 494       2024  950000         74     15.4
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 76**

# %%
unmatched_name(76)
# Out:
#                    Player Team_start Team_end Shoots Pos  GP  G  A   P  +/-  \
# 769  Rafael Harvey-Pinard        MTL      MTL      L   L  45  2  8  10   -2
#
#      ...  PPG  PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 769  ...    0    0    0    1    0    0  26  7.7    12.63  31.7
#
# [1 rows x 24 columns]

# %%
unmatched_matches(76)
# Out:
#                    PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  G  \
# 453  Rafaël Harvey-Pinard   24  Canada     184    5'9  LW, RW   Left  45  2
#
#      A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 453  8  ...    2023-07-03           24    None       2      RFA  restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 453       2025  1100000         69    12.63
#
# [1 rows x 48 columns]

# %%
replace(76,453)
# Out:
#                    PLAYER  AGE COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  G  \
# 453  Rafael Harvey-Pinard   24  Canada     184    5'9  LW, RW   Left  45  2
#
#      A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 453  8  ...    2023-07-03           24    None       2      RFA  restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 453       2025  1100000         69    12.63
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 77**

# %%
unmatched_name(77)
# Out:
#           Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  PPG  \
# 786  Zack Bolduc        STL      STL      L   C  25  5  4  9    0  ...    0
#
#      PPP  SHG  SHP  OTG  GWG   S    S%  TOI_min  FOW%
# 786    0    0    0    0    0  38  13.2    12.02  50.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(77)
# Out:
#              PLAYER  AGE COUNTRY  WEIGHT HEIGHT    POS HANDED  GP  G  A  ...  \
# 608  Zachary Bolduc   20  Canada     175    6'1     LW   Left  25  5  4  ...
# 724   Samuel Bolduc   22  Canada     210    6'4     LD   Left  34  2  3  ...
# 694  Zack Ostapchuk   20  Canada     203    6'4      C   Left   7  0  0  ...
# 797    Zack MacEwen   26  Canada     205    6'3  RW, C  Right  30  2  1  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 608    2021-08-24           18    None       3      ELC    restricted
# 724    2023-06-20           22    None       2      RFA    restricted
# 694    2021-09-29           18    None       3      ELC    restricted
# 797    2023-07-06           26    None       3      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 608       2026  1275833         73    12.00
# 724       2025   800000         76    13.13
# 694       2026   880000         76    10.48
# 797       2026   775000         75     6.38
#
# [4 rows x 48 columns]

# %%
replace(77,608)
# Out:
#           PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 608  Zack Bolduc   20  Canada     175    6'1  LW   Left  25  5  4  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 608    2021-08-24           18    None       3      ELC  restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 608       2026  1275833         73     12.0
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 78**

# %%
unmatched_name(78)
# Out:
#             Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  PPG  \
# 795  Matt Coronato        CGY      CGY      R   R  34  3  6  9  -15  ...    1
#
#      PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 795    1    0    0    0    0  58  5.2    12.62  26.3
#
# [1 rows x 24 columns]

# %%
unmatched_matches(78)
# Out:
#                  PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  \
# 511    Matthew Coronato   20  United States     183   5'10      RW  Right  34
# 3       Auston Matthews   25  United States     215    6'3       C   Left  81
# 16      Matthew Tkachuk   25  United States     202    6'2      RW   Left  80
# 87        Matthew Boldy   22  United States     196    6'2  RW, LW   Left  75
# 110      Mattias Ekholm   33         Sweden     215    6'4   LD/RD   Left  79
# 226  Mattias Samuelsson   23  United States     218    6'4      LD   Left  41
# 261       Matt Grzelcyk   29  United States     174    5'9      LD   Left  63
# 293            Matt Roy   28  United States     200    6'1      RD  Right  81
# 300        Matt Duchene   32         Canada     195   5'11   RW, C   Left  80
# 418         Matt Martin   34         Canada     220    6'3  LW, RW   Left  57
# 442        Matt Benning   29         Canada     203    6'1      RD  Right  14
# 477     Mattias Janmark   30         Sweden     195    6'1  LW, RW   Left  71
# 508       Matthew Knies   20  United States     217    6'3  LW, RW   Left  80
# 511    Matthew Coronato   20  United States     183   5'10      RW  Right  34
# 542      Matthew Savoie   19         Canada     175    5'9       C  Right   1
# 558          Matt Nieto   30  United States     185   5'11  LW, RW   Left  22
# 563       Matty Beniers   20  United States     175    6'2       C   Left  77
# 589      Matthew Kessel   23  United States     205    6'2      RD  Right  39
# 598     Matthew Poitras   19         Canada     177   5'11       C  Right  33
# 695          Matt Rempe   21         Canada     205    6'8   C, RW  Right  17
# 807    Matthew Phillips   25         Canada     140    5'7   RW, C  Right  31
# 837    Matthew Highmore   27         Canada     188   5'11  LW, RW   Left   7
#
#       G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 511   3   6  ...    2023-03-26           19    None       3      ELC
# 3    69  38  ...    2019-02-05           21     NMC       5      RFA
# 16   26  62  ...    2022-07-22           24     NMC       8      RFA
# 87   29  40  ...    2023-01-16           22    None       7      RFA
# 110  11  34  ...    2021-10-13           32    None       4      UFA
# 226   1   6  ...    2022-10-12           23    None       7      RFA
# 261   2   9  ...    2020-10-17           26    None       4      RFA
# 293   5  20  ...    2021-03-21           26    None       3      RFA
# 300  25  40  ...    2023-07-01           32    None       1      UFA
# 418   4   4  ...    2021-01-11           31    None       4      UFA
# 442   0   2  ...    2022-07-14           28    None       4      UFA
# 477   4   8  ...    2023-06-30           30    None       1      UFA
# 508  15  20  ...    2023-04-09           19    None       3      ELC
# 511   3   6  ...    2023-03-26           19    None       3      ELC
# 542   0   0  ...    2022-07-15           18    None       3      ELC
# 558   1   3  ...    2023-07-01           30    None       2      UFA
# 563  15  22  ...    2022-04-10           18    None       3      ELC
# 589   1   6  ...    2022-03-27           22    None       2      ELC
# 598   5  10  ...    2023-05-05           19    None       3      ELC
# 695   1   1  ...    2021-11-04           19    None       3      ELC
# 807   1   4  ...    2023-07-02           25    None       1      UFA
# 837   0   2  ...    2023-07-01           27    None       1      UFA
#
#            EXPIRY  EXP. YEAR       AAV  HEIGHT_in  TOI_min
# 511    restricted       2025   1491667         70    12.60
# 3    unrestricted       2024  11640250         75    20.95
# 16   unrestricted       2030   9500000         74    18.63
# 87   unrestricted       2030   7000000         74    18.90
# 110  unrestricted       2026   6250000         76    21.03
# 226  unrestricted       2030   4285714         76    20.50
# 261  unrestricted       2024   3687500         69    17.58
# 293  unrestricted       2024   3150000         73    20.88
# 300  unrestricted       2024   3000000         71    16.75
# 418  unrestricted       2024   1500000         75     9.30
# 442  unrestricted       2026   1250000         73    18.47
# 477  unrestricted       2024   1000000         73    11.88
# 508    restricted       2025    925000         75    13.67
# 511    restricted       2025   1491667         70    12.60
# 542    restricted       2027   1918333         69     3.92
# 558  unrestricted       2025    900000         71    11.60
# 563    restricted       2024   1850000         74    17.95
# 589    restricted       2024    925000         74    16.78
# 598    restricted       2026    950000         71    13.38
# 695    restricted       2025    820000         80     5.62
# 807  unrestricted       2024    775000         67    10.17
# 837  unrestricted       2024    775000         71     7.70
#
# [22 rows x 48 columns]

# %%
replace(78,511)
# Out:
#             PLAYER  AGE        COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  \
# 511  Matt Coronato   20  United States     183   5'10  RW  Right  34  3  6
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 511  ...    2023-03-26           19    None       3      ELC  restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 511       2025  1491667         70     12.6
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 79**

# %%
unmatched_name(79)
# Out:
#            Player Team_start Team_end Shoots Pos  GP   G   A   P  +/-  ...  \
# 821  Mitch Marner        TOR      TOR      R   R  69  26  59  85   21  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG    S    S%  TOI_min  FOW%
# 821    8   27    1    1    0    2  158  16.5    21.28  25.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(79)
# Out:
#                 PLAYER  AGE        COUNTRY  WEIGHT HEIGHT POS HANDED  GP   G  \
# 8      Mitchell Marner   26         Canada     180    6'0  RW  Right  69  26
# 8      Mitchell Marner   26         Canada     180    6'0  RW  Right  69  26
# 790       Ian Mitchell   24         Canada     175   5'11  RD  Right  13   0
# 800  Mitchell Stephens   26         Canada     193   5'11   C  Right  23   2
# 820   Mitchell Chaffee   25  United States     207    6'0  RW  Right  30   4
#
#       A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 8    59  ...    2019-09-13           22     NMC       6      RFA
# 8    59  ...    2019-09-13           22     NMC       6      RFA
# 790   2  ...    2023-07-10           24    None       1      RFA
# 800   1  ...    2023-07-04           26    None       1      RFA
# 820   3  ...    2023-07-01           25    None       1      UFA
#
#            EXPIRY  EXP. YEAR       AAV  HEIGHT_in  TOI_min
# 8    unrestricted       2025  10903000         72    21.27
# 8    unrestricted       2025  10903000         72    21.27
# 790    restricted       2024    775000         71    15.30
# 800  unrestricted       2024    775000         71     9.05
# 820  unrestricted       2024    775000         72    11.28
#
# [5 rows x 48 columns]

# %%
replace(79,8)
# Out:
#          PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP   G   A  ...  \
# 8  Mitch Marner   26  Canada     180    6'0  RW  Right  69  26  59  ...
#
#    SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 8    2019-09-13           22     NMC       6      RFA  unrestricted
#
#    EXP. YEAR       AAV  HEIGHT_in  TOI_min
# 8       2025  10903000         72    21.27
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 80**

# %%
unmatched_name(80)
# Out:
#          Player Team_start Team_end Shoots Pos  GP   G   A   P  +/-  ...  PPG  \
# 855  Matt Boldy        MIN      MIN      L   L  75  29  40  69    5  ...   10
#
#      PPP  SHG  SHP  OTG  GWG    S    S%  TOI_min  FOW%
# 855   25    0    0    1    7  227  12.8    18.92  42.1
#
# [1 rows x 24 columns]

# %%
unmatched_matches(80)
# Out:
#                  PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  \
# 87        Matthew Boldy   22  United States     196    6'2  RW, LW   Left  75
# 3       Auston Matthews   25  United States     215    6'3       C   Left  81
# 16      Matthew Tkachuk   25  United States     202    6'2      RW   Left  80
# 87        Matthew Boldy   22  United States     196    6'2  RW, LW   Left  75
# 110      Mattias Ekholm   33         Sweden     215    6'4   LD/RD   Left  79
# 226  Mattias Samuelsson   23  United States     218    6'4      LD   Left  41
# 261       Matt Grzelcyk   29  United States     174    5'9      LD   Left  63
# 293            Matt Roy   28  United States     200    6'1      RD  Right  81
# 300        Matt Duchene   32         Canada     195   5'11   RW, C   Left  80
# 418         Matt Martin   34         Canada     220    6'3  LW, RW   Left  57
# 442        Matt Benning   29         Canada     203    6'1      RD  Right  14
# 477     Mattias Janmark   30         Sweden     195    6'1  LW, RW   Left  71
# 508       Matthew Knies   20  United States     217    6'3  LW, RW   Left  80
# 511       Matt Coronato   20  United States     183   5'10      RW  Right  34
# 542      Matthew Savoie   19         Canada     175    5'9       C  Right   1
# 558          Matt Nieto   30  United States     185   5'11  LW, RW   Left  22
# 563       Matty Beniers   20  United States     175    6'2       C   Left  77
# 589      Matthew Kessel   23  United States     205    6'2      RD  Right  39
# 598     Matthew Poitras   19         Canada     177   5'11       C  Right  33
# 695          Matt Rempe   21         Canada     205    6'8   C, RW  Right  17
# 807    Matthew Phillips   25         Canada     140    5'7   RW, C  Right  31
# 837    Matthew Highmore   27         Canada     188   5'11  LW, RW   Left   7
#
#       G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 87   29  40  ...    2023-01-16           22    None       7      RFA
# 3    69  38  ...    2019-02-05           21     NMC       5      RFA
# 16   26  62  ...    2022-07-22           24     NMC       8      RFA
# 87   29  40  ...    2023-01-16           22    None       7      RFA
# 110  11  34  ...    2021-10-13           32    None       4      UFA
# 226   1   6  ...    2022-10-12           23    None       7      RFA
# 261   2   9  ...    2020-10-17           26    None       4      RFA
# 293   5  20  ...    2021-03-21           26    None       3      RFA
# 300  25  40  ...    2023-07-01           32    None       1      UFA
# 418   4   4  ...    2021-01-11           31    None       4      UFA
# 442   0   2  ...    2022-07-14           28    None       4      UFA
# 477   4   8  ...    2023-06-30           30    None       1      UFA
# 508  15  20  ...    2023-04-09           19    None       3      ELC
# 511   3   6  ...    2023-03-26           19    None       3      ELC
# 542   0   0  ...    2022-07-15           18    None       3      ELC
# 558   1   3  ...    2023-07-01           30    None       2      UFA
# 563  15  22  ...    2022-04-10           18    None       3      ELC
# 589   1   6  ...    2022-03-27           22    None       2      ELC
# 598   5  10  ...    2023-05-05           19    None       3      ELC
# 695   1   1  ...    2021-11-04           19    None       3      ELC
# 807   1   4  ...    2023-07-02           25    None       1      UFA
# 837   0   2  ...    2023-07-01           27    None       1      UFA
#
#            EXPIRY  EXP. YEAR       AAV  HEIGHT_in  TOI_min
# 87   unrestricted       2030   7000000         74    18.90
# 3    unrestricted       2024  11640250         75    20.95
# 16   unrestricted       2030   9500000         74    18.63
# 87   unrestricted       2030   7000000         74    18.90
# 110  unrestricted       2026   6250000         76    21.03
# 226  unrestricted       2030   4285714         76    20.50
# 261  unrestricted       2024   3687500         69    17.58
# 293  unrestricted       2024   3150000         73    20.88
# 300  unrestricted       2024   3000000         71    16.75
# 418  unrestricted       2024   1500000         75     9.30
# 442  unrestricted       2026   1250000         73    18.47
# 477  unrestricted       2024   1000000         73    11.88
# 508    restricted       2025    925000         75    13.67
# 511    restricted       2025   1491667         70    12.60
# 542    restricted       2027   1918333         69     3.92
# 558  unrestricted       2025    900000         71    11.60
# 563    restricted       2024   1850000         74    17.95
# 589    restricted       2024    925000         74    16.78
# 598    restricted       2026    950000         71    13.38
# 695    restricted       2025    820000         80     5.62
# 807  unrestricted       2024    775000         67    10.17
# 837  unrestricted       2024    775000         71     7.70
#
# [22 rows x 48 columns]

# %%
replace(80,87)
# Out:
#         PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS HANDED  GP   G   A  \
# 87  Matt Boldy   22  United States     196    6'2  RW, LW   Left  75  29  40
#
#     ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 87  ...    2023-01-16           22    None       7      RFA  unrestricted
#
#     EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 87       2030  7000000         74     18.9
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 81**

# %%
unmatched_name(81)
# Out:
#              Player Team_start Team_end Shoots Pos  GP   G   A   P  +/-  ...  \
# 857  Josh Morrissey        WPG      WPG      L   D  81  10  59  69   34  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG    S   S%  TOI_min  FOW%
# 857    2   19    0    0    0    1  196  5.1    24.18   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(81)
# Out:
#                PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  \
# 112  Joshua Morrissey   28         Canada     195    6'0      LD   Left  81
# 62        Josh Norris   24  United States     199    6'1       C   Left  50
# 112  Joshua Morrissey   28         Canada     195    6'0      LD   Left  81
# 151     Josh Anderson   29         Canada     227    6'3  RW, LW  Right  78
# 212       Josh Manson   31  United States     218    6'3      RD  Right  76
# 438        Josh Brown   29         Canada     217    6'5      RD  Right  51
# 512         Josh Doan   21  United States     183    6'1      RW  Right  11
# 514       Josh Mahura   25         Canada     190    6'0   LD/RD   Left  30
# 671        Joshua Roy   19         Canada     190    6'0  LW, RW   Left  23
# 691     Dakota Joshua   27  United States     183    6'2      LW   Left  63
#
#       G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 112  10  59  ...    2019-09-12           25     NMC       8      RFA
# 62   16  14  ...    2022-07-14           23    None       8      RFA
# 112  10  59  ...    2019-09-12           25     NMC       8      RFA
# 151   9  11  ...    2020-10-08           26   M-NTC       7      RFA
# 212   8  17  ...    2022-07-13           30     NTC       4      UFA
# 438   3   7  ...    2022-07-13           28    None       2      UFA
# 512   5   4  ...    2023-03-16           21    None       3      ELC
# 514   0   9  ...    2023-02-10           25    None       1      RFA
# 671   4   5  ...    2022-03-30           18    None       3      ELC
# 691  18  14  ...    2022-07-13           26    None       2      UFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 112  unrestricted       2028  6250000         72    24.17
# 62   unrestricted       2030  7950000         73    17.63
# 112  unrestricted       2028  6250000         72    24.17
# 151  unrestricted       2027  5500000         75    15.45
# 212  unrestricted       2026  4500000         75    17.77
# 438  unrestricted       2024  1275000         77    14.75
# 512    restricted       2026   925000         73    12.30
# 514  unrestricted       2024   925000         72    12.58
# 671    restricted       2026   881667         72    12.13
# 691  unrestricted       2024   825000         74    14.38
#
# [10 rows x 48 columns]

# %%
replace(81,112)
# Out:
#              PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP   G   A  ...  \
# 112  Josh Morrissey   28  Canada     195    6'0  LD   Left  81  10  59  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 112    2019-09-12           25     NMC       8      RFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 112       2028  6250000         72    24.17
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 82**

# %%
unmatched_name(82)
# Out:
#             Player Team_start Team_end Shoots Pos  GP   G   A   P  +/-  ...  \
# 882  Mike Matheson        MTL      MTL      L   D  82  11  51  62  -24  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG    S   S%  TOI_min  FOW%
# 882    5   28    2    2    0    0  187  5.9    25.55   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(82)
# Out:
#                PLAYER  AGE        COUNTRY  WEIGHT HEIGHT POS HANDED  GP   G  \
# 193  Michael Matheson   29         Canada     196    6'2  LD   Left  82  11
# 214      Mike Hoffman   33         Canada     190    6'0  LW   Left  66  10
# 235    Mikey Anderson   24  United States     194   5'11  LD   Left  74   2
# 473       Mike Reilly   29  United States     200    6'1  LD   Left  61   6
#
#       A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 193  51  ...    2017-10-07           24   M-NTC       8      RFA
# 214  13  ...    2021-07-28           31    None       3      UFA
# 235  16  ...    2023-02-15           24    None       8      RFA
# 473  18  ...    2023-07-01           29    None       1      UFA
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 193  unrestricted       2026  4875000         74    25.55
# 214  unrestricted       2024  4500000         72    13.72
# 235  unrestricted       2031  4125000         71    20.62
# 473  unrestricted       2024  1000000         73    17.15
#
# [4 rows x 48 columns]

# %%
replace(82,193)
# Out:
# /Users/ness/anaconda3/lib/python3.11/site-packages/IPython/core/displayhook.py:281: UserWarning: Output cache limit (currently 1000 entries) hit.
# Flushing oldest 200 entries.
#   warn('Output cache limit (currently {sz} entries) hit.\n'
#             PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP   G   A  ...  \
# 193  Mike Matheson   29  Canada     196    6'2  LD   Left  82  11  51  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 193    2017-10-07           24   M-NTC       8      RFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 193       2026  4875000         74    25.55
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 83**

# %%
unmatched_name(83)
# Out:
#           Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  PPG  \
# 908  Matt Savoie        BUF      BUF      R   C   1  0  0  0    0  ...    0
#
#      PPP  SHG  SHP  OTG  GWG  S   S%  TOI_min  FOW%
# 908    0    0    0    0    0  0  0.0     3.92   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(83)
# Out:
#                  PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  \
# 542      Matthew Savoie   19         Canada     175    5'9       C  Right   1
# 3       Auston Matthews   25  United States     215    6'3       C   Left  81
# 16      Matthew Tkachuk   25  United States     202    6'2      RW   Left  80
# 87           Matt Boldy   22  United States     196    6'2  RW, LW   Left  75
# 110      Mattias Ekholm   33         Sweden     215    6'4   LD/RD   Left  79
# 226  Mattias Samuelsson   23  United States     218    6'4      LD   Left  41
# 261       Matt Grzelcyk   29  United States     174    5'9      LD   Left  63
# 293            Matt Roy   28  United States     200    6'1      RD  Right  81
# 300        Matt Duchene   32         Canada     195   5'11   RW, C   Left  80
# 418         Matt Martin   34         Canada     220    6'3  LW, RW   Left  57
# 442        Matt Benning   29         Canada     203    6'1      RD  Right  14
# 477     Mattias Janmark   30         Sweden     195    6'1  LW, RW   Left  71
# 508       Matthew Knies   20  United States     217    6'3  LW, RW   Left  80
# 511       Matt Coronato   20  United States     183   5'10      RW  Right  34
# 542      Matthew Savoie   19         Canada     175    5'9       C  Right   1
# 558          Matt Nieto   30  United States     185   5'11  LW, RW   Left  22
# 563       Matty Beniers   20  United States     175    6'2       C   Left  77
# 589      Matthew Kessel   23  United States     205    6'2      RD  Right  39
# 598     Matthew Poitras   19         Canada     177   5'11       C  Right  33
# 695          Matt Rempe   21         Canada     205    6'8   C, RW  Right  17
# 807    Matthew Phillips   25         Canada     140    5'7   RW, C  Right  31
# 837    Matthew Highmore   27         Canada     188   5'11  LW, RW   Left   7
#
#       G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 542   0   0  ...    2022-07-15           18    None       3      ELC
# 3    69  38  ...    2019-02-05           21     NMC       5      RFA
# 16   26  62  ...    2022-07-22           24     NMC       8      RFA
# 87   29  40  ...    2023-01-16           22    None       7      RFA
# 110  11  34  ...    2021-10-13           32    None       4      UFA
# 226   1   6  ...    2022-10-12           23    None       7      RFA
# 261   2   9  ...    2020-10-17           26    None       4      RFA
# 293   5  20  ...    2021-03-21           26    None       3      RFA
# 300  25  40  ...    2023-07-01           32    None       1      UFA
# 418   4   4  ...    2021-01-11           31    None       4      UFA
# 442   0   2  ...    2022-07-14           28    None       4      UFA
# 477   4   8  ...    2023-06-30           30    None       1      UFA
# 508  15  20  ...    2023-04-09           19    None       3      ELC
# 511   3   6  ...    2023-03-26           19    None       3      ELC
# 542   0   0  ...    2022-07-15           18    None       3      ELC
# 558   1   3  ...    2023-07-01           30    None       2      UFA
# 563  15  22  ...    2022-04-10           18    None       3      ELC
# 589   1   6  ...    2022-03-27           22    None       2      ELC
# 598   5  10  ...    2023-05-05           19    None       3      ELC
# 695   1   1  ...    2021-11-04           19    None       3      ELC
# 807   1   4  ...    2023-07-02           25    None       1      UFA
# 837   0   2  ...    2023-07-01           27    None       1      UFA
#
#            EXPIRY  EXP. YEAR       AAV  HEIGHT_in  TOI_min
# 542    restricted       2027   1918333         69     3.92
# 3    unrestricted       2024  11640250         75    20.95
# 16   unrestricted       2030   9500000         74    18.63
# 87   unrestricted       2030   7000000         74    18.90
# 110  unrestricted       2026   6250000         76    21.03
# 226  unrestricted       2030   4285714         76    20.50
# 261  unrestricted       2024   3687500         69    17.58
# 293  unrestricted       2024   3150000         73    20.88
# 300  unrestricted       2024   3000000         71    16.75
# 418  unrestricted       2024   1500000         75     9.30
# 442  unrestricted       2026   1250000         73    18.47
# 477  unrestricted       2024   1000000         73    11.88
# 508    restricted       2025    925000         75    13.67
# 511    restricted       2025   1491667         70    12.60
# 542    restricted       2027   1918333         69     3.92
# 558  unrestricted       2025    900000         71    11.60
# 563    restricted       2024   1850000         74    17.95
# 589    restricted       2024    925000         74    16.78
# 598    restricted       2026    950000         71    13.38
# 695    restricted       2025    820000         80     5.62
# 807  unrestricted       2024    775000         67    10.17
# 837  unrestricted       2024    775000         71     7.70
#
# [22 rows x 48 columns]

# %%
replace(83,542)
# Out:
#           PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 542  Matt Savoie   19  Canada     175    5'9   C  Right   1  0  0  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 542    2022-07-15           18    None       3      ELC  restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 542       2027  1918333         69     3.92
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 84**

# %%
unmatched_name(84)
# Out:
#                Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  \
# 912  Georgii Merkulov        BOS      BOS      L   C   4  0  0  0    1  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG  S   S%  TOI_min  FOW%
# 912    0    0    0    0    0    0  3  0.0    10.58  21.4
#
# [1 rows x 24 columns]

# %%
unmatched_matches(84)
# Out:
#               PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 520  Georgi Merkulov   22  Russia     181   5'11  LW   Left   4  0  0  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 520    2022-04-09           21    None       3      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 520       2025  925000         71    10.57
#
# [1 rows x 48 columns]

# %%
replace(84,520)
# Out:
#                PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 520  Georgii Merkulov   22  Russia     181   5'11  LW   Left   4  0  0  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 520    2022-04-09           21    None       3      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 520       2025  925000         71    10.57
#
# [1 rows x 48 columns]

# %% [markdown]
# **Index 85**

# %%
unmatched_name(85)
# Out:
#             Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  PPG  \
# 916  Pierrick Dube        WSH      WSH      R   R   3  0  0  0    1  ...    0
#
#      PPP  SHG  SHP  OTG  GWG  S   S%  TOI_min  FOW%
# 916    0    0    0    0    0  3  0.0     9.33   0.0
#
# [1 rows x 24 columns]

# %%
unmatched_matches(85)
# Out:
#             PLAYER  AGE COUNTRY  WEIGHT HEIGHT        POS HANDED  GP  G  A  \
# 362    Dillon Dube   24  Canada     187   5'11  LW, RW, C   Left  43  3  4
# 595  Pierrick Dubé   22   Other     170    5'9         RW  Right   3  0  0
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 362  ...    2021-08-26           22    None       3      RFA  unrestricted
# 595  ...    2023-07-01           22    None       2      ELC    restricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 362       2024  2300000         71    11.15
# 595       2025   950000         69     9.32
#
# [2 rows x 48 columns]

# %%
replace(85,595)
# Out:
#             PLAYER  AGE COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  ...  \
# 595  Pierrick Dube   22   Other     170    5'9  RW  Right   3  0  0  ...
#
#      SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING      EXPIRY  \
# 595    2023-07-01           22    None       2      ELC  restricted
#
#      EXP. YEAR     AAV  HEIGHT_in  TOI_min
# 595       2025  950000         69     9.32
#
# [1 rows x 48 columns]

# %% [markdown]
# <H3> Check remaining mismatched names

# %%
#find remaining unmatched players from nhl_cleaned
nhl_cleaned[~nhl_players.isin(capfriendly['PLAYER'])]
# Out:
#             Player Team_start Team_end Shoots Pos  GP  G  A   P  +/-  ...  \
# 472    Collin Graf        SJS      SJS      R   R   7  0  2   2   -4  ...
# 746  Tony DeAngelo        CAR      CAR      R   D  31  3  8  11   -7  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 472    0    1    0    0    0    0   7  0.0    16.60   0.0
# 746    2    6    0    0    0    0  44  6.8    14.33   0.0
#
# [2 rows x 24 columns]

# %%
#find index number from nhl_follow_up
nhl_follow_up
# Out:
# [{'Player': 'ensure change to Sebastian Aho (C) or Sebastian Aho (D)'},
#  {'collin graf missing': 'missing from capfriendly - unmatched index 47'},
#  {'Tony DeAngelo': 'no match - unmatched index 72'}]

# %% [markdown]
# **Re-examine: unmatched index 47 for partial matches for Collin Graf**

# %%
#name in nhl_cleaned
unmatched_name(47)
# Out:
#           Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  PPG  \
# 472  Collin Graf        SJS      SJS      R   R   7  0  2  2   -4  ...    0
#
#      PPP  SHG  SHP  OTG  GWG  S   S%  TOI_min  FOW%
# 472    1    0    0    0    0  7  0.0     16.6   0.0
#
# [1 rows x 24 columns]

# %%
# use partial matches of names to find matches in capfriendly - to_list() returned too many for df to show

#potential partiel matches tried:
#capfriendly[capfriendly.PLAYER.str.contains('Col')]
#capfriendly[capfriendly.PLAYER.str.contains('ol')]
#capfriendly[capfriendly.PLAYER.str.contains('in')]['PLAYER'].to_list()
#capfriendly[capfriendly.PLAYER.str.contains('Gr')]
#capfriendly[capfriendly.PLAYER.str.contains('af')]
#capfriendly[capfriendly.PLAYER.str.contains('ra')]['PLAYER'].to_list()

'capfreindly does not have data for "Collin Graf"'
# Out:
# 'capfreindly does not have data for "Collin Graf"'

# %%
#drop row for collin Graf at index
nhl_cleaned = nhl_cleaned.drop(index=472, axis=0)

# %%
#confirm droppend index
nhl_cleaned.shape
# Out:
# (923, 24)

# %%
#reset index for nhl_cleaned
nhl_cleaned = nhl_cleaned.reset_index(drop=True)

# %%
#confirm index reset
nhl_cleaned.iloc[[472]]
# Out:
#              Player Team_start Team_end Shoots Pos  GP  G  A  P  +/-  ...  \
# 472  Justin Dowling        NJD      NJD      L   C   2  1  0  1   -2  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG  S    S%  TOI_min  FOW%
# 472    0    0    0    0    0    0  3  33.3    10.53  30.8
#
# [1 rows x 24 columns]

# %%
#remove colin graph follow up from nhl_follow_up
nhl_follow_up.pop(1)

#confirm
nhl_follow_up
# Out:
# [{'Player': 'ensure change to Sebastian Aho (C) or Sebastian Aho (D)'},
#  {'Tony DeAngelo': 'no match - unmatched index 72'}]

# %% [markdown]
# **Re-examine: unmatched index 77 for partial matches for Tony DeAngelo**

# %%
#name in nhl_cleaned
unmatched_name(72)
# Out:
#             Player Team_start Team_end Shoots Pos  GP  G  A   P  +/-  ...  \
# 746  Tony DeAngelo        CAR      CAR      R   D  31  3  8  11   -7  ...
#
#      PPG  PPP  SHG  SHP  OTG  GWG   S   S%  TOI_min  FOW%
# 746    2    6    0    0    0    0  44  6.8    14.33   0.0
#
# [1 rows x 24 columns]

# %%
# use partial matches of names to find matches in capfriendly
capfriendly[capfriendly.PLAYER.str.contains('gel')]
# Out:
#                PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  \
# 35   Alex Pietrangelo   33         Canada     210    6'3      RD  Right  64
# 326    Warren Foegele   27         Canada     198    6'2  LW, RW   Left  82
# 405  Anthony Deangelo   27  United States     180   5'11      RD  Right  31
# 416     Brandon Hagel   24         Canada     175    6'0      LW   Left  82
# 499     Sam Colangelo   21  United States     205    6'2      RW  Right   3
# 738  Luke Evangelista   21         Canada     166   5'11      RW  Right  80
#
#       G   A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 35    4  29  ...    2020-10-12           30     NMC       7      UFA
# 326  20  21  ...    2021-07-31           25    None       3      RFA
# 405   3   8  ...    2023-07-24           27    None       1      UFA
# 416  26  49  ...    2021-08-06           22    None       3      RFA
# 499   1   0  ...    2024-04-11           21    None       2      ELC
# 738  16  23  ...    2020-11-09           18    None       3      ELC
#
#            EXPIRY  EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 35   unrestricted       2027  8800000         75    23.55
# 326  unrestricted       2024  2750000         74    13.97
# 405  unrestricted       2024  1675000         71    14.33
# 416    restricted       2024  1500000         72    19.25
# 499    restricted       2025  1300000         74    12.55
# 738    restricted       2025   896667         71    13.95
#
# [6 rows x 48 columns]

# %%
# replace name name founf from parial match for Tony DeAngelo
replace(72,405)
# Out:
#             PLAYER  AGE        COUNTRY  WEIGHT HEIGHT POS HANDED  GP  G  A  \
# 405  Tony DeAngelo   27  United States     180   5'11  RD  Right  31  3  8
#
#      ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  \
# 405  ...    2023-07-24           27    None       1      UFA  unrestricted
#
#      EXP. YEAR      AAV  HEIGHT_in  TOI_min
# 405       2024  1675000         71    14.33
#
# [1 rows x 48 columns]

# %%
#remove Tony DeAngelo follow up from nhl_follow_up
nhl_follow_up.pop(1)

#confirm
nhl_follow_up
# Out:
# [{'Player': 'ensure change to Sebastian Aho (C) or Sebastian Aho (D)'}]

# %% [markdown]
# **Confirm no more mismatched Player names**

# %%
nhl_cleaned[~nhl_cleaned.Player.isin(capfriendly['PLAYER'])]
# Out:
# Empty DataFrame
# Columns: [Player, Team_start, Team_end, Shoots, Pos, GP, G, A, P, +/-, PIM, P/GP, EVG, EVP, PPG, PPP, SHG, SHP, OTG, GWG, S, S%, TOI_min, FOW%]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# **Since Sebastian Aho (C) or Sebastian Aho (D) did not appear in 'mismatched_nhl' they were successfully changed in both dataframes and can be removed form capfriendly_follow_up**

# %%
#remove Sebastian Aho changes from nhl_follow_up
nhl_follow_up.pop(0)

#confirm
nhl_follow_up
# Out:
# []

# %% [markdown]
# <h3>Explore remining follow up items from capfriendly_follow_up

# %%
capfriendly_follow_up
# Out:
# [{'POS': 'drop after join?  too many positions'},
#  {'PLAYER': 'revisit to change player names after cleaning NHL official data'},
#  {'capfriendly_clean_columns': 'create cleaned df after fixing player data to match nhl data'}]

# %%
#capfriendly_follow_up[1] 'PLAYER' has already been addressed 
#with previous player name matching and therefor can be removed from capfriendly_follow_up
capfriendly_follow_up.pop(1)

#confirm
capfriendly_follow_up
# Out:
# [{'POS': 'drop after join?  too many positions'},
#  {'capfriendly_clean_columns': 'create cleaned df after fixing player data to match nhl data'}]

# %% [markdown]
# <h4>Change capfriendly['POS'] to categorical varriable

# %% [markdown]
# nhl_cleaned['Pos'] has the official position but capfriendly['POS'] can be used to represent if they play multiple positions.

# %%
#review unique values
capfriendly['POS'].value_counts()
# Out:
# POS
# RD           127
# LD           119
# LW, RW       106
# C            105
# RW            76
# RW, LW        69
# LD/RD         66
# LW            65
# C, LW         56
# C, RW         38
# LW, C         34
# RW, C         28
# C, LW, RW     13
# LW, C, RW      7
# RW, C, LW      4
# LD/RD, LW      3
# LW, RW, C      3
# C, RW, LW      2
# D              1
# RW, LW, C      1
# Name: count, dtype: int64

# %%
#list of single positions
single_pos = ['RD', 'LD', 'D', 'LW', 'RW', 'C']

# %%
#capfriendly before change
capfriendly
# Out:
#                 PLAYER  AGE        COUNTRY  WEIGHT HEIGHT     POS HANDED  GP  \
# 0     Nathan MacKinnon   27         Canada     200    6'0       C  Right  82
# 1       Connor McDavid   26         Canada     193    6'1       C   Left  76
# 2       Artemi Panarin   31         Russia     170   5'11      LW  Right  82
# 3      Auston Matthews   25  United States     215    6'3       C   Left  81
# 4        Erik Karlsson   33         Sweden     190    6'0      RD  Right  82
# ..                 ...  ...            ...     ...    ...     ...    ...  ..
# 918    Jalen Chatfield   27  United States     188    6'1      RD  Right  72
# 919       Parker Kelly   24         Canada     188    6'0      LW   Left  80
# 920     Boris Katchouk   25         Canada     179    6'1      LW   Left  59
# 921     Taylor Raddysh   25         Canada     198    6'2      RW  Right  73
# 922  Alex Barré-Boulet   26         Canada     168    5'9  RW, LW   Left  36
#
#       G    A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 0    51   89  ...    2022-09-20           27     NMC       8      UFA
# 1    32  100  ...    2017-07-05           21     NMC       8      RFA
# 2    49   71  ...    2019-07-01           27     NMC       7      UFA
# 3    69   38  ...    2019-02-05           21     NMC       5      RFA
# 4    11   45  ...    2019-06-17           29     NMC       8      UFA
# ..   ..  ...  ...           ...          ...     ...     ...      ...
# 918   8   14  ...    2022-01-21           26    None       2      RFA
# 919   8   10  ...    2021-10-12           23    None       2      RFA
# 920   7    6  ...    2021-07-31           23    None       3      RFA
# 921   5    9  ...    2021-07-30           23    None       3      RFA
# 922   6    3  ...    2021-07-30           24    None       3      RFA
#
#            EXPIRY  EXP. YEAR       AAV  HEIGHT_in  TOI_min
# 0    unrestricted       2031  12600000         72    22.80
# 1    unrestricted       2026  12500000         73    21.35
# 2    unrestricted       2026  11642857         71    20.12
# 3    unrestricted       2024  11640250         75    20.95
# 4    unrestricted       2027  11500000         72    24.27
# ..            ...        ...       ...        ...      ...
# 918  unrestricted       2024    762500         73    15.18
# 919  unrestricted       2024    762500         72    11.70
# 920  unrestricted       2024    758333         73    11.47
# 921  unrestricted       2024    758333         74    15.87
# 922  unrestricted       2024    758333         69    11.18
#
# [923 rows x 48 columns]

# %%
#change position in single positions list to True
capfriendly.loc[~capfriendly['POS'].isin(single_pos), 'POS'] = True

#change position not in single positions list to False
capfriendly.loc[capfriendly['POS'].isin(single_pos), 'POS'] = False

# %%
#confirm
capfriendly['POS'].unique()
# Out:
# array([False, True], dtype=object)

# %%
#rename column ['POS'] to ['POS_multi']
capfriendly = capfriendly.rename(columns={'POS':'POS_multi'})

#confirm all ['POS'] changes
capfriendly
# Out:
#                 PLAYER  AGE        COUNTRY  WEIGHT HEIGHT POS_multi HANDED  \
# 0     Nathan MacKinnon   27         Canada     200    6'0     False  Right
# 1       Connor McDavid   26         Canada     193    6'1     False   Left
# 2       Artemi Panarin   31         Russia     170   5'11     False  Right
# 3      Auston Matthews   25  United States     215    6'3     False   Left
# 4        Erik Karlsson   33         Sweden     190    6'0     False  Right
# ..                 ...  ...            ...     ...    ...       ...    ...
# 918    Jalen Chatfield   27  United States     188    6'1     False  Right
# 919       Parker Kelly   24         Canada     188    6'0     False   Left
# 920     Boris Katchouk   25         Canada     179    6'1     False   Left
# 921     Taylor Raddysh   25         Canada     198    6'2     False  Right
# 922  Alex Barré-Boulet   26         Canada     168    5'9      True   Left
#
#      GP   G    A  ...  SIGNING DATE  SIGNING AGE  CLAUSE  LENGTH  SIGNING  \
# 0    82  51   89  ...    2022-09-20           27     NMC       8      UFA
# 1    76  32  100  ...    2017-07-05           21     NMC       8      RFA
# 2    82  49   71  ...    2019-07-01           27     NMC       7      UFA
# 3    81  69   38  ...    2019-02-05           21     NMC       5      RFA
# 4    82  11   45  ...    2019-06-17           29     NMC       8      UFA
# ..   ..  ..  ...  ...           ...          ...     ...     ...      ...
# 918  72   8   14  ...    2022-01-21           26    None       2      RFA
# 919  80   8   10  ...    2021-10-12           23    None       2      RFA
# 920  59   7    6  ...    2021-07-31           23    None       3      RFA
# 921  73   5    9  ...    2021-07-30           23    None       3      RFA
# 922  36   6    3  ...    2021-07-30           24    None       3      RFA
#
#            EXPIRY  EXP. YEAR       AAV  HEIGHT_in  TOI_min
# 0    unrestricted       2031  12600000         72    22.80
# 1    unrestricted       2026  12500000         73    21.35
# 2    unrestricted       2026  11642857         71    20.12
# 3    unrestricted       2024  11640250         75    20.95
# 4    unrestricted       2027  11500000         72    24.27
# ..            ...        ...       ...        ...      ...
# 918  unrestricted       2024    762500         73    15.18
# 919  unrestricted       2024    762500         72    11.70
# 920  unrestricted       2024    758333         73    11.47
# 921  unrestricted       2024    758333         74    15.87
# 922  unrestricted       2024    758333         69    11.18
#
# [923 rows x 48 columns]

# %%
#review capfriendly_follow_up
capfriendly_follow_up
# Out:
# [{'POS': 'drop after join?  too many positions'},
#  {'capfriendly_clean_columns': 'create cleaned df after fixing player data to match nhl data'}]

# %%
#remove 'POS' capfriendly_follow_up
capfriendly_follow_up.pop(0)

#confirm
capfriendly_follow_up
# Out:
# [{'capfriendly_clean_columns': 'create cleaned df after fixing player data to match nhl data'}]

# %% [markdown]
# **Update capfriendly_clean_columns after POS_multi change**

# %%
#identify index of 'POS'
capfriendly_clean_columns.index('POS')
# Out:
# 5

# %%
#replace 'POS' with 'POS_multi' in capfriendly_clean_columns
capfriendly_clean_columns[5] = 'POS_multi'

#confirm
capfriendly_clean_columns
# Out:
# ['PLAYER',
#  'AGE',
#  'COUNTRY',
#  'WEIGHT',
#  'HEIGHT_in',
#  'POS_multi',
#  'HANDED',
#  'GP',
#  'G',
#  'A',
#  'P',
#  'P/GP',
#  '+/-',
#  'Sh',
#  'Sh%',
#  'TOI_min',
#  'ixG',
#  'iSh',
#  'iCF',
#  'iFF',
#  'ixG60',
#  'iSh60',
#  'iCF60',
#  'iFF60',
#  'SF',
#  'SA',
#  'SF%',
#  'CF',
#  'CA',
#  'CF%',
#  'FF',
#  'FA',
#  'FF%',
#  'xGF',
#  'xGA',
#  'xGF%',
#  'SIGNING TEAM',
#  'EXTENSION',
#  'SIGNING DATE',
#  'SIGNING AGE',
#  'CLAUSE',
#  'LENGTH',
#  'SIGNING',
#  'EXPIRY',
#  'EXP. YEAR',
#  'AAV']

# %% [markdown]
# <h3>Create capfriendly_cleaned and save as .csv

# %%
capfriendly_cleaned = capfriendly[capfriendly_clean_columns]

#confirm
capfriendly_cleaned
# Out:
#                 PLAYER  AGE        COUNTRY  WEIGHT  HEIGHT_in POS_multi  \
# 0     Nathan MacKinnon   27         Canada     200         72     False
# 1       Connor McDavid   26         Canada     193         73     False
# 2       Artemi Panarin   31         Russia     170         71     False
# 3      Auston Matthews   25  United States     215         75     False
# 4        Erik Karlsson   33         Sweden     190         72     False
# ..                 ...  ...            ...     ...        ...       ...
# 918    Jalen Chatfield   27  United States     188         73     False
# 919       Parker Kelly   24         Canada     188         72     False
# 920     Boris Katchouk   25         Canada     179         73     False
# 921     Taylor Raddysh   25         Canada     198         74     False
# 922  Alex Barré-Boulet   26         Canada     168         69      True
#
#     HANDED  GP   G    A  ...  SIGNING TEAM  EXTENSION  SIGNING DATE  \
# 0    Right  82  51   89  ...           COL       True    2022-09-20
# 1     Left  76  32  100  ...           EDM       True    2017-07-05
# 2    Right  82  49   71  ...           NYR      False    2019-07-01
# 3     Left  81  69   38  ...           TOR       True    2019-02-05
# 4    Right  82  11   45  ...           SJS       True    2019-06-17
# ..     ...  ..  ..  ...  ...           ...        ...           ...
# 918  Right  72   8   14  ...           CAR       True    2022-01-21
# 919   Left  80   8   10  ...           OTT       True    2021-10-12
# 920   Left  59   7    6  ...           TBL      False    2021-07-31
# 921  Right  73   5    9  ...           TBL      False    2021-07-30
# 922   Left  36   6    3  ...           TBL      False    2021-07-30
#
#      SIGNING AGE  CLAUSE  LENGTH  SIGNING        EXPIRY  EXP. YEAR       AAV
# 0             27     NMC       8      UFA  unrestricted       2031  12600000
# 1             21     NMC       8      RFA  unrestricted       2026  12500000
# 2             27     NMC       7      UFA  unrestricted       2026  11642857
# 3             21     NMC       5      RFA  unrestricted       2024  11640250
# 4             29     NMC       8      UFA  unrestricted       2027  11500000
# ..           ...     ...     ...      ...           ...        ...       ...
# 918           26    None       2      RFA  unrestricted       2024    762500
# 919           23    None       2      RFA  unrestricted       2024    762500
# 920           23    None       3      RFA  unrestricted       2024    758333
# 921           23    None       3      RFA  unrestricted       2024    758333
# 922           24    None       3      RFA  unrestricted       2024    758333
#
# [923 rows x 46 columns]

# %% [markdown]
# <h4> Export cleaned capfrienly df to .csv

# %%
#Save capfriendly_cleaned to capfriendly_cleaned.csv
#comment out after saving to not save multiples

#create path
cap_cleaned_path = "/Users/ness/Desktop/Springboard/Projects/-Capstone 2/NHL Salaries/clean_data/capfriendly_cleaned.csv"

#save
#capfriendly_cleaned.to_csv(cap_cleaned_path, index=False)

# %% [markdown]
# <h2> Merge capfriendly_cleaned with nhl_cleaned

# %%
f'capfriendly_cleaned shape: {capfriendly_cleaned.shape} and nhl_cleaned shape: {nhl_cleaned.shape}'
# Out:
# 'capfriendly_cleaned shape: (923, 46) and nhl_cleaned shape: (923, 24)'

# %%
#Merge on shared columns
nhl_salaries = pd.merge(nhl_cleaned, capfriendly_cleaned, left_on=['Player','GP', 'G', 'A', 'P'],
                     right_on=['PLAYER', 'GP', 'G', 'A', 'P'])

# %% [markdown]
# Player names are all the same.  If 'GP', 'G', 'A', 'P' are the same fpr each player in both df the length of the merged df dhould be 923

# %%
nhl_salaries.shape
# Out:
# (923, 66)

# %%
nhl_salaries.columns
# Out:
# Index(['Player', 'Team_start', 'Team_end', 'Shoots', 'Pos', 'GP', 'G', 'A',
#        'P', '+/-_x', 'PIM', 'P/GP_x', 'EVG', 'EVP', 'PPG', 'PPP', 'SHG', 'SHP',
#        'OTG', 'GWG', 'S', 'S%', 'TOI_min_x', 'FOW%', 'PLAYER', 'AGE',
#        'COUNTRY', 'WEIGHT', 'HEIGHT_in', 'POS_multi', 'HANDED', 'P/GP_y',
#        '+/-_y', 'Sh', 'Sh%', 'TOI_min_y', 'ixG', 'iSh', 'iCF', 'iFF', 'ixG60',
#        'iSh60', 'iCF60', 'iFF60', 'SF', 'SA', 'SF%', 'CF', 'CA', 'CF%', 'FF',
#        'FA', 'FF%', 'xGF', 'xGA', 'xGF%', 'SIGNING TEAM', 'EXTENSION',
#        'SIGNING DATE', 'SIGNING AGE', 'CLAUSE', 'LENGTH', 'SIGNING', 'EXPIRY',
#        'EXP. YEAR', 'AAV'],
#       dtype='object')

# %% [markdown]
# <h3> Explore duplicate columns and their differnece

# %% [markdown]
# <h4> Explore duplicate columns with same names

# %%
#list of duplicate columns
dup = ['+/-_x', '+/-_y','P/GP_x', 'P/GP_y', 'TOI_min_x', 'TOI_min_y']

# %% [raw]
# These columns should have the same values but when i tried to merge on them they df was not the correct length so there aresome calues that are different.

# %% [markdown]
# **difference in '+/-'**

# %%
#find difference in '+/-'
nhl_salaries[nhl_salaries['+/-_x']!= nhl_salaries['+/-_y']]
# Out:
# Empty DataFrame
# Columns: [Player, Team_start, Team_end, Shoots, Pos, GP, G, A, P, +/-_x, PIM, P/GP_x, EVG, EVP, PPG, PPP, SHG, SHP, OTG, GWG, S, S%, TOI_min_x, FOW%, PLAYER, AGE, COUNTRY, WEIGHT, HEIGHT_in, POS_multi, HANDED, P/GP_y, +/-_y, Sh, Sh%, TOI_min_y, ixG, iSh, iCF, iFF, ixG60, iSh60, iCF60, iFF60, SF, SA, SF%, CF, CA, CF%, FF, FA, FF%, xGF, xGA, xGF%, SIGNING TEAM, EXTENSION, SIGNING DATE, SIGNING AGE, CLAUSE, LENGTH, SIGNING, EXPIRY, EXP. YEAR, AAV]
# Index: []
#
# [0 rows x 66 columns]

# %% [markdown]
# **difference in 'P/GP'**

# %%
#find difference in 'P/GP'
nhl_salaries[nhl_salaries['P/GP_x']!= nhl_salaries['P/GP_y']]
# Out:
# Empty DataFrame
# Columns: [Player, Team_start, Team_end, Shoots, Pos, GP, G, A, P, +/-_x, PIM, P/GP_x, EVG, EVP, PPG, PPP, SHG, SHP, OTG, GWG, S, S%, TOI_min_x, FOW%, PLAYER, AGE, COUNTRY, WEIGHT, HEIGHT_in, POS_multi, HANDED, P/GP_y, +/-_y, Sh, Sh%, TOI_min_y, ixG, iSh, iCF, iFF, ixG60, iSh60, iCF60, iFF60, SF, SA, SF%, CF, CA, CF%, FF, FA, FF%, xGF, xGA, xGF%, SIGNING TEAM, EXTENSION, SIGNING DATE, SIGNING AGE, CLAUSE, LENGTH, SIGNING, EXPIRY, EXP. YEAR, AAV]
# Index: []
#
# [0 rows x 66 columns]

# %%
#find difference in 'TOI_min'
nhl_salaries[nhl_salaries['TOI_min_x']!= nhl_salaries['TOI_min_y']][['TOI_min_x','TOI_min_y']]
# Out:
#      TOI_min_x  TOI_min_y
# 3        22.15      22.13
# 4        23.83      23.82
# 6        21.97      21.95
# 14       17.77      17.75
# 15       16.52      16.50
# ..         ...        ...
# 909      11.67      11.65
# 911      10.58      10.57
# 912      14.73      14.72
# 913      11.57      11.55
# 915       9.33       9.32
#
# [413 rows x 2 columns]

# %% [markdown]
# Values are similar but slightly different likely due to rounding. I will keep the offical TOI_min from nhl_cleaned (TOI_min_x) and drop TOI_min from capfriendly_cleaned (TOI_min_y) at a later step.

# %% [markdown]
# **Initiate list of duplicate columns to drop later**

# %%
#Creat a list of duplicate columns to drop later 
merged_drop = ['TOI_min_y']

# %% [markdown]
# **Update shared columns and Re-merge**

# %%
#update shared columns and Re-merge
nhl_salaries = pd.merge(nhl_cleaned, capfriendly_cleaned, left_on=['Player','GP', 'G', 'A', 'P','+/-','P/GP'],
                     right_on=['PLAYER', 'GP', 'G', 'A', 'P','+/-','P/GP'])

# %%
nhl_salaries.columns
# Out:
# Index(['Player', 'Team_start', 'Team_end', 'Shoots', 'Pos', 'GP', 'G', 'A',
#        'P', '+/-', 'PIM', 'P/GP', 'EVG', 'EVP', 'PPG', 'PPP', 'SHG', 'SHP',
#        'OTG', 'GWG', 'S', 'S%', 'TOI_min_x', 'FOW%', 'PLAYER', 'AGE',
#        'COUNTRY', 'WEIGHT', 'HEIGHT_in', 'POS_multi', 'HANDED', 'Sh', 'Sh%',
#        'TOI_min_y', 'ixG', 'iSh', 'iCF', 'iFF', 'ixG60', 'iSh60', 'iCF60',
#        'iFF60', 'SF', 'SA', 'SF%', 'CF', 'CA', 'CF%', 'FF', 'FA', 'FF%', 'xGF',
#        'xGA', 'xGF%', 'SIGNING TEAM', 'EXTENSION', 'SIGNING DATE',
#        'SIGNING AGE', 'CLAUSE', 'LENGTH', 'SIGNING', 'EXPIRY', 'EXP. YEAR',
#        'AAV'],
#       dtype='object')

# %% [markdown]
# <h4> Explore duplicate columns with different names

# %% [markdown]
# **'Player' and 'PLAYER' both represet 'player name'**

# %%
#add 'PLAYER' to drop list
merged_drop.append('PLAYER')

# %% [markdown]
# **'S' and 'Sh' both represet 'shots taken'**

# %%
#explore differences in shots
nhl_salaries[nhl_salaries['S']!= nhl_salaries['Sh']]
# Out:
# Empty DataFrame
# Columns: [Player, Team_start, Team_end, Shoots, Pos, GP, G, A, P, +/-, PIM, P/GP, EVG, EVP, PPG, PPP, SHG, SHP, OTG, GWG, S, S%, TOI_min_x, FOW%, PLAYER, AGE, COUNTRY, WEIGHT, HEIGHT_in, POS_multi, HANDED, Sh, Sh%, TOI_min_y, ixG, iSh, iCF, iFF, ixG60, iSh60, iCF60, iFF60, SF, SA, SF%, CF, CA, CF%, FF, FA, FF%, xGF, xGA, xGF%, SIGNING TEAM, EXTENSION, SIGNING DATE, SIGNING AGE, CLAUSE, LENGTH, SIGNING, EXPIRY, EXP. YEAR, AAV]
# Index: []
#
# [0 rows x 64 columns]

# %% [markdown]
# The values are all the same.  I will keep the offical shot count from nhl_cleaned (S) and drop the shot count from capfriendly_cleaned (Sh) at a later step.

# %%
#append 'Sh' to merged_drop
merged_drop.append('Sh')

# %% [markdown]
# **'S%' and 'Sh%' both represet 'shots percentage' which is the percent of shots that resulted in a goal**

# %%
#explore differences in shots
nhl_salaries[nhl_salaries['S%']!= nhl_salaries['Sh%']][['S%','Sh%']]
# Out:
#        S%   Sh%
# 0     7.2  0.07
# 1     7.8  0.08
# 2     6.5  0.06
# 3     6.3  0.06
# 4     5.7  0.06
# ..    ...   ...
# 894  11.5  0.11
# 895  14.2  0.14
# 896  10.8  0.11
# 897   8.5  0.09
# 898   4.1  0.04
#
# [748 rows x 2 columns]

# %% [markdown]
# The values are equal but are formatted differenly.  I will keep the offical shot percent from nhl_cleaned (S%) and drop shot percent from capfriendly_cleaned (Sh%) at a later step.

# %%
#append 'Sh' to merged_drop
merged_drop.append('Sh%')

# %% [markdown]
# <h4>Drop duplicate columns: 'TOI_min_y', 'Sh', 'Sh%'

# %%
#view columns to drop
merged_drop
# Out:
# ['TOI_min_y', 'PLAYER', 'Sh', 'Sh%']

# %%
#drop columns and save df
nhl_salaries = nhl_salaries.drop(columns=merged_drop)

# %% [markdown]
# <h2> Format and arrange columns to final format

# %% [markdown]
# Numeric columns that represent in season stats with stay capitalized, all other columns will change to lower case

# %%
nhl_salaries.columns
# Out:
# Index(['Player', 'Team_start', 'Team_end', 'Shoots', 'Pos', 'GP', 'G', 'A',
#        'P', '+/-', 'PIM', 'P/GP', 'EVG', 'EVP', 'PPG', 'PPP', 'SHG', 'SHP',
#        'OTG', 'GWG', 'S', 'S%', 'TOI_min_x', 'FOW%', 'AGE', 'COUNTRY',
#        'WEIGHT', 'HEIGHT_in', 'POS_multi', 'HANDED', 'ixG', 'iSh', 'iCF',
#        'iFF', 'ixG60', 'iSh60', 'iCF60', 'iFF60', 'SF', 'SA', 'SF%', 'CF',
#        'CA', 'CF%', 'FF', 'FA', 'FF%', 'xGF', 'xGA', 'xGF%', 'SIGNING TEAM',
#        'EXTENSION', 'SIGNING DATE', 'SIGNING AGE', 'CLAUSE', 'LENGTH',
#        'SIGNING', 'EXPIRY', 'EXP. YEAR', 'AAV'],
#       dtype='object')

# %%
basic_stats = ['GP', 'G', 'A', 'P', '+/-', 'PIM', 'P/GP', 'EVG', 'EVP', 'PPG', 'PPP', 'SHG', 'SHP', 'OTG', 'GWG', 'S', 'S%','TOI_min_x', 'FOW%']

# %%
advanced_stats = ['ixG', 'iSh', 'iCF', 'iFF', 'ixG60', 'iSh60', 'iCF60', 'iFF60', 'SF', 'SA', 'SF%', 'CF', 'CA', 'CF%', 'FF', 'FA', 'FF%', 'xGF', 'xGA', 'xGF%']

# %%
player_details = ['Player', 'Team_start', 'Team_end', 'Shoots', 'Pos', 'AGE', 'COUNTRY', 'WEIGHT', 'HEIGHT_in', 'POS_multi', 'HANDED', 'SIGNING TEAM', 'EXTENSION', 'SIGNING DATE', 'SIGNING AGE', 'CLAUSE', 'LENGTH', 'SIGNING', 'EXPIRY', 'EXP. YEAR', 'AAV']

# %% [markdown]
# **Convert 'player_details' columns to lowercase**

# %%
#convert player_details columns to lowercase and replace spaces with underscore
nhl_salaries.columns = [col.lower().replace(' ', '_') if col in player_details else col for col in nhl_salaries.columns]

# %%
#confirm lowecase changes
nhl_salaries.columns
# Out:
# Index(['player', 'team_start', 'team_end', 'shoots', 'pos', 'GP', 'G', 'A',
#        'P', '+/-', 'PIM', 'P/GP', 'EVG', 'EVP', 'PPG', 'PPP', 'SHG', 'SHP',
#        'OTG', 'GWG', 'S', 'S%', 'TOI_min_x', 'FOW%', 'age', 'country',
#        'weight', 'height_in', 'pos_multi', 'handed', 'ixG', 'iSh', 'iCF',
#        'iFF', 'ixG60', 'iSh60', 'iCF60', 'iFF60', 'SF', 'SA', 'SF%', 'CF',
#        'CA', 'CF%', 'FF', 'FA', 'FF%', 'xGF', 'xGA', 'xGF%', 'signing_team',
#        'extension', 'signing_date', 'signing_age', 'clause', 'length',
#        'signing', 'expiry', 'exp._year', 'aav'],
#       dtype='object')

# %% [markdown]
# **Rename 'TOI_min_x' and 'exp._year' to remove unwanted characters**

# %%
#rename 'TOI_min_x' to 'TOI_min' and 'exp._year' to 'exp_year'
nhl_salaries = nhl_salaries.rename(columns = {'TOI_min_x':'TOI_min', 'exp._year':'exp_year'})

# %%
nhl_salaries.columns
# Out:
# Index(['player', 'team_start', 'team_end', 'shoots', 'pos', 'GP', 'G', 'A',
#        'P', '+/-', 'PIM', 'P/GP', 'EVG', 'EVP', 'PPG', 'PPP', 'SHG', 'SHP',
#        'OTG', 'GWG', 'S', 'S%', 'TOI_min', 'FOW%', 'age', 'country', 'weight',
#        'height_in', 'pos_multi', 'handed', 'ixG', 'iSh', 'iCF', 'iFF', 'ixG60',
#        'iSh60', 'iCF60', 'iFF60', 'SF', 'SA', 'SF%', 'CF', 'CA', 'CF%', 'FF',
#        'FA', 'FF%', 'xGF', 'xGA', 'xGF%', 'signing_team', 'extension',
#        'signing_date', 'signing_age', 'clause', 'length', 'signing', 'expiry',
#        'exp_year', 'aav'],
#       dtype='object')

# %% [markdown]
# **Update basic_stats to reflect column name changes**

# %%
#copy basic_stats to create basic_stats_updated
basic_stats_updated = basic_stats.copy()

#find index of TOI_min_x and replace 'TOI_min_x' with 'TOI_min' at index 
basic_stats_updated[basic_stats_updated.index('TOI_min_x')] = 'TOI_min'

#confirm changes
basic_stats_updated
# Out:
# ['GP',
#  'G',
#  'A',
#  'P',
#  '+/-',
#  'PIM',
#  'P/GP',
#  'EVG',
#  'EVP',
#  'PPG',
#  'PPP',
#  'SHG',
#  'SHP',
#  'OTG',
#  'GWG',
#  'S',
#  'S%',
#  'TOI_min',
#  'FOW%']

# %% [markdown]
# **Update player_details to reflect column name changes**

# %%
#update player_details
player_details_updated = ['player', 'team_start', 'team_end', 'shoots', 'pos', 'age', 'country', 'weight', 
                          'height_in', 'pos_multi', 'handed', 'signing_team', 'extension', 'signing_date', 
                          'signing_age', 'clause', 'length', 'signing', 'expiry', 'exp_year', 'aav']

# %% [markdown]
# **Create list of columns in their final order**

# %%
#initiate list with 'player' names first in list
final_layout=['player']

#extend list with basic_stats
final_layout.extend(basic_stats_updated)

#extend list with advanced_stats
final_layout.extend(advanced_stats)

#extend list with player_details excluding 'player' names at index 0
final_layout.extend(player_details_updated[1:])


final_layout
# Out:
# ['player',
#  'GP',
#  'G',
#  'A',
#  'P',
#  '+/-',
#  'PIM',
#  'P/GP',
#  'EVG',
#  'EVP',
#  'PPG',
#  'PPP',
#  'SHG',
#  'SHP',
#  'OTG',
#  'GWG',
#  'S',
#  'S%',
#  'TOI_min',
#  'FOW%',
#  'ixG',
#  'iSh',
#  'iCF',
#  'iFF',
#  'ixG60',
#  'iSh60',
#  'iCF60',
#  'iFF60',
#  'SF',
#  'SA',
#  'SF%',
#  'CF',
#  'CA',
#  'CF%',
#  'FF',
#  'FA',
#  'FF%',
#  'xGF',
#  'xGA',
#  'xGF%',
#  'team_start',
#  'team_end',
#  'shoots',
#  'pos',
#  'age',
#  'country',
#  'weight',
#  'height_in',
#  'pos_multi',
#  'handed',
#  'signing_team',
#  'extension',
#  'signing_date',
#  'signing_age',
#  'clause',
#  'length',
#  'signing',
#  'expiry',
#  'exp_year',
#  'aav']

# %%
#confirm all columns included in final_layout
len(final_layout)==len(nhl_salaries.columns)
# Out:
# True

# %%
nhl_salaries[final_layout].head()
# Out:
#              player  GP   G   A   P  +/-  PIM  P/GP  EVG  EVP  ...  \
# 0   Mikael Backlund  82  15  24  39   -4   24  0.48   12   34  ...
# 1    Scott Laughton  82  13  26  39   -9   69  0.48   10   26  ...
# 2    Evan Rodrigues  80  12  27  39   26   34  0.49    9   29  ...
# 3   Gustav Forsling  79  10  29  39   56   43  0.49    9   37  ...
# 4  Rasmus Andersson  78   9  30  39  -11   47  0.50    8   30  ...
#
#    signing_team  extension  signing_date  signing_age  clause  length  \
# 0           CGY       True    2018-02-16           29     NMC       6
# 1           PHI       True    2021-04-12           27    None       5
# 2           FLA      False    2023-07-02           29    None       4
# 3           FLA       True    2021-07-15           25    None       3
# 4           CGY       True    2020-01-08           23    None       6
#
#    signing        expiry  exp_year      aav
# 0      UFA  unrestricted      2024  5350000
# 1      UFA  unrestricted      2026  3000000
# 2      UFA  unrestricted      2027  3000000
# 3      RFA  unrestricted      2024  2666667
# 4      RFA  unrestricted      2026  4550000
#
# [5 rows x 60 columns]

# %% [markdown]
# <h2>Create nhl_salaries_cleaned

# %%
#create final df
nhl_salaries_cleaned = nhl_salaries[final_layout]

# %%
nhl_salaries_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 923 entries, 0 to 922
# Data columns (total 60 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   player        923 non-null    object
#  1   GP            923 non-null    int64
#  2   G             923 non-null    int64
#  3   A             923 non-null    int64
#  4   P             923 non-null    int64
#  5   +/-           923 non-null    int64
#  6   PIM           923 non-null    int64
#  7   P/GP          923 non-null    float64
#  8   EVG           923 non-null    int64
#  9   EVP           923 non-null    int64
#  10  PPG           923 non-null    int64
#  11  PPP           923 non-null    int64
#  12  SHG           923 non-null    int64
#  13  SHP           923 non-null    int64
#  14  OTG           923 non-null    int64
#  15  GWG           923 non-null    int64
#  16  S             923 non-null    int64
#  17  S%            923 non-null    float64
#  18  TOI_min       923 non-null    float64
#  19  FOW%          923 non-null    float64
#  20  ixG           923 non-null    float64
#  21  iSh           923 non-null    int64
#  22  iCF           923 non-null    int64
#  23  iFF           923 non-null    int64
#  24  ixG60         923 non-null    float64
#  25  iSh60         923 non-null    float64
#  26  iCF60         923 non-null    float64
#  27  iFF60         923 non-null    float64
#  28  SF            923 non-null    int64
#  29  SA            923 non-null    int64
#  30  SF%           923 non-null    float64
#  31  CF            923 non-null    int64
#  32  CA            923 non-null    int64
#  33  CF%           923 non-null    float64
#  34  FF            923 non-null    int64
#  35  FA            923 non-null    int64
#  36  FF%           923 non-null    float64
#  37  xGF           923 non-null    float64
#  38  xGA           923 non-null    float64
#  39  xGF%          923 non-null    float64
#  40  team_start    923 non-null    category
#  41  team_end      923 non-null    category
#  42  shoots        923 non-null    category
#  43  pos           923 non-null    category
#  44  age           923 non-null    int64
#  45  country       923 non-null    category
#  46  weight        923 non-null    int64
#  47  height_in     923 non-null    int64
#  48  pos_multi     923 non-null    object
#  49  handed        923 non-null    category
#  50  signing_team  923 non-null    category
#  51  extension     923 non-null    object
#  52  signing_date  923 non-null    datetime64[ns]
#  53  signing_age   923 non-null    int64
#  54  clause        923 non-null    category
#  55  length        923 non-null    int64
#  56  signing       923 non-null    category
#  57  expiry        923 non-null    category
#  58  exp_year      923 non-null    int64
#  59  aav           923 non-null    int64
# dtypes: category(10), datetime64[ns](1), float64(15), int64(31), object(3)
# memory usage: 374.7+ KB

# %% [markdown]
# **Save to .csv**

# %%
#create path
salaries_cleaned_path = "/Users/ness/Desktop/Springboard/Projects/-Capstone 2/NHL Salaries/clean_data/nhl_salaries_cleaned.csv"

#save
nhl_cleaned.to_csv(salaries_cleaned_path, index=False)

# %% [markdown]
# <h2> Follow up:

# %% [markdown]
# * below are two functions to show df without outliers and to show df with only outliers. I briefly elplored outliers here but felt it was more appropriate for the EDA phase.

# %% [markdown]
# <h4>Define function to calculate IQR and outliers

# %%
def subset_by_iqr(df, column, whisker_width=1.5):
    """Remove outliers from a dataframe by column, including optional 
    #  whiskers, removing rows for which the column value are 
    #   less than Q1-1.5IQR or greater than Q3+1.5IQR.
    Args:
        df (`:obj:pd.DataFrame`): A pandas dataframe to subset
        column (str): Name of the column to calculate the subset from.
        whisker_width (float): Optional, loosen the IQR filter by a
                               factor of `whisker_width` * IQR.
    Returns:
        (`:obj:pd.DataFrame`): Filtered dataframe
    """
    # Calculate Q1, Q2 and IQR
    q1 = df[column].quantile(0.25)                 
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1
    print(f"q1 = {q1}, q3 = {q3}, and IQR = {iqr}")
    # Apply filter with respect to IQR, including optional whiskers
   
    filter = (df[column] >= q1 - whisker_width*iqr) & (df[column] <= q3 + whisker_width*iqr)
    return df.loc[filter]

# %%
def outliers(df, column, whisker_width=1.5):
    '''shows outliers'''
    """... from a dataframe by column, including optional 
    #  whiskers, removing rows for which the column value are 
    #   less than Q1-1.5IQR or greater than Q3+1.5IQR.
    Args:
        df (`:obj:pd.DataFrame`): A pandas dataframe to subset
        column (str): Name of the column to calculate the subset from.
        whisker_width (float): Optional, loosen the IQR filter by a
                               factor of `whisker_width` * IQR.
    Returns:
        (`:obj:pd.DataFrame`): Filtered dataframe
    """
    # Calculate Q1, Q2 and IQR
    q1 = df[column].quantile(0.25)                 
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1
    print(f"q1 = {q1}, q3 = {q3}, and IQR = {q1 - whisker_width*iqr} to {q3 + whisker_width*iqr}")
    # Apply filter with respect to IQR, including optional whiskers
    filter = (df[column] >= q1 - whisker_width*iqr) & (df[column] <= q3 + whisker_width*iqr)
    return df.loc[~filter]
