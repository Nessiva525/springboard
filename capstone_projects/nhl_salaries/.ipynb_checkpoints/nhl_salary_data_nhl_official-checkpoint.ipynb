# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.capfriendly.com/browse/active/2024?stats-season=2024'

# %%
r = requests.get(url)

soup = BeautifulSoup(r.text, 'html')

# %%
# Find table
table = soup.find('table')

# %%
table
# Out:
# <table class="tbl sortable" id="brwt"><thead><tr class="column_head"><th class="left" style="width:199px;min-width:199px">PLAYER</th><th class="center" style="min-width:55px">TEAM</th><th class="center brs_srt cp" data-srt="14">AGE</th><th class="center" style="width:70px;min-width:70px">POS</th><th class="center">HANDED</th><th class="center brs_srt cp" data-srt="13"><span class="q" title="Games Played">GP</span></th><th class="center brs_srt cp" data-srt="3"><span class="q" title="Goals">G</span></th><th class="center brs_srt cp" data-srt="4"><span class="q" title="Assists">A</span></th><th class="center brs_srt cp" data-srt="5"><span class="q" title="Points">P</span></th><th class="center brs_srt cp" data-srt="25"><span class="q" title="Points Per Game">P/GP</span></th><th class="center brs_srt cp" data-srt="9"><span class="q" title="Plus/Minus">+/-</span></th><th class="center brs_srt cp" data-srt="22"><span class="q" title="Shots on Goal">Sh</span></th><th class="center brs_srt cp" data-srt="24"><span class="q" title="Shooting Percentage">Sh%</span></th><th class="center brs_srt cp" data-srt="10"><span class="q" title="Average Time on Ice">TOI</span></th><th class="center brs_srt cp" data-srt="6"><span class="q" title="Wins">W</span></th><th class="center brs_srt cp" data-srt="11"><span class="q" title="Losses">L</span></th><th class="center brs_srt cp" data-srt="12"><span class="q" title="Shutouts">SO</span></th><th class="center brs_srt cp" data-srt="7"><span class="q" title="Goals Against Average">GAA</span></th><th class="center brs_srt cp" data-srt="8"><span class="q" title="Save Percentage">Sv%</span></th><th class="center" style="width:80px;min-width:80px">CLAUSE</th><th class="center brs_srt cp" data-srt="53" style="min-width:65px">EXPIRY</th><th class="center brs_srt cp sorted_desc" data-srt="1" style="width:85px;min-width:85px">CAP HIT</th><th class="center brs_srt cp" data-srt="2" style="width:80px;min-width:80px">SALARY</th></tr></thead><tbody><tr class="odd"><td class="left"><div class="l">1. <a href="/players/nathan-mackinnon">Nathan MacKinnon</a></div></td><td class="center"><a href="/teams/avalanche"><img alt="Logo of the Colorado Avalanche" class="im_mid" src="https://cdn2.capfriendly.com/images/logos/colorado_avalanche.svg" style="height:15px;width:15px;margin-right:5px;margin-top:-2px;"/>COL</a></td><td class="center">27</td><td class="center" style="min-width:70px">C</td><td class="center" style="width:54px">Right</td><td class="center stat">82</td><td class="center stat">51</td><td class="center stat">89</td><td class="center stat_emph">140</td><td class="center stat">1.71</td><td class="center stat">35</td><td class="center stat">405</td><td class="center stat">0.13</td><td class="center stat">22:48</td><td class="center stat">-</td><td class="center stat">-</td><td class="center stat">-</td><td class="center stat">-</td><td class="center stat">-</td><td class="center">NMC</td><td class="center">UFA<br/><a href=""></a></td><td class="center">$12,600,000</td><td class="center">$16,500,000</td></tr><tr class="even"><td class="left"><div class="l">2. <a href="/players/connor-mcdavid">Connor McDavid</a></div></td><td class="center"><a href="/teams/oilers"><img alt="Logo of the Edmonton Oilers" class="im_mid" src="https://cdn2.capfriendly.com/images/logos/edmonton_oilers.svg" style="height:15px;width:15px;margin-right:5px;margin-top:-2px;"/>EDM</a></td><td class="center">26</td><td class="center" style="min-width:70px">C</td><td class="center" style="width:54px">Left</td><td class="center stat">76</td><td class="center stat">32</td><td class="center stat">100</td><td class="center stat_emph">132</td><td class="center stat">1.74</td><td class="center stat">35</td><td class="center stat">263</td><td class="center stat">0.12</td><td class="center stat">21:21</td><td class="center stat">-</td><td class="center stat">-</td><td class="center stat">-</td><td class="center stat">-</td><td class="center stat">-</t ...

# %%
#find table titles

world_titles = soup.find_all('th')

# %%
world_titles
# Out:
# [<th class="left" style="width:199px;min-width:199px">PLAYER</th>,
#  <th class="center" style="min-width:55px">TEAM</th>,
#  <th class="center brs_srt cp" data-srt="14">AGE</th>,
#  <th class="center" style="width:70px;min-width:70px">POS</th>,
#  <th class="center">HANDED</th>,
#  <th class="center brs_srt cp" data-srt="13"><span class="q" title="Games Played">GP</span></th>,
#  <th class="center brs_srt cp" data-srt="3"><span class="q" title="Goals">G</span></th>,
#  <th class="center brs_srt cp" data-srt="4"><span class="q" title="Assists">A</span></th>,
#  <th class="center brs_srt cp" data-srt="5"><span class="q" title="Points">P</span></th>,
#  <th class="center brs_srt cp" data-srt="25"><span class="q" title="Points Per Game">P/GP</span></th>,
#  <th class="center brs_srt cp" data-srt="9"><span class="q" title="Plus/Minus">+/-</span></th>,
#  <th class="center brs_srt cp" data-srt="22"><span class="q" title="Shots on Goal">Sh</span></th>,
#  <th class="center brs_srt cp" data-srt="24"><span class="q" title="Shooting Percentage">Sh%</span></th>,
#  <th class="center brs_srt cp" data-srt="10"><span class="q" title="Average Time on Ice">TOI</span></th>,
#  <th class="center brs_srt cp" data-srt="6"><span class="q" title="Wins">W</span></th>,
#  <th class="center brs_srt cp" data-srt="11"><span class="q" title="Losses">L</span></th>,
#  <th class="center brs_srt cp" data-srt="12"><span class="q" title="Shutouts">SO</span></th>,
#  <th class="center brs_srt cp" data-srt="7"><span class="q" title="Goals Against Average">GAA</span></th>,
#  <th class="center brs_srt cp" data-srt="8"><span class="q" title="Save Percentage">Sv%</span></th>,
#  <th class="center" style="width:80px;min-width:80px">CLAUSE</th>,
#  <th class="center brs_srt cp" data-srt="53" style="min-width:65px">EXPIRY</th>,
#  <th class="center brs_srt cp sorted_desc" data-srt="1" style="width:85px;min-width:85px">CAP HIT</th>,
#  <th class="center brs_srt cp" data-srt="2" style="width:80px;min-width:80px">SALARY</th>]

# %%
#extract table titles

world_table_titles = [title.text for title in world_titles]

# %%
world_table_titles
# Out:
# ['PLAYER',
#  'TEAM',
#  'AGE',
#  'POS',
#  'HANDED',
#  'GP',
#  'G',
#  'A',
#  'P',
#  'P/GP',
#  '+/-',
#  'Sh',
#  'Sh%',
#  'TOI',
#  'W',
#  'L',
#  'SO',
#  'GAA',
#  'Sv%',
#  'CLAUSE',
#  'EXPIRY',
#  'CAP HIT',
#  'SALARY']

# %%
#add table titles to df

df = pd.DataFrame(columns = world_table_titles)

df
# Out:
# Empty DataFrame
# Columns: [PLAYER, TEAM, AGE, POS, HANDED, GP, G, A, P, P/GP, +/-, Sh, Sh%, TOI, W, L, SO, GAA, Sv%, CLAUSE, EXPIRY, CAP HIT, SALARY]
# Index: []
#
# [0 rows x 23 columns]

# %%
#collect row data

column_data = soup.find_all('tr')

# %%
#extract table data and add to df

for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text for data in row_data]
    
    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#                         PLAYER TEAM AGE        POS HANDED  GP  G   A   P  \
# 0        1551. Jalen Chatfield  CAR  27         RD  Right  72  8  14  22
# 1          1552. Billy Sweezey  CBJ  27         RD  Right   0  0   0   0
# 2   1553. Dillon Heatherington  OTT  28         LD   Left   0  0   0   0
# 3         1554. Steven Fogarty  MIN  30      C, RW  Right   0  0   0   0
# 4        1555. Kevin Connauton  LAK  33      LD/RD   Left   0  0   0   0
# 5           1556. Kevin Gravel  NSH  31         LD   Left   0  0   0   0
# 6       1557. Dennis Cholowski  NYI  25         LD   Left   0  0   0   0
# 7       1558. Jonny Brodzinski  NYR  30          C  Right  57  6  13  19
# 8           1559. Matthew Peca  STL  30      LW, C   Left   0  0   0   0
# 9         1560. Jacob Moverare  LAK  24         LD   Left  24  1   0   1
# 10       1561. Jacob MacDonald  SJS  30      LD/RD   Left  34  7   2   9
# 11        1562. Dennis Gilbert  CGY  26         LD   Left  34  1   6   7
# 12         1563. Nicolas Petan  NYR  28  C, LW, RW   Left   6  0   2   2
# 13         1564. Cooper Marody  PHI  26      C, RW  Right   0  0   0   0
# 14      1565. Spencer Smallman  COL  26         RW  Right   0  0   0   0
# 15       1566. Kyle Capobianco  WPG  25         LD   Left   0  0   0   0
# 16      1567. Arnaud Durandeau  MTL  24         LW   Left   0  0   0   0
# 17     1568. Alex Barré-Boulet  TBL  26     RW, LW   Left  36  6   3   9
# 18        1569. Taylor Raddysh  CHI  25         RW  Right  73  5   9  14
# 19        1570. Boris Katchouk  OTT  25         LW   Left  59  7   6  13
# 20           1571. Jet Greaves  CBJ  22          G   Left   9  -   -   -
#
#     P/GP  ...    TOI  W  L SO   GAA   Sv% CLAUSE      EXPIRY   CAP HIT  \
# 0   0.31  ...  15:11  -  -  -     -     -                UFA  $762,500
# 1   0.00  ...         -  -  -     -     -                UFA  $762,500
# 2   0.00  ...         -  -  -     -     -                UFA  $762,500
# 3   0.00  ...         -  -  -     -     -                UFA  $762,500
# 4   0.00  ...         -  -  -     -     -                UFA  $762,500
# 5   0.00  ...         -  -  -     -     -                UFA  $762,500
# 6   0.00  ...         -  -  -     -     -                RFA  $762,500
# 7   0.33  ...  11:07  -  -  -     -     -                UFA  $762,500
# 8   0.00  ...         -  -  -     -     -                UFA  $762,500
# 9   0.04  ...  10:26  -  -  -     -     -                RFA  $762,500
# 10  0.26  ...  12:01  -  -  -     -     -                UFA  $762,500
# 11  0.21  ...  12:17  -  -  -     -     -                UFA  $762,500
# 12  0.33  ...  10:50  -  -  -     -     -                UFA  $762,500
# 13  0.00  ...         -  -  -     -     -                UFA  $762,500
# 14  0.00  ...         -  -  -     -     -                UFA  $762,500
# 15  0.00  ...         -  -  -     -     -         UFAGroup 6  $762,500
# 16  0.00  ...         -  -  -     -     -         UFAGroup 6  $762,500
# 17  0.25  ...  11:11  -  -  -     -     -                UFA  $758,333
# 18  0.19  ...  15:52  -  -  -     -     -                RFA  $758,333
# 19  0.22  ...  11:28  -  -  -     -     -                RFA  $758,333
# 20     -  ...      -  3  6  0  3.50  .908                RFA  $758,333
#
#       SALARY
# 0   $775,000
# 1   $775,000
# 2   $775,000
# 3   $775,000
# 4   $775,000
# 5   $775,000
# 6   $775,000
# 7   $775,000
# 8   $775,000
# 9   $775,000
# 10  $775,000
# 11  $775,000
# 12  $775,000
# 13  $775,000
# 14  $775,000
# 15  $775,000
# 16  $775,000
# 17  $775,000
# 18  $775,000
# 19  $775,000
# 20  $775,000
#
# [21 rows x 23 columns]

# %%
#export page one to csv file
#df.to_csv(r'/Users/ness/Desktop/Springboard/Projects/Capstone 2/NHL Salaries/Salaries_pg_1.csv', index = False)

# %%
#All 32 pages of active player data from Capfriendly.com for the 2023-24 season

page = 1

url_test = f"https://www.capfriendly.com/browse/active/2024?stats-season=2024&pg=2{page}"
r = requests.get(url_test)
soup = BeautifulSoup(r.text, 'html')
table = soup.find('table')
world_titles = soup.find_all('th')
world_table_titles = [title.text for title in world_titles]
all_player_data = pd.DataFrame(columns = world_table_titles)

while page!= 33:
    url_test = f"https://www.capfriendly.com/browse/active/2024?stats-season=2024&pg={page}"
    r = requests.get(url_test)
    soup = BeautifulSoup(r.text, 'html')
    #table = soup.find('table')
    #world_titles = soup.find_all('th')
    #world_table_titles = [title.text for title in world_titles]
    #df_test = pd.DataFrame(columns = world_table_titles)
    column_data = soup.find_all('tr')
    
    for row in column_data[1:]:
        row_data = row.find_all('td')
        individual_row_data = [data.text for data in row_data]
    
        length = len(all_player_data)
        all_player_data.loc[length] = individual_row_data
    
    page = page+1

# %%
all_player_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 all_player_data
#
# NameError: name 'all_player_data' is not defined

# %%
all_player_data.to_csv(r'/Users/ness/Desktop/Springboard/Projects/-Capstone 2/NHL Salaries/Salaries_all.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 all_player_data.to_csv(r'/Users/ness/Desktop/Springboard/Projects/-Capstone 2/NHL Salaries/Salaries_all.csv', index = False)
#
# NameError: name 'all_player_data' is not defined
